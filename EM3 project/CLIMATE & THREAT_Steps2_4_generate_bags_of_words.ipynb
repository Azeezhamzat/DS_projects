# %% [markdown]
# # In this script we will learn how to extract bags-of-words to perform dyachronic analysis of historical texts.

# %% [markdown]
# ## Section 1
# ### First we use word lists from psychometric tools and obtain synonyms and hyponyms using WordNet

# %%
## The first time you use this script, uncomment lines 3 and 5

#!pip install nltk
import nltk
#nltk.download('all')
from nltk.corpus import wordnet as wn

# Here we can change the langauge of analysis
languages = ['eng']

# %%
### Function to Generate synonyms and hyponyms using Wordnet

def generate_wordnet_list(word_base,languages,exclude_list):
  word_lists = []

  #iterate over languages
  for language in languages:
    word_list = []

    # iterate over words in the word_base list
    for word in word_base:

      ## iterate over different meanings of the word synsets
      for meaning in wn.synsets(word, pos=wn.NOUN+wn.VERB+wn.ADJ):
        if meaning.name() not in exclude_list:
          print(meaning)
          print(meaning.definition())
          print('\n')


          ## iterate over different synonyms and add them to list
          for synonym in meaning.lemmas(language):
            #print(synonym)

            ## if the synonym is no in the list add it
            if synonym.name() not in word_list:
              word_list.append(synonym.name())
              #print(synonym.name())

          ## iterate over hyponyms
          for hyponym in meaning.hyponyms():
            #print(hyponym.lemmas(language))

            ## iterate over synonyms of hyponyms
            for synonym_of_hyponym in hyponym.lemmas(language):
              #print(synonym_of_hyponym.name())

              ## if the synonym of the hyponym is no in the list add it
              if synonym_of_hyponym.name() not in word_list:
                word_list.append(synonym_of_hyponym.name())

    ## add the language-specific word list to the global word list, sort the words in alphabetic order   
    word_lists +=[sorted(word_list)]

  ## there are 3 lists now, one for each language, we iterate over the list of lists and print each
  for lst in word_lists:
    #print(lst)
    return(lst)

# %%
## Example of seed-words related to a target concept - for instance, clmate. 
## In this case, I obtained based seed word list from:
# Ishaya, S., & Abaje, I. B. (2008). Indigenous people's perception on climate change and adaptation strategies in Jema'a local government area of Kaduna State, Nigeria. Journal of geography and regional planning, 1(8), 138.
# Ayalew, M. S., Demissie, G. D., Muchie, K. F., Tadesse, S., & Alemu, K. PERCEPTION OF CLIMATE CHANGE AND ASSOCIATED FACTORS AMONG RURAL DWELLERS OF GONDAR ZURIA DISTRICT, NORTHWEST ETHIOPIA.
word_base_climate = ['Drought','typhoon', 'landslide','flood','Temperature','weather','environment','rainfall','weather','dry','adaptation','season','natural','ecosystems']
## Using the function above, we can obtain the list of synonyms and hyponyms of the seed words,
## We can also exclude word meanings that are irrelvant for the concept we want to measure

## For instance, 'quilt' is not related to climate, and we can add it to the exclusion list
## We run the script until all the words in the list of synsets displayed below have relevant meanings 

exclude_list_climate = ['landslide.n.01','flood.n.03','weather.v.01','weather.v.01','weather.v.03','dry.n.01','dry.s.02','dry.a.04','dry.a.05','dry.a.06','dry.a.07','dry.s.08','dry.s.09','dry.s.10','dry.s.12','dry.s.15','dry.s.16',
                       'adaptation.n.01','adaptation.n.03','season.n.03','season.v.01','season.v.02','temper.v.04','natural.n.01','natural.n.02','natural.n.03','natural.a.05','natural.s.06','natural.s.07','natural.s.08','natural.s.09','lifelike.s.02',
                       'dry.s.13','dry.s.14']
climate_list = generate_wordnet_list(word_base_climate,languages,exclude_list_climate)
# Out:
# Synset('drought.n.01')
# a shortage of rainfall
#
#
# Synset('drought.n.02')
# a prolonged shortage
#
#
# Synset('typhoon.n.01')
# a tropical cyclone occurring in the western Pacific or Indian oceans
#
#
# Synset('landslide.n.02')
# a slide of a large mass of dirt and rock down a mountain or cliff
#
#
# Synset('flood.n.01')
# the rising of a body of water and its overflowing onto normally dry land
#
#
# Synset('flood.n.02')
# an overwhelming number or amount
#
#
# Synset('flood.n.04')
# a large flow
#
#
# Synset('flood.n.05')
# the act of flooding; filling to overflowing
#
#
# Synset('flood_tide.n.02')
# the occurrence of incoming water (between a low tide and the following high tide);  -Shakespeare
#
#
# Synset('deluge.v.01')
# fill quickly beyond capacity; as with a liquid
#
#
# Synset('flood.v.02')
# cover with liquid, usually water
#
#
# Synset('flood.v.03')
# supply with an excess of
#
#
# Synset('flood.v.04')
# become filled to overflowing
#
#
# Synset('temperature.n.01')
# the degree of hotness or coldness of a body or environment (corresponding to its molecular activity)
#
#
# Synset('temperature.n.02')
# the somatic sensation of cold or heat
#
#
# Synset('weather.n.01')
# the atmospheric conditions that comprise the state of the atmosphere in terms of temperature and wind and clouds and precipitation
#
#
# Synset('weather.v.02')
# cause to slope
#
#
# Synset('weather.v.04')
# change under the action or influence of the weather
#
#
# Synset('upwind.s.01')
# towards the side exposed to wind
#
#
# Synset('environment.n.01')
# the totality of surrounding conditions
#
#
# Synset('environment.n.02')
# the area in which something exists or lives
#
#
# Synset('rain.n.01')
# water falling in drops from vapor condensed in the atmosphere
#
#
# Synset('weather.n.01')
# the atmospheric conditions that comprise the state of the atmosphere in terms of temperature and wind and clouds and precipitation
#
#
# Synset('weather.v.02')
# cause to slope
#
#
# Synset('weather.v.04')
# change under the action or influence of the weather
#
#
# Synset('upwind.s.01')
# towards the side exposed to wind
#
#
# Synset('dry.v.01')
# remove the moisture from and make dry
#
#
# Synset('dry.v.02')
# become dry or drier
#
#
# Synset('dry.a.01')
# free from liquid or moisture; lacking natural or normal moisture or depleted of water; or no longer wet
#
#
# Synset('dry.a.03')
# lacking moisture or volatile components
#
#
# Synset('dry.s.11')
# unproductive especially of the expected results
#
#
# Synset('adaptation.n.02')
# the process of adapting to something (such as environmental conditions)
#
#
# Synset('season.n.01')
# a period of the year marked by special events or activities in some field
#
#
# Synset('season.n.02')
# one of the natural periods into which the year is divided by the equinoxes and solstices or atmospheric conditions
#
#
# Synset('natural.a.01')
# in accordance with nature; relating to or concerning nature
#
#
# Synset('natural.a.02')
# existing in or produced by nature; not artificial or imitation
#
#
# Synset('natural.a.03')
# existing in or in conformity with nature or the observable world; neither supernatural nor magical
#
#
# Synset('natural.s.04')
# functioning or occurring in a normal way; lacking abnormalities or deficiencies
#
#
# Synset('ecosystem.n.01')
# a system formed by the interaction of a community of organisms with their physical environment

# %%
## This is a very broad list which includes all possible synonyms and hyponyms 
## related to the seed words we chose for climate

## As one can verify, this list needs prunning 
## some of it by excluding irrelevant synsets a priori (cell above), 
## but some of it can also be done manually a posteriori

print(climate_list)
# Out:
# ['Curie_point', 'Curie_temperature', 'Noachian_deluge', "Noah's_flood", 'Noah_and_the_Flood', 'Whitsun', 'Whitsuntide', 'Whitweek', 'absolute_temperature', 'absolute_zero', 'acclimation', 'acclimatisation', 'acclimatization', 'adaptation', 'adaption', 'adjustment', 'air', 'air_current', 'alluvion', 'ambiance', 'ambience', 'area', 'arena', 'atmosphere', 'atmospheric_condition', 'atmospheric_state', 'autumn', 'background', 'bad_weather', 'baseball_season', 'basketball_season', 'blood_heat', 'blow-dry', 'body_temperature', 'boil', 'boiling_point', 'circumstance', 'cloudburst', 'cold', 'cold_weather', 'coldness', 'comfort_zone', 'conditions', 'context', 'current_of_air', 'debacle', 'dedifferentiation', 'dehumidify', 'dehydrate', 'deluge', 'desiccate', 'dew_point', 'differentiation', 'domain', 'domestication', 'downfall', 'downpour', 'drench', 'drip-dry', 'drizzle', 'drought', 'drouth', 'dry', 'dry_out', 'dry_season', 'dry_up', 'ecology', 'ecosystem', 'effusion', 'element', 'elements', 'environment', 'environs', 'exhibition_season', 'exsiccate', 'fair_weather', 'fall', 'field', 'fishing_season', 'flash_flood', 'flash_point', 'flashflood', 'flashpoint', 'flood', 'flood_tide', 'flow', 'flowage', 'football_season', 'freezing_point', 'frigidity', 'frigidness', 'glut', 'good_weather', 'growing_season', 'habitat', 'harvest', 'harvest_time', 'haying', 'haying_time', 'heat', 'high_season', 'high_temperature', 'hockey_season', 'holiday_season', 'home', 'home_ground', 'hot_weather', 'hotness', 'hunting_season', 'inclemency', 'inclementness', 'inundate', 'inundation', 'landslide', 'landslip', 'low_temperature', 'medium', 'melting_point', 'melting_pot', 'mercury', 'milieu', 'mizzle', 'monsoon', 'mudslide', 'natural', 'off-season', 'orbit', 'outpouring', 'overflow', 'oversupply', 'parch', 'parts', 'peak_season', 'pelter', 'precipitation', 'preseason', 'rain', 'rain_shower', 'rainfall', 'rainstorm', 'rainy_season', 'rising_tide', 'rockslide', 'room_temperature', 'rough-dry', 'run_dry', 'scene', 'scope', 'scorch', 'sear', 'season', 'seedtime', 'setting', 'sheepshearing', 'shower', 'simmer', 'soaker', 'social_season', 'specialisation', 'specialization', 'sphere', 'spin-dry', 'spray-dry', 'spring', 'springtime', 'street', 'submerge', 'summer', 'summertime', 'sunshine', 'surround', 'surroundings', 'swamp', 'temperateness', 'temperature', 'thaw', 'thawing', 'the_Flood', 'theatrical_season', 'time_of_year', 'torrent', 'tumble_dry', 'typhoon', 'upwind', 'warming', 'warmth', 'waterspout', 'wave', 'weather', 'weather_condition', 'wind', 'winter', 'wintertime']

# %%
## THREAT

#Ishaya, S., & Abaje, I. B. (2008). Indigenous people's perception on climate change and adaptation strategies in Jema'a local government area of Kaduna State, Nigeria. Journal of geography and regional planning, 1(8), 138.
#Pickson, R. B., & He, G. (2021). Smallholder Farmers’ Perceptions, Adaptation Constraints, and Determinants of Adaptive Capacity to Climate Change in Chengdu. SAGE Open. https://doi.org/10.1177/21582440211032638

exclude_list_threat = ['vulnerable.s.02','decreasing.a.02','poor_people.n.01','hapless.s.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','switch.v.03','change.v.05','exchange.v.01','transfer.v.06','deepen.v.04','change.v.10','challenge.n.01','challenge.n.02','challenge.n.03','challenge.n.04','challenge.n.05','challenge.v.01','challenge.v.02','challenge.v.03','challenge.v.04','diminish.v.02','waste.n.01','waste.n.02','waste.n.05','waste.v.01','waste.v.02','neutralize.v.04','consume.v.03','godforsaken.s.01','critical.a.01',
                      'critical.a.03','critical.s.04','battle.n.01','gamble.v.01','competitiveness.n.01','fight.n.04','fight.n.05','contend.v.06','pest.n.03','supplanting.n.01','translation.n.07','displacement.n.04','displacement.n.07','loss.n.05','loss.n.06','personnel_casualty.n.01','refuse.v.02','refuse.v.01','decline.v.07','obstruct.v.02','flimsy.s.03''constraint.n.01','constraint.n.03','negative.n.01',
                       'negative.n.02','veto.v.01','negative.a.04','negative.s.06','damaging.s.02','negative.s.08','vulnerable.s.02','decreasing.a.02','poor.a.02','vulnerable.s.02','poor_people.n.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','change.v.05','change.v.06','exchange.v.01','transfer.v.06']

word_base_threat = ['unpredictable', 'risk', 'hindrances', 'Lack','vulnerable','decreasing','Poor','incidence','devastating','changing','challenges','repercussions' 'scarcity', 'diminishing', 'waste', 'critical','fight','disaster','exacerbated','severity','adverse','pest','depletion','endanger','displacement','loss','decline','impeded','fragile','inundation','constraints','negative','problem']
threat_list = generate_wordnet_list(word_base_threat,languages,exclude_list_education)
# Out:
# Synset('unpredictable.a.01')
# not capable of being foretold
#
#
# Synset('unpredictable.s.02')
# unknown in advance
#
#
# Synset('irregular.s.02')
# not occurring at expected times
#
#
# Synset('hazard.n.01')
# a source of danger; a possibility of incurring loss or misfortune
#
#
# Synset('risk.n.02')
# a venture undertaken without regard to possible loss or injury
#
#
# Synset('risk.n.03')
# the probability of becoming infected given that exposure to an infectious agent has occurred
#
#
# Synset('risk.n.04')
# the probability of being exposed to an infectious agent
#
#
# Synset('risk.v.01')
# expose to a chance of loss or damage
#
#
# Synset('gamble.v.01')
# take a risk in the hope of a favorable outcome
#
#
# Synset('hindrance.n.01')
# something immaterial that interferes with or delays action or progress
#
#
# Synset('hindrance.n.02')
# any obstruction that impedes or is burdensome
#
#
# Synset('hindrance.n.03')
# the act of hindering or obstructing or impeding
#
#
# Synset('lack.n.01')
# the state of needing something that is absent or unavailable
#
#
# Synset('miss.v.06')
# be without
#
#
# Synset('vulnerable.a.01')
# susceptible to attack
#
#
# Synset('vulnerable.s.02')
# susceptible to criticism or persuasion or temptation
#
#
# Synset('vulnerable.s.03')
# capable of being wounded or hurt
#
#
# Synset('decrease.v.01')
# decrease in size, extent, or range
#
#
# Synset('decrease.v.02')
# make smaller
#
#
# Synset('decreasing.a.01')
# becoming less or smaller
#
#
# Synset('decreasing.a.02')
# music
#
#
# Synset('poor_people.n.01')
# people without possessions or wealth (considered as a group)
#
#
# Synset('hapless.s.01')
# deserving or inciting pity; ; ; - Galsworthy
#
#
# Synset('poor.a.02')
# having little money or few possessions
#
#
# Synset('poor.a.03')
# characterized by or indicating poverty
#
#
# Synset('poor.a.04')
# lacking in specific resources, qualities or substances
#
#
# Synset('inadequate.s.02')
# not sufficient to meet a need
#
#
# Synset('poor.s.06')
# unsatisfactory
#
#
# Synset('incidence.n.01')
# the relative frequency of occurrence of something
#
#
# Synset('incidence.n.02')
# the striking of a light beam on a surface
#
#
# Synset('lay_waste_to.v.01')
# cause extensive destruction or ruin utterly
#
#
# Synset('devastate.v.02')
# overwhelm or overpower
#
#
# Synset('annihilating.s.02')
# making light of; ; ; - W.S.Gilbert
#
#
# Synset('annihilative.s.01')
# wreaking or capable of wreaking complete destruction
#
#
# Synset('crushing.s.01')
# physically or spiritually devastating; often used in combination
#
#
# Synset('change.v.01')
# cause to change; make different; cause a transformation
#
#
# Synset('change.v.02')
# undergo a change; become different in essence; losing one's or its original nature
#
#
# Synset('change.v.03')
# become different in some particular way, without permanently losing one's or its former characteristics or essence
#
#
# Synset('switch.v.03')
# lay aside, abandon, or leave for another
#
#
# Synset('change.v.05')
# change clothes; put on different clothes
#
#
# Synset('change.v.06')
# exchange or replace with another, usually of the same kind or category
#
#
# Synset('exchange.v.01')
# give to, and receive from, one another
#
#
# Synset('transfer.v.06')
# change from one vehicle or transportation line to another
#
#
# Synset('deepen.v.04')
# become deeper in tone
#
#
# Synset('change.v.10')
# remove or replace the coverings of
#
#
# Synset('changing.s.01')
# marked by continuous change or effective action
#
#
# Synset('challenge.n.01')
# a demanding or stimulating situation
#
#
# Synset('challenge.n.02')
# a call to engage in a contest or fight
#
#
# Synset('challenge.n.03')
# questioning a statement and demanding an explanation
#
#
# Synset('challenge.n.04')
# a formal objection to the selection of a particular person as a juror
#
#
# Synset('challenge.n.05')
# a demand by a sentry for a password or identification
#
#
# Synset('challenge.v.01')
# take exception to
#
#
# Synset('challenge.v.02')
# issue a challenge to
#
#
# Synset('challenge.v.03')
# ask for identification
#
#
# Synset('challenge.v.04')
# raise a formal objection in a court of law
#
#
# Synset('decrease.v.01')
# decrease in size, extent, or range
#
#
# Synset('diminish.v.02')
# lessen the authority, dignity, or reputation of
#
#
# Synset('diminishing.s.01')
# becoming smaller or less or appearing to do so
#
#
# Synset('waste.n.01')
# any materials unused and rejected as worthless or unwanted
#
#
# Synset('waste.n.02')
# useless or profitless activity; using or expending or consuming thoughtlessly or carelessly
#
#
# Synset('thriftlessness.n.01')
# the trait of wasting resources
#
#
# Synset('barren.n.01')
# an uninhabited wilderness that is worthless for cultivation
#
#
# Synset('waste.n.05')
# (law) reduction in the value of an estate caused by act or neglect
#
#
# Synset('waste.v.01')
# spend thoughtlessly; throw away
#
#
# Synset('waste.v.02')
# use inefficiently or inappropriately
#
#
# Synset('waste.v.03')
# get rid of
#
#
# Synset('waste.v.04')
# run off as waste
#
#
# Synset('neutralize.v.04')
# get rid of (someone who may be a threat) by killing
#
#
# Synset('consume.v.03')
# spend extravagantly
#
#
# Synset('pine_away.v.01')
# lose vigor, health, or flesh, as through grief
#
#
# Synset('waste.v.08')
# cause to grow thin or weak
#
#
# Synset('lay_waste_to.v.01')
# cause extensive destruction or ruin utterly
#
#
# Synset('waste.v.10')
# become physically weaker
#
#
# Synset('godforsaken.s.01')
# located in a dismal or remote area; desolate
#
#
# Synset('critical.a.01')
# marked by a tendency to find and call attention to errors and flaws
#
#
# Synset('critical.a.02')
# at or of a point at which a property or phenomenon suffers an abrupt change especially having enough mass to sustain a chain reaction
#
#
# Synset('critical.a.03')
# characterized by careful evaluation and judgment
#
#
# Synset('critical.s.04')
# urgently needed; absolutely necessary
#
#
# Synset('critical.s.05')
# forming or having the nature of a turning point or crisis
#
#
# Synset('critical.a.06')
# being in or verging on a state of crisis or emergency
#
#
# Synset('critical.a.07')
# of or involving or characteristic of critics or criticism
#
#
# Synset('battle.n.01')
# a hostile meeting of opposing military forces in the course of a war
#
#
# Synset('fight.n.02')
# the act of fighting; any contest or struggle
#
#
# Synset('competitiveness.n.01')
# an aggressive willingness to compete
#
#
# Synset('fight.n.04')
# an intense verbal dispute
#
#
# Synset('fight.n.05')
# a boxing or wrestling match
#
#
# Synset('contend.v.06')
# be engaged in a fight; carry on a fight
#
#
# Synset('fight.v.02')
# fight against or resist strongly
#
#
# Synset('fight.v.03')
# make a strenuous or labored effort
#
#
# Synset('crusade.v.01')
# exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for
#
#
# Synset('catastrophe.n.02')
# a state of extreme (usually irremediable) ruin and misfortune
#
#
# Synset('calamity.n.01')
# an event resulting in great loss and misfortune
#
#
# Synset('disaster.n.03')
# an act that has disastrous consequences
#
#
# Synset('worsen.v.02')
# make worse
#
#
# Synset('exacerbate.v.02')
# exasperate or irritate
#
#
# Synset('badness.n.02')
# used of the degree of something undesirable e.g. pain or weather
#
#
# Synset('asperity.n.01')
# something hard to endure
#
#
# Synset('austereness.n.01')
# extreme plainness
#
#
# Synset('severity.n.04')
# excessive sternness
#
#
# Synset('adverse.s.01')
# contrary to your interests or welfare
#
#
# Synset('adverse.s.02')
# in an opposing direction
#
#
# Synset('plague.n.01')
# a serious (sometimes fatal) infection of rodents caused by Yersinia pestis and accidentally transmitted to humans by the bite of a flea that has bitten an infected animal
#
#
# Synset('plague.n.02')
# any epidemic disease with a high death rate
#
#
# Synset('pest.n.03')
# a persistently annoying person
#
#
# Synset('pest.n.04')
# any unwanted and destructive insect or other animal that attacks food or crops or livestock etc.
#
#
# Synset('depletion.n.01')
# the act of decreasing something markedly
#
#
# Synset('depletion.n.02')
# the state of being depleted
#
#
# Synset('endanger.v.01')
# pose a threat to; present a danger to
#
#
# Synset('queer.v.02')
# put in a dangerous, disadvantageous, or difficult position
#
#
# Synset('supplanting.n.01')
# act of taking the place of another especially using underhanded tactics
#
#
# Synset('shift.n.01')
# an event in which something is displaced without rotation
#
#
# Synset('translation.n.07')
# the act of uniform movement
#
#
# Synset('displacement.n.04')
# (chemistry) a reaction in which an elementary substance displaces and sets free a constituent element from a compound
#
#
# Synset('displacement.n.05')
# (psychiatry) a defense mechanism that transfers affect or reaction from the original object to some more acceptable one
#
#
# Synset('displacement.n.06')
# to move something from its natural environment
#
#
# Synset('displacement.n.07')
# act of removing from office or employment
#
#
# Synset('loss.n.01')
# something that is lost
#
#
# Synset('loss.n.02')
# gradual decline in amount or activity
#
#
# Synset('loss.n.03')
# the act of losing someone or something
#
#
# Synset('loss.n.04')
# the disadvantage that results from losing something
#
#
# Synset('loss.n.05')
# the experience of losing a loved one
#
#
# Synset('loss.n.06')
# the amount by which the cost of a business exceeds its revenue
#
#
# Synset('personnel_casualty.n.01')
# military personnel lost by death or capture
#
#
# Synset('passing.n.02')
# euphemistic expressions for death
#
#
# Synset('decline.n.01')
# change toward something smaller or lower
#
#
# Synset('decline.n.02')
# a condition inferior to an earlier condition; a gradual falling off from a better state
#
#
# Synset('decay.n.02')
# a gradual decrease; as of stored charge or current
#
#
# Synset('descent.n.05')
# a downward slope or bend
#
#
# Synset('worsen.v.01')
# grow worse
#
#
# Synset('refuse.v.02')
# refuse to accept
#
#
# Synset('refuse.v.01')
# show unwillingness towards
#
#
# Synset('decline.v.04')
# grow smaller
#
#
# Synset('decline.v.05')
# go down
#
#
# Synset('decline.v.06')
# go down in value
#
#
# Synset('decline.v.07')
# inflect for number, gender, case, etc.,
#
#
# Synset('impede.v.01')
# be a hindrance or obstacle to
#
#
# Synset('obstruct.v.02')
# block passage through
#
#
# Synset('impeded.s.01')
# made difficult or slow
#
#
# Synset('delicate.s.03')
# easily broken or damaged or destroyed
#
#
# Synset('fragile.s.02')
# vulnerably delicate
#
#
# Synset('flimsy.s.03')
# lacking substance or significance; ; ; ; a fragile claim to fame"
#
#
# Synset('flood.n.01')
# the rising of a body of water and its overflowing onto normally dry land
#
#
# Synset('flood.n.02')
# an overwhelming number or amount
#
#
# Synset('constraint.n.01')
# the state of being physically constrained
#
#
# Synset('restraint.n.06')
# a device that retards something's motion
#
#
# Synset('constraint.n.03')
# the act of constraining; the threat or use of force to control the thoughts or behavior of others
#
#
# Synset('negative.n.01')
# a reply of denial
#
#
# Synset('negative.n.02')
# a piece of photographic film showing an image with light and shade or colors reversed
#
#
# Synset('veto.v.01')
# vote against; refuse to endorse; refuse to assent
#
#
# Synset('negative.a.01')
# characterized by or displaying negation or denial or opposition or resistance; having no positive features
#
#
# Synset('negative.a.02')
# expressing or consisting of a negation or refusal or denial
#
#
# Synset('negative.s.03')
# having the quality of something harmful or unpleasant
#
#
# Synset('negative.a.04')
# not indicating the presence of microorganisms or disease or a specific condition
#
#
# Synset('negative.a.05')
# reckoned in a direction opposite to that regarded as positive
#
#
# Synset('negative.s.06')
# less than zero
#
#
# Synset('damaging.s.02')
# designed or tending to discredit, especially without positive or helpful suggestions
#
#
# Synset('negative.s.08')
# having a negative charge
#
#
# Synset('minus.s.02')
# involving disadvantage or harm
#
#
# Synset('problem.n.01')
# a state of difficulty that needs to be resolved
#
#
# Synset('problem.n.02')
# a question raised for consideration or solution
#
#
# Synset('trouble.n.01')
# a source of difficulty

# %%
print(threat_list)
# Out:
# ['Americanise', 'Americanize', 'Armageddon', 'Europeanise', 'Europeanize', 'Frenchify', 'Gordian_knot', 'Islamise', 'Islamize', 'Noachian_deluge', "Noah's_flood", 'Noah_and_the_Flood', 'abate', 'abbreviate', 'abridge', 'absence', 'accelerate', 'accommodate', 'accustom', 'acerbate', 'acetylate', 'acetylise', 'acetylize', 'achromatise', 'achromatize', 'acquire', 'act_of_God', 'action', 'activate', 'adapt', 'add', 'adjust', 'adopt', 'adorn', 'adventure', 'adverse', 'aerate', "affaire_d'honneur", 'affect', 'affray', 'age', 'aggravate', 'agitate', 'air_bag', 'airbrake', 'albatross', 'alchemise', 'alchemize', 'alcoholise', 'alcoholize', 'alien', 'alienate', 'alkalinise', 'alkalinize', 'allegorise', 'allegorize', 'alluvion', 'alter', 'alternate', 'amalgamate', 'ameliorate', 'amend', 'amplitude', 'angulate', 'animalise', 'animalize', 'animate', 'animise', 'animize', 'annihilating', 'annihilative', 'antagonism', 'antiquate', 'antique', 'apocalypse', 'appeal', 'archaise', 'archaize', 'armed_combat', 'arouse', 'arrange', 'arrester', 'arrester_hook', 'arterialise', 'arterialize', 'ascend', 'ash', 'asperity', 'asphyxiate', 'assail', 'assault', 'assibilate', 'assimilate', 'assume', 'attack', 'austereness', 'automate', 'automatise', 'automatize', 'avianise', 'avianize', 'awaken', 'back_up', 'badness', 'balance-of-payments_problem', 'balk', 'band', 'bandy', 'banging', 'bar', 'barb', 'barbarise', 'barbarize', 'barren', 'barricade', 'barricado', 'barter', 'battering', 'battle', 'baulk', 'bear_down', 'bear_on', 'bear_upon', 'beating', 'beautify', 'become_flat', 'bedim', 'beef_up', 'begrime', 'belittle', 'bell_the_cat', 'bemire', 'bestialise', 'bestialize', 'bestow', 'better', 'bind', 'blackball', 'blear', 'blighter', 'blind', 'blister', 'block', 'block_off', 'block_out', 'block_up', 'blockade', 'blot_out', 'blow', 'blunt', 'blur', 'body_waste', 'boil', 'boil_down', 'bolshevise', 'bolshevize', 'bond', 'boondoggle', 'bounce', 'box', 'brain-teaser', 'brake', 'brake_pad', 'brake_shoe', 'branch_out', 'brawl', 'break', 'break_down', 'break_into', 'break_up', 'brighten', 'bring', 'bring_down', 'broaden', 'brush', 'brutalise', 'brutalize', 'bubble', 'bubonic_plague', 'burn', 'cage', 'calamity', 'calcify', 'call', 'call-out', 'call_into_question', "call_one's_bluff", 'call_out', 'calling_into_question', 'camp', 'campaign', 'can_of_worms', 'capacitate', 'capitalise', 'capitalize', 'capitulation', 'capture', 'carbonate', 'case', 'caseate', 'cash', 'cash_in', 'cataclysm', 'catastrophe', 'catch', 'catch_on', 'cause_to_sleep', 'cave_in', 'centralise', 'centralize', 'chain', 'challenge', 'chance', 'change', 'change_by_reversal', 'change_form', 'change_integrity', 'change_intensity', 'change_magnitude', 'change_over', 'change_posture', 'change_shape', 'change_state', 'change_surface', 'change_taste', 'changing', 'channel-surf', 'charge', 'chasten', 'cheapen', 'check', 'chicken-fight', 'chickenfight', 'chill', 'choke', 'choke_off', 'chord', 'circularize', 'circumscribe', 'civilise', 'civilize', 'clarify', 'clash', 'classicise', 'classicize', 'clean', 'clear', 'climb_up', 'clinker', 'clog', 'clog_up', 'close-quarter_fighting', 'close_up', 'clot', 'cloud', 'coagulate', 'coarsen', 'cohere', 'collapse', 'collimate', 'colly', 'color', 'color_in', 'colorise', 'colorize', 'colour', 'colour_in', 'colourise', 'colourize', 'combat', 'combat_injury', 'come', 'come_around', 'come_down', 'come_in', 'come_round', 'commercialise', 'commercialize', 'commix', 'communise', 'communize', 'commute', 'compensate', 'competitiveness', 'complexify', 'complicate', 'complication', 'compromise', 'concentrate', 'concretise', 'concretize', 'condense', 'confine', 'conflict', 'conform', 'confrontation', 'confuse', 'congest', 'conjugate', 'conk_out', 'constitutionalise', 'constitutionalize', 'constraint', 'consume', 'consumption', 'contaminate', 'contend', 'contract', 'contract_out', 'contrary', 'contribute', 'conundrum', 'conventionalise', 'conventionalize', 'convert', 'cook', 'cool', 'cool_do ...

# %% [markdown]
# ## Section 2: Generate a semantic vector map with word2vec

# %%
from gensim.models.word2vec import Word2Vec
import os
from os import path

## This function organizes corpus as list of sentences, and each sentence as a list of words,
## as input to the function WordVec

## Collect preprocessed texts in txt format
root_folder = os.getcwd()
print(root_folder)

## This will be a list of clean sentences
word2vec_input = []

## This iterates over your path, folders and subfolders looking for txt files
for path, subdirs, files in os.walk(root_folder):
    for file in files:
        if '.txt' in file and 'model' not in file:
            print(file)
            name = os.path.join(path, file)
        
            file_text = open(name, encoding = 'utf-8').read()

            ## this creates the list of paragraphs - lines
            text_list_paragraphs = file_text.split('\n')

            ## this will clean the paragraphs further -- getting read of \r at the end of the line
            for paragraph in text_list_paragraphs:
                #print (paragraph)
                
                paragraph = paragraph.replace('\r', '')

                ## we add the paragraphs to the word2vec input list
                word2vec_input += [paragraph.split(' ')]
            
                #print(word2vec_input)
# Out:
# C:\Users\azeez\Downloads\EM3 PROJECT - Copy\Revised Scripts 2to5and7
# ABUBAKAR AND COMFORT-2021-corporate response to climate change.txt
# Amanda Sabo-2016-impacts and responses knowledge community.txt
# Amanda-2016-Water Sensitive Planning Practices.txt
# Avil and David-2021-Carbon storage.txt
# Benedict-2021-neocorporatism.txt
# Djongmo et al-2021-Carbon management.txt
# Dunia E. Santiago-2021-Energy use in hotels.txt
# Jaeryoung et al-2021-Exploring the feasibility.txt
# Liqiang etal-2021-frequency tracking.txt
# Michel Gueldry-2018-Climate Change and public opinion.txt
# RIA JHOANNA-2021-adaptations toward climate risk challenges.txt
# Sikiru et al-2021-FarmerHerders’ Conflict and Climate Change.txt
# Suyong et al-2021-Coevolutionary game of manufacturer's abatement behavior.txt
# Tao et al-2021-multimodal transportation of medical aid.txt
# Tianyi et al-2021-building thermal system.txt
# Ufuk etal-2021-Intelligent energy optimization system.txt
# Vivien etal-2021-Heat Waves.txt
# Wang and Zhang-2021-Decision and coordination.txt
# Yangluxi Li and Lei Chendead-2021-low carbon architecture near water under self circulation system using dead effect.txt
# Zarqa Shaheen-2021-Climate Change and Natural Hazards.txt
# Zhezhi  et al-2021-luminescent coupling effect.txt

# %%
## Here we build the vector space with Word2Vec

SentenceCorpus = word2vec_input
word2vec_output = Word2Vec(SentenceCorpus, min_count=1)

# %%
## Save vector space

word2vec_output.save('w2v_model.txt')

# %% [markdown]
# ## Section 3. Use the vector semantic map to evaluate if the bags of words created in section 1 are ecologically valid

# %%
###  funtion to use word2vec to inquiry about the 10 most similar semantically words to each seed word in word_list

def get_word2vec_list(word_list,model):

  list_of_word2vec_lists = []
  for word in word_list:
    try:

      ## here is the crucial line - we are using the model that we trained to get the most similar words within our corpus
      list_vects=model.wv.most_similar([word],topn=10)

      new_list = []
      new_list +=[word]
      for item in list_vects:
        word1 = item[0]
        new_list += [word1]

      #print(new_list)
      #print('\n')
      list_of_word2vec_lists += [new_list]


    
    except KeyError:
      continue
  return(list_of_word2vec_lists)

# %%
## open vector space for english in the early modern period
model = Word2Vec.load('w2v_model.txt')

# %%
## get word2vec list of 10 most similar words for the prosociality bag of words

list_of_climate_w2v = get_word2vec_list(climate_list,model)

index =0
for w2v_list in list_of_climate_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['adaptation', 'mitigation', 'strategies', 'impact', 'technology', 'risks', 'issues', 'policies', 'knowledge', 'effects', 'adverse']
# 1 ['adjustment', 'thermal', 'envelope', 'under', 'first', 'transfer', 'time', 'state', 'types', 'power', 'linear']
# 2 ['air', 'CC', 'along', 'around', 'rice', 'farming', 'over', 'include', 'specific', 'who', 'fracture']
# 3 ['area', 'data', 'each', 'process', 'land', 'was', 'risk', 'characteristics', 'developed', 'relevant', 'simulation']
# 4 ['arena', 'status,', 'Mapfori', 'USSR,', 'Maureen', '(25,', '(Dbh),', 'Society’s', '“BDMET:', 'Feeling', 'Care']
# 5 ['atmosphere', 'BIM', 'developed', 'water', 'local', 'internet', 'respondents', 'knowledge', 'issues', 'process', 'renewable']
# 6 ['background', 'aim', 'context', 'building', 'development', 'profits', 'combination', 'energy', 'objective', 'means', 'study']
# 7 ['cold', 'technical', 'per', 'embedded', 'including', 'relative', 'status', 'conflicts', 'prevailing', 'We', 'do']
# 8 ['conditions', 'sustainable', 'economic', 'plans', 'temperatures', 'game', 'our', 'resources', 'increasing', 'control', 'soil']
# 9 ['context', 'aim', 'conservation', 'means', 'a', 'combination', 'result', 'objective', 'study', 'development', 'RD&D']
# 10 ['domain', 'business', 'sustainable', 'survey', 'tracking', 'indicates', 'monitoring', 'positive', 'calculation', 'control', 'public']
# 11 ['drought', 'products', 'our', 'models', 'included', 'social', 'indicates', 'platform', 'decision-making', 'innovative', 'theory']
# 12 ['dry', 'after', 'When', '(Table', 'stress', 'relative', 'before', 'EOS', 'multiple', 'like', 'To']
# 13 ['ecology', 'purpose', 'databases', 'paper.', 'subsurface', 'magnitude', 'paper,', 'authors,', 'face', 'limitation', 'mediator']
# 14 ['ecosystem', 'intensity', 'position', 'maximum', 'coefficient', 'network', 'behavior', 'model.', 'solar', 'weather', 'specific']
# 15 ['elements', 'our', 'positive', 'models', 'increasing', 'control', 'sustainable', 'public', 'construction', 'game', 'resonant']
# 16 ['environment', 'national', 'actions', 'different', 'were', 'women', 'how', 'policy', 'areas', 'government', 'access']
# 17 ['fall', 'no', 'some', 'less', 'relatively', 'think', 'did', 'see', 'private', 'much', 'connected']
# 18 ['field', 'health', 'environmental', 'SLR', 'global', 'levels', 'strategy', 'most', 'were', 'characteristics', 'community']
# 19 ['flood', 'including', 'wireless', 'per', 'status', 'solar', 'individual', 'model.', 'European', 'represent', 'storage']
# 20 ['flow', 'heating', 'example,', 'costs', 'four', 'For', 'using', 'core', 'sharing', 'coefficient', 'process,']
# 21 ['habitat', 'Living', 'Korea', 'Factors', 'European', 'respectively.', 'evolutionary', 'savannah', 'behavior', 'long-term', 'consists']
# 22 ['harvest', 'Hazelwood', 'conscious', '13:', 'preparation', '11464)', 'health?', '5,', 'agreements', 'concentration', '(composed']
# 23 ['heat', 'wave', 'regional', 'surface', 'national', 'current', 'available', 'QBF', 'all', 'government', 'Revit']
# 24 ['home', 'agroecological', 'do', 'complex', '(Table', 'Thus,', 'intense', 'increased', 'over', 'low-pass', 'requires']
# 25 ['inundate', 'Location', 'a.', 'manufacturers.', 'tripartite', 'degradation', 'multimodal', 'Paris', 'components', 'predictions', 'State']
# 26 ['inundation', 'as', 'important', 'just', 'to', 'means', 'described', 'result', 'source', 'useful', 'shown']
# 27 ['landslide', 'Machinery.', 'Develop,', 'conceptualization', '1752–1760.', 'Farrakhan', 'https://doi.org/10.3390/socsci8030093.', 'turn”', 'Units', 'meanings”', 'transportation.']
# 28 ['medium', 'consumers’', 'dry', 'receive', 'taking', 'Thus,', 'algorithm', 'welfare', 'increasingly', 'interests', '6']
# 29 ['monsoon', 'operations.', 'G.,', 'Saf', 'Specialist', 'Intelligence:', 'Requires', 'Experience', '2.3.', 'PR', 'regardless']
# 30 ['natural', 'about', 'strategies.', 'implementation', 'related', 'cooperation', 'reducing', 'application', 'its', 'response', 'role']
# 31 ['parts', 'time', 'phase', 'being', 'larger', 'using', 'grazing', 'various', 'state', 'many', 'population']
# 32 ['precipitation', 'whereas', 'COVID-19', 'rather', 'Their', 'Even', '11', 'like', '5', 'Indigenous', '2019']
# 33 ['rain', '“What', 'Gas', 'Waves', 'Comfort', 'Anglia', 'Southern', 'November', 'Publishing', '4:', 'First']
# 34 ['rainfall', 'respectively.', 'agricultural', 'green', 'among', 'three', 'group', 'strategies,', '3.', 'long-term', 'devices']
# 35 ['scope', 'role', 'development', 'design', 'results', 'new', 'system', 'policies', 'building', 'are', 'in']
# 36 ['season', 'level,', 'stress', 'algorithm', 'his', 'layer', 'pressure', 'sea', 'storm', 'animals', 'meters']
# 37 ['setting', 'current', 'time', 'comprehensive', 'value', 'emissions', 'manufacturers', 'all', 'capacity', 'being', 'various']
# 38 ['shower', 'cities.', 'proportion', 'means', 'development', 'objective', 'members', 'quality', 'competition', 'publisher', 'indexes']
# 39 ['sphere', 'context.', 'optimize', 'collaborated', 'made', 'better', 'mostly', 'reference', 'enhance', 'vulnerable', 'functional']
# 40 ['spring', 'Brazilian', 'R,', '±', 'Cruse', 'Trade', 'whereas', 'councils', '2020.', 'Abubakar', '4,']
# 41 ['street', 'affects', 'Within', 'existence', 'goveranance', 'positioned', 'relation', 'hotel.', 'optimize', 'electoral', 'gradual']
# 42 ['summer', 'dynamic', 'Delta', 'promotion', 'under', 'time', 'division', 'establishment', 'cooling', 'during', 'One']
# 43 ['surroundings', '2008).', '2006).', '2006;', 'chain.', '(2013),', 'stocks', 'disruption', '2016).', 'analysis.', 'crops']
# 44 ['swamp', 'late', 'practical', 'efforts,', 'technological', 'indices', 'responsibility', 'efficiency.', 'considering', 'aspects', 'broad']
# 45 ['temperature', 'both', 'systems', 'other', 'improve', 'integration', 'provided', 'However,', 'these', 'decision-making', 'processes']
# 46 ['typhoon', 'paper.', 'purpose', 'subdivisions', 'paper,', 'subsurface', 'latitudes', 'gathering', 'investigation.', 'publication.', 'emission,']
# 47 ['warming', 'respondents', 'demand', 'influence', 'BIM', 'reduction', 'area', 'effects', 'key', 'water', 'total']
# 48 ['wave', 'heat', 'regional', 'being', 'Revit', 'national', 'current', 'QBF', 'all', 'lands', 'few']
# 49 ['weather', 'across', 'behavior', 'costs', 'rice', 'international', 'agricultural', 'heating', 'One', 'among', 'political']
# 50 ['wind', 'group', 'green', 'plan', 'Open', 'minimum', 'sea-level', 'even', 'multi-junction', 'photovoltaic', 'We']
# 51 ['winter', 'included', 'second', 'decentralized', 'residential', 'function', 'theory', 'months', 'architecture', 'indigenous', 'trees']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with prosociality
## in this example we can chose, for instance (among others) indexes 3,6,9,11,13 and 14

relevant_climate_w2v_words = list( list_of_climate_w2v[i] for i in [3,6,9,11,13,14])


## Add all the words into one final bags of words
climate_BoW = [item for sublist in relevant_climate_w2v_words for item in sublist]

print(climate_BoW)
# Out:
# ['adjustment', 'some', 'specific', 'decision-making', 'sustainable', 'planning,', 'resources', 'plans', 'above', 'decision', 'models', 'cold', 'significantly', 'sustainable', 'stakeholders', 'lower', 'system.', 'specific', 'resources', 'plans', 'EU', 'software', 'drought', 'combination', 'chain', 'exchange', 'objective', 'profits', 'part', 'application', 'role', 'study.', 'context', 'elements', 'lack', 'profit', 'requirements', 'Delta', 'management', 'amount', 'architecture', 'two', 'service', 'function', 'fertilizer', '2017).', '2011).', '2009).', '(2017),', '2012).', 'Smith', 'regulation.', '(2017)', '[26]', '2019).', 'flood', '(1)', 'solar', 'Carbon', 'etc.', 'group', 'forest', 'sensors,', 'political', 'embedded', 'Their']

# %%
## get word2vec words for authoritarianism

list_of_threat_w2v = get_word2vec_list(threat_list,model)

index =0
for w2v_list in list_of_threat_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['argument', 'intended', '(islands', 'proof', 'hot,', 'equilibrium', 'import', 'Contentious', 'ancient', 'otherwise', '(ϕ1']
# 1 ['ask', 'Saarinen', 'Assis,', 'preserved', '“rise”', '2017)', 'welcome', 'additive', 'suggestions', 'transgression.', 'fits']
# 2 ['battle', 'that', 'used', 'single', 'increase', 'is', 'necessary', 'decrease', 'comes', 'full', 'play']
# 3 ['burn', 'plan.', 'k', 'CES', 'stocking', 'Zealand.', 'Lanka,', 'Adeyemi,', 'Seolgye-e', 'Unanticipated', 'Simultaneously,']
# 4 ['call', 'found', 'enhanced', 'explained', 'achieved', 'implemented', 'equal', 'likely', 'easily', 'calculated', 'Figures']
# 5 ['chance', 'brief', 'approach.', 'residential', '10.', 'stakeholder', 'low-carbon', 'compare', 'PMBOK', 'operations.', 'design.']
# 6 ['claim', 'national', 'all', 'strategy', 'integrating', 'rate', 'provided', 'access', 'were', 'mainly', 'temperature']
# 7 ['collide', '(Agricultural', 'desalination', 'automation', 'forum', 'Last', 'Factors', 'Korea', '(IPCC', 'Korea:', '[3].']
# 8 ['collision', 'It', 'likely', 'known', 'only', 'equal', 'will', 'integrated', 'may', 'they', 'should']
# 9 ['combat', 'hazards', 'mitigation', 'mitigating', 'hazards.', 'adapt', 'causes,', 'vulnerabilities', 'mitigate', 'hazards,', 'adapting']
# 10 ['competition', 'This', 'because', 'potential', 'developing', 'but', 'compared', 'greater', 'associated', 'framework', 'approach']
# 11 ['conflict', 'further', 'very', 'provides', 'LC', 'framework', 'hotel', 'cities', 'higher', 'but', 'consider']
# 12 ['consume', 'Oxford', 'York', 'UTCI', '(6):', '[A', 'unrestricted', '26', '2021;', 'Anglia', 'Trinidad']
# 13 ['contention', 'Ousman', 'displacement', 'crisis', 'Furthermore,', 'irrigation', 'plays', 'far', 'room', 'nationally', 'get']
# 14 ['contestation', 'Mallick', 'authorities,', '.1996.', 're-use,', '(Niedersächsisches', 'velocity', 'Victoria', 'constituency', 'Indices', 'March']
# 15 ['cost', 'under', 'between', 'thermal', 'many', 'total', 'main', 'SLR', 'emission', 'value', 'state']
# 16 ['critical', 'products', 'our', 'three', 'open', 'decision-making', 'management,', 'no', 'tracking', 'creativity', 'resource']
# 17 ['danger', 'PI', 'subsidy', 'From', 'since', 'capabilities', 'index', 'too', 'consumers’', 'include', 'taxation']
# 18 ['dearth', 'Punjab', 'sections,', 'paddock', 'occurrence,', 'commission.', 'state:', 'answered', 'organizing', 'Meteorotropic', 'Atmosphere']
# 19 ['decisive', 'themes', 'risk’s', 'sense', 'date,', 'Optimizes', 'British', 'Cuban', 'templates', 'tax-subsidy', 'emails,']
# 20 ['demand', 'total', 'reduction', 'carbon', 'BIM', 'many', 'main', 'government', 'performance', 'transport', 'parts']
# 21 ['devastate', '2020b;', 'firms', 'L1,', 'moves', 'supraordinate', '7.2', 'Toma', 'provincial', 'Fault', '[“Urban']
# 22 ['difference', 'some', 'systems', 'specific', 'lower', 'social', 'software', 'first', 'compressor', 'scenarios', 'power']
# 23 ['dispute', 'Trinidad', '[36]', 'D.,', '2021;', '1999.', 'Normal', '-', 'B.,', 'town', 'May']
# 24 ['dissipation', 'Cui,', '(Government', '(leaf', 'UZOMA', 'Griggs', 'world.', 'Lars', 'am', 'maximization,', 'nature-based']
# 25 ['draw', 'generate', 'get', 'grazing', 'what', 'However,', 'stable', 'less', 'standard', 'given', 'institutions']
# 26 ['enemy', 'centralized', 'First,', 'descriptive', 'systems.', 'without', 'material', 'improving', 'below', 'policies,', 'denial']
# 27 ['engagement', 'equally', 'sea-level', 'values', 'maximizing', 'structure', 'patterns', 'ETL', 'final', 'example,', '2015']
# 28 ['exact', 'investigating', '2016—in', 'Library', 'Kim.', 'McHarg,', 'cooperation.”', '3.05a', 'Retailers', 'ε∗∗', '77–89.']
# 29 ['excrement', '(K', 'eβ', 'Explaining', 'αβ', 'πn', 'θ', 'w', '(α', 'ϕ1', 'extra']
# 30 ['exhaust', 'adjustment.', 'Robert.', '(Schweikert,', '(GB50189-2015)’.', '“Ifugao', '32611-6595,', 'Lubell,', 'Materials', 'BJ,', 'stiffness']
# 31 ['fight', 'dealing', 'responding', 'mitigation', 'to', 'threat', 'adapt', 'extent', 'question', 'mitigating', 'technology']
# 32 ['fighting', '(QBFwCC)', 'governments;', 'speed,”', 'brief', 'incidents', 'guidance', 'discounts', 'Botswana:', 'Evans', '‘zero']
# 33 ['fool', 'bargaining', '2011–2016', 'vapor', '17,', '(271)', '(-0.62,', 'Stakeholder', '1998,', '0.00', 'Dwight']
# 34 ['friction', 'characteristic', 'Barangay', 'PCI', 'engineering', 'approach.', 'products.', 'efficiency.', 'technological', 'effects.', 'comparison,']
# 35 ['game', 'optimization', 'EU', 'monitoring', 'construction', 'resources', 'Lab', 'plan', 'existing', 'resonant', 'three']
# 36 ['gap', 'year', 'pressure', 'mangroves', 'intelligent', 'farmers.', 'CC', 'national,', 'personal', 'low', 'level,']
# 37 ['garbage', 'actuators', 'G.,', '(2012)', '•K)', 'Enter,', '(such', 'others.', 'groups,', 'tribunals', 'structural']
# 38 ['govern', 'selection', 'savannah', 'example,', 'group', 'formal', 'WSN', 'mean', 'wireless', 'percent', 'seasons']
# 39 ['hazard', 'demands', 'mitigation', 'adaptation', 'implemented', 'address', 'respond', 'regards', 'optimise', 'advance', 'permitted']
# 40 ['involve', 'Ecotect', 'described', 'such', 'responsible', 'addition,', 'undertaking', 'revealed', 'places', 'research,', 'publisher']
# 41 ['match', 'process', 'herders', 'growing', 'analyzed', 'transformation', 'networks', 'environmental', 'health', 'associated', 'frequency']
# 42 ['necessitate', 'Rye.', 'skills', 'Schäfer,', 'INE.', 'stakeholders.', 'continues', 'division,', 'Lion', 'identifiable.', 'dates']
# 43 ['need', 'expected', 'used', 'it', 'necessary', 'considered', 'may', 'that', 'also', 'known', 'way']
# 44 ['pacification', 'other,', 'sequester', 'addition', 'section.', 'function,', '5),', '1974).', 'concluded', 'speed.', 'paper,']
# 45 ['race', 'assessment.', 'realise', 'appeared', 'advance', 'fit', 'align', 'severity).', 'responded', 'socio-ecological', 'interesting']
# 46 ['refuse', 'issue-level', 'institutionalism', 'sites', 'By', 'Total', '(Figure', '2015,', 'Soil', 'liberal', '2007).']
# 47 ['require', 'consider', 'LC', 'than', 'higher', 'but', 'according', 'take', 'connected', 'determine', 'sources']
# 48 ['rising', 'medical', 'selected', 'past', 'personal', 'year', 'pressure', 'regional', 'particular', 'wave', 'area,']
# 49 ['risk', 'data', 'different', 'health', 'processes', 'effect', 'changes', 'government', 'range', 'production', 'policies']
# 50 ['scarcity', 'Clés', 'Tony', 'Q.', 'follow', 'vivos', '(De', 'Ge', 'Pakissan', '(Article)', 'Kern,']
# 51 ['series', 'along', 'during', 'around', 'fracture', 'example,', 'strategic', 'using', 'coefficient', 'while', 'intensity']
# 52 ['sewage', 'partly', 'projections', 'laboratory,', 'delta', 'world,', 'drive', 'politics', 'multiplier', 'prevent', 'section']
# 53 ['sewerage', '<select', '(Lentz', 'roads,', 'apply', 'propose', 'accessible', 'two-stage', 'Maître', 'ship', 'know']
# 54 ['shoot', 'WSPP.', 'game-changer', 'relax', 'hotel,', 'article,', 'epitomized', 'ArchiBUS', 'sink.', 'null', 'broke']
# 55 ['shower', 'actor-oriented', 'article,', '(WSPP),', 'accelerate', 'sequester', '12.4', 'omissions', 'headquartered', 'floor.', 'work,']
# 56 ['struggle', '3.', 'final', '2D', 'tend', 'three', 'instance,', 'equipment', 'territorial', 'creativity', 'critical']
# 57 ['take', 'people', 'so', 'achieve', 'standard', 'or', 'than', 'However,', 'into', 'possible', 'connected']
# 58 ['vital', 'nationally', 'combined', 'is,', 'see', 'where', 'had', 'much', 'faster', 'what', 'less']
# 59 ['want', 'effort', 'due', 'strategies', 'risks', 'define', 'effect', 'water', 'perceived', 'benefit', 'geographical']
# 60 ['war', 'affected', 'MAP', 'found', 'addressed', 'explained', 'implemented', 'conclusions', 'WSPP,', 'considered', 'equal']
# 61 ['warfare', 'Travelife', 'Nigeria’s', 'primarily', 'Daily', 'sixty', 'bulbs', 'nonlinear', 'Christian', 'sector,', 'Caprock']
# 62 ['waste', '4.', 'final', 'green', '3.', 'South', 'structure', 'Korea', '100', '(1)', 'ETL']
# 63 ['wastewater', 'TEv,', 'Equations', 'carrying', 'broader', 'history,', 'buying', 'operated', 'MS', 'damping', 'Katja']
# 64 ['words', 'diplomatic', '70', 'functions,', 'canals,', 'Intervals', 'Mkhululi,', 'waves.', 'independently', 'waves,', 'Quantum']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with prosociality
## in this example we choose indexes 3,6,9,11,13 and 14
relevant_threat_w2v_words = list( list_of_threat_w2v[i] for i in [4,12,15,38,48])


## Add all the words into one final bags of words
threat_BoW = [item for sublist in relevant_threat_w2v_words for item in sublist]

print(threat_BoW)
# Out:
# ['call', 'found', 'enhanced', 'explained', 'achieved', 'implemented', 'equal', 'likely', 'easily', 'calculated', 'Figures', 'consume', 'Oxford', 'York', 'UTCI', '(6):', '[A', 'unrestricted', '26', '2021;', 'Anglia', 'Trinidad', 'cost', 'under', 'between', 'thermal', 'many', 'total', 'main', 'SLR', 'emission', 'value', 'state', 'govern', 'selection', 'savannah', 'example,', 'group', 'formal', 'WSN', 'mean', 'wireless', 'percent', 'seasons', 'rising', 'medical', 'selected', 'past', 'personal', 'year', 'pressure', 'regional', 'particular', 'wave', 'area,']

# %%
## An hypothetical bag of words was thus obtained, which can be used for frequency analyses
## See next script

print('climate',climate_BoW)
print('\n')
print('threat',threat_BoW)
# Out:
# climate ['adjustment', 'some', 'specific', 'decision-making', 'sustainable', 'planning,', 'resources', 'plans', 'above', 'decision', 'models', 'cold', 'significantly', 'sustainable', 'stakeholders', 'lower', 'system.', 'specific', 'resources', 'plans', 'EU', 'software', 'drought', 'combination', 'chain', 'exchange', 'objective', 'profits', 'part', 'application', 'role', 'study.', 'context', 'elements', 'lack', 'profit', 'requirements', 'Delta', 'management', 'amount', 'architecture', 'two', 'service', 'function', 'fertilizer', '2017).', '2011).', '2009).', '(2017),', '2012).', 'Smith', 'regulation.', '(2017)', '[26]', '2019).', 'flood', '(1)', 'solar', 'Carbon', 'etc.', 'group', 'forest', 'sensors,', 'political', 'embedded', 'Their']
#
#
# threat ['call', 'found', 'enhanced', 'explained', 'achieved', 'implemented', 'equal', 'likely', 'easily', 'calculated', 'Figures', 'consume', 'Oxford', 'York', 'UTCI', '(6):', '[A', 'unrestricted', '26', '2021;', 'Anglia', 'Trinidad', 'cost', 'under', 'between', 'thermal', 'many', 'total', 'main', 'SLR', 'emission', 'value', 'state', 'govern', 'selection', 'savannah', 'example,', 'group', 'formal', 'WSN', 'mean', 'wireless', 'percent', 'seasons', 'rising', 'medical', 'selected', 'past', 'personal', 'year', 'pressure', 'regional', 'particular', 'wave', 'area,']
