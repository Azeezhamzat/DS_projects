# %% [markdown]
# ## Section 1
# ### First we use word lists from psychometric tools and obtain synonyms and hyponyms using WordNet

# %%
## The first time you use this script, uncomment lines 3 and 5

# !pip install nltk
import nltk
nltk.download('all')
from nltk.corpus import wordnet as wn

# Here we can change the langauge of analysis
languages = ['eng']
# Out:
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.6.5)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2021.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\azeez\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
### Function to Generate synonyms and hyponyms using Wordnet

def generate_wordnet_list(word_base,languages,exclude_list):
  word_lists = []

  #iterate over languages
  for language in languages:
    word_list = []

    # iterate over words in the word_base list
    for word in word_base:

      ## iterate over different meanings of the word synsets
      for meaning in wn.synsets(word, pos=wn.NOUN+wn.VERB+wn.ADJ):
        if meaning.name() not in exclude_list:
          print(meaning)
          print(meaning.definition())
          print('\n')


          ## iterate over different synonyms and add them to list
          for synonym in meaning.lemmas(language):
            #print(synonym)

            ## if the synonym is no in the list add it
            if synonym.name() not in word_list:
              word_list.append(synonym.name())
              #print(synonym.name())

          ## iterate over hyponyms
          for hyponym in meaning.hyponyms():
            #print(hyponym.lemmas(language))

            ## iterate over synonyms of hyponyms
            for synonym_of_hyponym in hyponym.lemmas(language):
              #print(synonym_of_hyponym.name())

              ## if the synonym of the hyponym is no in the list add it
              if synonym_of_hyponym.name() not in word_list:
                word_list.append(synonym_of_hyponym.name())

    ## add the language-specific word list to the global word list, sort the words in alphabetic order   
    word_lists +=[sorted(word_list)]

  ## there are 3 lists now, one for each language, we iterate over the list of lists and print each
  for lst in word_lists:
    #print(lst)
    return(lst)

# %%
## Example of seed-words related to a target concept - for instance, prosociality. 
## In this case, I obtained based seed word list from:
# Sterett, S. M. (2018). Climate change adaptation: Existential threat, welfare states and legal management. Oñati Socio-Legal Series, Forthcoming.
word_base_adaptation = ['adaptation','management','intervention','shifting','tranformation','governance','compesation','insurance','litigation','support','responsibility',]
## Using the function above, we can obtain the list of synonyms and hyponyms of the seed words,
## We can also exclude word meanings that are irrelvant for the concept we want to measure

## For instance, 'quilt' is not related to prosociality, and we can add it to the exclusion list
## We run the script until all the words in the list of synsets displayed below have relevant meanings 

exclude_list_adaptation = ['landslide.n.01','flood.n.03','weather.v.01','weather.v.01','weather.v.03','dry.n.01','dry.s.02','dry.a.04','dry.a.05','dry.a.06','dry.a.07','dry.s.08','dry.s.09','dry.s.10','dry.s.12','dry.s.15','dry.s.16',
                       'adaptation.n.01','adaptation.n.03','season.n.03','season.v.01','season.v.02','temper.v.04','natural.n.01','natural.n.02','natural.n.03','natural.a.05','natural.s.06','natural.s.07','natural.s.08','natural.s.09','lifelike.s.02',
                       'dry.s.13','dry.s.14','management.n.02','intervention.n.04','shift.v.10','shift.v.12','support.n.04','support.n.06','accompaniment.n.02','support.n.10','support.v.09',]
adaptation_list = generate_wordnet_list(word_base_adaptation,languages,exclude_list_adaptation)
# Out:
# Synset('adaptation.n.02')
# the process of adapting to something (such as environmental conditions)
#
#
# Synset('management.n.01')
# the act of managing something
#
#
# Synset('intervention.n.01')
# the act of intervening (as to mediate a dispute, etc.)
#
#
# Synset('intervention.n.02')
# a policy of intervening in the affairs of other countries
#
#
# Synset('interposition.n.02')
# the act or fact of interposing one thing between or among others
#
#
# Synset('treatment.n.01')
# care provided to improve a situation (especially medical procedures or applications that are intended to relieve illness or injury)
#
#
# Synset('shift.n.05')
# the act of moving from one place to another
#
#
# Synset('switch.v.04')
# make a shift in or exchange of
#
#
# Synset('shift.v.02')
# change place or direction
#
#
# Synset('transfer.v.04')
# move around
#
#
# Synset('stir.v.02')
# move very slightly
#
#
# Synset('shift.v.05')
# move from one setting or context to another
#
#
# Synset('shift.v.06')
# change in quality
#
#
# Synset('shift.v.07')
# move and exchange for another
#
#
# Synset('careen.v.02')
# move sideways or in an unsteady way
#
#
# Synset('lurch.v.02')
# move abruptly
#
#
# Synset('shift.v.11')
# change phonetically as part of a systematic historical change
#
#
# Synset('switch.v.03')
# lay aside, abandon, or leave for another
#
#
# Synset('shifting.s.01')
# continuously varying
#
#
# Synset('shifting.s.02')
# changing position or direction
#
#
# Synset('shifting.s.03')
# (of soil) unstable
#
#
# Synset('administration.n.02')
# the persons (or committees or departments etc.) who make up a body for the purpose of administering something
#
#
# Synset('government.n.02')
# the act of governing; exercising authority
#
#
# Synset('insurance.n.01')
# promise of reimbursement in the case of loss; paid to people or companies so concerned about hazards that they have made prepayments to an insurance company
#
#
# Synset('policy.n.03')
# written contract or certificate of insurance
#
#
# Synset('indemnity.n.01')
# protection against future loss
#
#
# Synset('litigation.n.01')
# a legal proceeding in a court; a judicial contest to determine and enforce legal rights
#
#
# Synset('support.n.01')
# the activity of providing for or maintaining by supplying with money or necessities
#
#
# Synset('support.n.02')
# aiding the cause or policy or interests of
#
#
# Synset('support.n.03')
# something providing immaterial assistance to a person or cause or interest
#
#
# Synset('documentation.n.03')
# documentary validation
#
#
# Synset('support.n.07')
# supporting structure that holds up or provides a foundation
#
#
# Synset('support.n.08')
# the act of bearing the weight of or strengthening
#
#
# Synset('support.n.11')
# financial resources provided to make some project possible
#
#
# Synset('support.v.01')
# give moral or psychological support, aid, or courage to
#
#
# Synset('support.v.02')
# support materially or financially
#
#
# Synset('back.v.01')
# be behind; approve of
#
#
# Synset('hold.v.10')
# be the physical support of; carry the weight of
#
#
# Synset('confirm.v.01')
# establish or strengthen as with new evidence or facts
#
#
# Synset('subscribe.v.03')
# adopt as a belief
#
#
# Synset('corroborate.v.03')
# support with evidence or authority or make more certain or confirm
#
#
# Synset('defend.v.01')
# argue or speak in defense of
#
#
# Synset('patronize.v.04')
# be a regular customer or client of
#
#
# Synset('digest.v.03')
# put up with something or somebody unpleasant
#
#
# Synset('duty.n.01')
# the social force that binds you to the courses of action demanded by that force; ; - John D.Rockefeller Jr
#
#
# Synset('province.n.02')
# the proper sphere or extent of your activities
#
#
# Synset('responsibility.n.03')
# a form of trustworthiness; the trait of being answerable to someone for something or being responsible for one's conduct

# %%
## This is a very broad list which includes all possible synonyms and hyponyms 
## related to the seed words we chose for climate

## As one can verify, this list needs prunning 
## some of it by excluding irrelevant synsets a priori (cell above), 
## but some of it can also be done manually a posteriori

print(adaptation_list)
# Out:
# ['Curia', 'G-Jo', 'abide', 'abutment', 'accept', 'acclimation', 'acclimatisation', 'acclimatization', 'accountability', 'acupressure', 'acupuncture', 'adaptation', 'adaption', 'adherence', 'adhesion', 'adjustment', 'administration', 'advance', 'advocacy', 'affirm', 'agitate', 'aid', 'anchor', 'answerability', 'answerableness', 'apologise', 'apologize', 'approval', 'approving', 'architrave', 'assist', 'assurance', 'attachment', 'authorisation', 'authorization', 'autogenic_therapy', 'autogenic_training', 'autogenics', 'automobile_insurance', 'back', 'back_up', 'backbone', 'backing', 'base', 'basement', 'bear', 'bear_out', 'bear_up', 'beat_down', 'bench', 'blessing', 'block', 'boost', 'brace', 'bracket', 'brass', 'break', 'bring_home_the_bacon', 'brook', 'budge', 'bunker', 'buoy', 'buoy_up', 'burden_of_proof', 'business_interruption_insurance', 'buttress', 'buttressing', 'buy_at', 'canalisation', 'canalization', 'car_insurance', 'careen', 'carry', 'carry_forward', 'carry_over', 'champion', 'change', 'change_over', 'channel-surf', 'channelisation', 'channelization', 'chiropractic', 'chock', 'civic_duty', 'civic_responsibility', 'coinsurance', 'conducting', 'confirm', 'corroborate', 'county_council', 'custody_battle', 'cut', 'dangling', 'database_management', 'dedifferentiation', 'defend', 'demand', 'demonstrate', 'dependability', 'dependableness', 'detoxification', 'differentiation', 'digest', 'diphthongise', 'diphthongize', 'direction', 'disenfranchisement', 'dislodge', 'disposal', 'document', 'documentation', 'domestication', 'duty', 'ecclesiastical_province', 'empowerment', 'encourage', 'endorse', 'endorsement', 'endure', 'establish', 'establishment', 'excuse', 'executive', 'fault', 'fend_for', 'filial_duty', 'finance', 'financial_backing', 'financial_support', 'fire_insurance', 'floater', 'floating_policy', 'fomentation', 'foot', 'footstall', 'foundation', 'frequent', 'fund', 'fundament', 'funding', 'further', 'governance', 'governing', 'governing_body', 'government', 'government_activity', 'government_officials', 'groundwork', 'group_insurance', 'guarantee', 'guardianship', 'guidance', 'handling', 'hanging', 'hazard_insurance', 'health_insurance', 'help', 'hold', 'hold_still_for', 'hold_up', 'homemaking', 'hydropathy', 'hydrotherapy', 'imperative', 'incumbency', 'indemnity', 'indorse', 'indorsement', 'insurance', 'insurance_policy', 'intercession', 'interference', 'intermediation', 'interposition', 'intervention', 'job', 'judicial_proceeding', 'judiciary', 'jump', 'justify', 'keep_going', 'keeping', 'keystone', 'lawmaking', 'leap', 'legal_duty', 'legislating', 'legislation', 'liability_insurance', 'life_assurance', 'life_insurance', 'lifeline', 'linchpin', 'line_of_duty', 'litigation', 'live_with', 'logistic_assistance', 'logistic_support', 'lurch', 'lynchpin', 'mainstay', 'maintenance', 'malpractice_insurance', 'management', 'massage', 'mediation', 'medical_aid', 'medical_care', 'misconduct', 'misdirection', 'misgovernment', 'mismanagement', 'misrule', 'modality', 'moral_obligation', 'naprapathy', 'naturopathy', 'noblesse_oblige', 'obligation', 'officialdom', 'organisation', 'organization', 'orthodontic_treatment', 'orthoptics', 'osteoclasis', 'osteopathy', 'oversight', 'patronage', 'patronise', 'patronize', 'pay', 'pedestal', 'pitch', 'plinth', 'plump_for', 'plunk_for', 'pole', 'policy', 'prerequisite', 'promote', 'prop', 'prop_up', 'propping_up', 'protagonism', 'prove', 'provide', 'province', 'put_up', 'rationalise', 'rationalize', 'reassurance', 'reinsurance', 'reliability', 'reliableness', 'remove', 'reposition', 'requirement', 'responsibility', 'responsibleness', 'rest-cure', 'safekeeping', 'scaffold', 'second', 'see_through', 'self-insurance', 'shew', 'shiatsu', 'shift', 'shifting', 'shifty', 'shop', 'shop_at', 'shore', 'shore_up', 'shoring', 'shoring_up', 'show', 'shuffle', 'shunt', 'sit_out', 'specialisation', 'specialization', 'sponsor', 'sponsorship', 'stand', 'stand_for', 'stand_up', 'steering', 'stick_out', 'stic ...

# %%
# ## THREAT

#Sterett, S. M. (2018). Climate change adaptation: Existential threat, welfare states and legal management. Oñati Socio-Legal Series, Forthcoming.
word_base_threat = ['warning','threathen','risk','problem','terrify','danger','attack','problems', 'trials','causation','harm','damage','blame']
   
                    # 'disaster','unpredictable', 'risk', 'hindrances', 'Lack','vulnerable','decreasing','Poor','incidence','devastating','changing','challenges','repercussions' 'scarcity', 'diminishing', 'waste', 'critical','fight','disaster','exacerbated','severity','adverse','pest','depletion','endanger','displacement','loss','decline','impeded','fragile','inundation','constraints','negative','problem']


exclude_list_threat = ['risk.n.02','attack.n.01','attack.n.02','fire.n.09','attack.v.02','attack.v.03','assail.v.01','attack.v.05',
                       'test.n.05','trial.n.02','test.n.04','trial.n.04','trial.n.05','damage.n.02','price.n.02','blasted.s.01'] #'vulnerable.s.02','decreasing.a.02','poor_people.n.01','hapless.s.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','switch.v.03','change.v.05','exchange.v.01','transfer.v.06','deepen.v.04','change.v.10','challenge.n.01','challenge.n.02','challenge.n.03','challenge.n.04','challenge.n.05','challenge.v.01','challenge.v.02','challenge.v.03','challenge.v.04','diminish.v.02','waste.n.01','waste.n.02','waste.n.05','waste.v.01','waste.v.02','neutralize.v.04','consume.v.03','godforsaken.s.01','critical.a.01',
#                        'critical.a.03','critical.s.04','battle.n.01','gamble.v.01','competitiveness.n.01','fight.n.04','fight.n.05','contend.v.06','pest.n.03','supplanting.n.01','translation.n.07','displacement.n.04','displacement.n.07','loss.n.05','loss.n.06','personnel_casualty.n.01','refuse.v.02','refuse.v.01','decline.v.07','obstruct.v.02','flimsy.s.03''constraint.n.01','constraint.n.03','negative.n.01',
#                         'negative.n.02','veto.v.01','negative.a.04','negative.s.06','damaging.s.02','negative.s.08','vulnerable.s.02','decreasing.a.02','poor.a.02','vulnerable.s.02','poor_people.n.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','change.v.05','change.v.06','exchange.v.01','transfer.v.06']

threat_list = generate_wordnet_list(word_base_threat,languages,exclude_list_threat)
# Out:
# Synset('warning.n.01')
# a message informing of danger
#
#
# Synset('admonition.n.01')
# cautionary advice about something imminent (especially imminent danger or other unpleasantness)
#
#
# Synset('warning.n.03')
# notification of something, usually in advance
#
#
# Synset('warn.v.01')
# notify of danger, potential harm, or risk
#
#
# Synset('warn.v.02')
# admonish or counsel in terms of someone's behavior
#
#
# Synset('warn.v.03')
# ask to go away
#
#
# Synset('warn.v.04')
# notify, usually in advance
#
#
# Synset('admonitory.s.01')
# serving to warn
#
#
# Synset('hazard.n.01')
# a source of danger; a possibility of incurring loss or misfortune
#
#
# Synset('risk.n.03')
# the probability of becoming infected given that exposure to an infectious agent has occurred
#
#
# Synset('risk.n.04')
# the probability of being exposed to an infectious agent
#
#
# Synset('risk.v.01')
# expose to a chance of loss or damage
#
#
# Synset('gamble.v.01')
# take a risk in the hope of a favorable outcome
#
#
# Synset('problem.n.01')
# a state of difficulty that needs to be resolved
#
#
# Synset('problem.n.02')
# a question raised for consideration or solution
#
#
# Synset('trouble.n.01')
# a source of difficulty
#
#
# Synset('terrify.v.01')
# fill with terror; frighten greatly
#
#
# Synset('danger.n.01')
# the condition of being susceptible to harm or injury
#
#
# Synset('danger.n.03')
# a cause of pain or injury or loss
#
#
# Synset('danger.n.04')
# a dangerous place
#
#
# Synset('approach.n.01')
# ideas or actions intended to deal with a problem or situation
#
#
# Synset('attack.n.05')
# the act of attacking
#
#
# Synset('attack.n.06')
# a decisive manner of beginning a musical tone or phrase
#
#
# Synset('attack.n.07')
# a sudden occurrence of an uncontrollable condition
#
#
# Synset('attack.n.08')
# the onset of a corrosive or destructive process (as by a chemical agent)
#
#
# Synset('attack.n.09')
# strong criticism
#
#
# Synset('attack.v.01')
# launch an attack or assault on; begin hostilities or start warfare with
#
#
# Synset('attack.v.06')
# begin to injure
#
#
# Synset('problem.n.01')
# a state of difficulty that needs to be resolved
#
#
# Synset('problem.n.02')
# a question raised for consideration or solution
#
#
# Synset('trouble.n.01')
# a source of difficulty
#
#
# Synset('trial.n.06')
# an annoying or frustrating or catastrophic event
#
#
# Synset('causing.n.01')
# the act of causing something to happen
#
#
# Synset('injury.n.01')
# any physical damage to the body caused by violence or accident or fracture etc.
#
#
# Synset('damage.n.01')
# the occurrence of a change for the worse
#
#
# Synset('damage.n.03')
# the act of damaging something or someone
#
#
# Synset('harm.v.01')
# cause or do harm to
#
#
# Synset('damage.n.01')
# the occurrence of a change for the worse
#
#
# Synset('damage.n.03')
# the act of damaging something or someone
#
#
# Synset('wrong.n.02')
# any harm or injury resulting from a violation of a legal right
#
#
# Synset('damage.v.01')
# inflict damage upon
#
#
# Synset('damage.v.02')
# suffer or be susceptible to damage
#
#
# Synset('incrimination.n.01')
# an accusation that you are responsible for some lapse or misdeed
#
#
# Synset('blame.n.02')
# a reproach for some lapse or misdeed
#
#
# Synset('blame.v.01')
# put or pin the blame on
#
#
# Synset('blame.v.02')
# harass with constant criticism
#
#
# Synset('blame.v.03')
# attribute responsibility to

# %%
# ## DAMAGE

# #Stewart A. E. (2021). Psychometric Properties of the Climate Change Worry Scale. International journal of environmental research and public health, 18(2), 494. https://doi.org/10.3390/ijerph18020494

# exclude_list_damage = ['price.n.02','personnel_casualty.n.01','worry.v.05','worry.v.06','effect.n.04','effect.n.05','affect.n.01','involve.v.01','feign.v.01','severe.s.04','reverence.v.01','stress.n.01','stress.n.03','stress.n.05','stress.v.01','stress.v.02','try.v.07','depression.n.05','depression.n.08','depression.n.09','extreme.n.01','extreme_point.n.01','extreme.s.04','damage.n.02','risk.n.02','gamble.v.01','sensitivity.n.03','fear.n.03']
# #
# word_base_damage = ['damage','loss','worry','effect','affect','outbreak','severe','paralyzed','difficult','fear','stress','anxiety','depression','extreme','threat','risks','sensitivity']
# damage_list = generate_wordnet_list(word_base_damage,languages,exclude_list_damage)

# %%
print(threat_list)
# Out:
# ['CVA', 'Gordian_knot', 'admonish', 'admonition', 'admonitory', 'adventure', 'afflict', 'alarm', 'alarmism', 'alert', 'alerting', 'anxiety_attack', 'apoplexy', 'approach', 'aspersion', 'assail', 'assault', 'attack', 'attempt', 'avenue', 'balance-of-payments_problem', 'bang_up', 'beleaguer', 'bell_the_cat', 'besiege', 'bilge', 'birth_trauma', 'bite', 'blame', 'blast_trauma', 'bleeding', 'blemish', 'blitz', 'blunt_trauma', 'bomb', 'bombard', 'brain-teaser', 'brain_damage', 'break', 'bruise', 'bump', 'burn', 'bust', 'calumny', 'can_of_worms', 'cannonade', 'case', 'causation', 'causing', 'caution', 'cautionary', 'caveat', 'cerebrovascular_accident', 'chance', 'charge', 'circumvent', 'clear_and_present_danger', 'coercion', 'compulsion', 'contusion', 'conundrum', 'convulsion', 'corrode', 'counterattack', 'counterstrike', 'cryopathy', 'cut_up', 'damage', 'danger', 'deep_water', 'defacement', 'defamation', 'defloration', 'deflower', 'deformation', 'denigration', 'deterrent_example', 'detriment', 'discourage', 'disfiguration', 'disfigurement', 'dislocation', 'distortion', 'disturb', 'eat', 'eat_away', 'electric_shock', 'endangerment', 'enigma', 'erode', 'example', 'exemplary', 'exposure', 'false_alarm', 'fault', 'find_fault', 'fire', 'fit', 'flare', 'flaw', 'forewarn', 'forewarning', 'fracture', 'fret', 'frost', 'frostbite', 'gamble', 'gas', 'go_for_broke', 'growing_pains', 'haemorrhage', 'harm', 'hazard', 'hazardousness', 'heads-up', 'health_hazard', 'heart_attack', 'hem_in', 'hemorrhage', 'hit', 'homework_problem', 'hurt', 'hydra', 'hysterics', 'ictus', 'impair', 'impairment', 'incrimination', 'inculpation', 'inducement', 'inducing', 'induction', 'influence', 'initiation', 'injure', 'injury', 'insect_bite', 'insecurity', 'intravasation', 'invade', 'jeopardize', 'jeopardy', 'job', 'koan', 'ladder', 'lay_on_the_line', 'legal_injury', 'lesion', 'lesson', 'luck_it', 'luck_through', 'mangle', 'mar', 'matter', 'menace', 'monish', 'monition', 'monitory', 'moral_hazard', 'mutilate', 'mystifier', 'object_lesson', 'occlusion', 'occupational_hazard', 'occupy', 'panic', 'paroxysm', 'pelt', 'penetrating_injury', 'penetrating_trauma', 'pepper', 'peril', 'perilousness', 'pick', 'pinch', 'plan_of_attack', 'pons_asinorum', 'poser', 'powder_keg', 'premonition', 'pressure_point', 'previse', 'problem', 'pull', 'put_on_the_line', 'puzzle', 'puzzler', 'race_problem', 'raid', 'rap', 'raptus', 'ravel', 'rebus', 'riddle', 'risk', 'risk_of_exposure', 'risk_of_infection', 'riskiness', 'run', 'run_a_risk', 'rupture', 'rust', 'scathe', 'seizure', 'self-incrimination', 'sending', 'shatter', 'sicken', 'slander', 'smash', 'smash_up', 'smite', 'spoil', 'spot', 'stake', 'sticker', 'sting', 'storm', 'strafe', 'strain', 'strategic_warning', 'strike', 'stroke', 'stumper', 'submarine', 'surprise', 'surround', 'sword_of_Damocles', 'tactical_warning', 'take_a_chance', 'take_chances', 'teaser', 'terrify', 'terrorise', 'terrorize', 'threat', 'threaten', 'tone-beginning', 'torpedo', 'total', 'touch', 'toughie', 'trauma', 'trial', 'tribulation', 'trigger', 'trouble', 'twist', 'venture', 'visitation', 'vitiate', 'vulnerability', 'wake-up_call', 'wale', 'warn', 'warning', 'weal', 'wear_away', 'welt', 'wheal', 'whiplash', 'whiplash_injury', 'whittle_away', 'whittle_down', 'word_of_advice', 'wound', 'wounding', 'wrench', 'wrong']

# %% [markdown]
# ## Section 2: Generate a semantic vector map with word2vec

# %%
from gensim.models.word2vec import Word2Vec
import os
from os import path

## This function organizes corpus as list of sentences, and each sentence as a list of words,
## as input to the function WordVec

## Collect preprocessed texts in txt format
root_folder = os.getcwd()
print(root_folder)

## This will be a list of clean sentences
word2vec_input = []

## This iterates over your path, folders and subfolders looking for txt files
for path, subdirs, files in os.walk(root_folder):
    for file in files:
        if '.txt' in file and 'model' not in file:
            print(file)
            name = os.path.join(path, file)
        
            file_text = open(name, encoding = 'utf-8',errors='ignore').read()

            ## this creates the list of paragraphs - lines
            text_list_paragraphs = file_text.split('\n')

            ## this will clean the paragraphs further -- getting read of \r at the end of the line
            for paragraph in text_list_paragraphs:
                #print (paragraph)
                
                paragraph = paragraph.replace('\r', '')

                ## we add the paragraphs to the word2vec input list
                word2vec_input += [paragraph.split(' ')]
            
                #print(word2vec_input)
# Out:
# C:\Users\azeez\Documents\EM3 SUBMISSION FOLDER
# aaditya-2012-Climate responsive.txt
# abdel-2013-Ski.txt
# abdul-2012-Mod.txt
# abo-2012-Microaerobic.txt
# Abu-2009-compression.txt
# afonso-2013-Tracer gas.txt
# afrasiabian-2019-analysis.txt
# agrawal-2011-Flow characteristics.txt
# agrawal-2012-Study.txt
# agyeni-2012-Experimenta.txt
# ahmad-2016-Investigation of the ef.txt
# ahmadi-2016-Applying.txt
# ahmadi-2016-Thermodynamic anal.txt
# ahmadi-2020-Portfolio optimization.txt
# ahmed-2018-Design methodology.txt
# Ajay-2009-simultaneous.txt
# akyuz-2010-Energetic.txt
# alamier-2020- Synthesi.txt
# alayietal-2020-Energy.txt
# alayietal-2020-Technical and environmental.txt
# aldali-2011-energetic.txt
# aldali-2011-Solar absorber tube analysis.txt
# aleknaviciute-2012-Plasma assis.txt
# aleknaviviute-2016-Towards clean.txt
# alexander-2013-solid sorption.txt
# ali ahmadi-2016-Modeling solubility of carb.txt
# alkhalidi etal-2019-Energy efficient cooling.txt
# alkhalidi etal-2020-Using Wood.txt
# alkhalidi-2020- Do green buildings.txt
# Allison-2014-thermal energy storage.txt
# alm-2020-Quantum chemica.txt
# almosawi-2020-Synergistic effect of.txt
# almutairi etal-2011-Cycling durability studies.txt
# alqahtani-2019-The effect.txt
# alqahtani-2020-Building enve.txt
# alsallal-2010-Daylighting and visual performance.txt
# alsallal-2018-Daylighting performan.txt
# altan etal-2019-An experimental study roof.txt
# alwetaishi-2019-Sustainable ap.txt
# alyousef and varnham-2010-Saudi Arabia.txt
# Amanda Sabo-2016-impacts and response.txt
# Amanda-2016-Water Sensitive Planning Practices.txt
# amhadi and assaf-2019-Assessment.txt
# An etal-2014-Efficiency of household.txt
# ana etal-2010-Performance simulation.txt
# ana etal-2019-Energy assessment.txt
# Andrea and Francis-2020-tropical climate.txt
# anestopoulou etal-2016-On the development.txt
# angrisani etal-2013-the influence of cooling air.txt
# annadurai etal-2018-Experimental.txt
# Aprea etal-2012-exergy an.txt
# Arif etal-2012-exergy analysis.txt
# arslan-2013-Characterization.txt
# ascione etal-2016-Design.txt
# ashley-2016-direct absorbing.txt
# Ashouri etal-2015-organic rankine cycle.txt
# assad-2020-Renewable.txt
# auid etal-2013-Organic Rankine cycles.txt
# avgerinos -2013-Computational study.txt
# avgerinos etal-2016-Experimental stu.txt
# avgerinos-2016-Effect.txt
# awogbemi etal-2019-Comparative stud.txt
# awogbemi etal-2020-Optimization of FAME.txt
# aydin etal-2015-Numerical analysis of solar.txt
# ayou etal-2013-Analysis.txt
# Azad-2008-Split heat pipe heat.txt
# azad-2012-heat pipe heat exchanger.txt
# baitule and sudhakar-2017-Solar powered green campus.txt
# Baljit etal-2020-performance study.txt
# bANSAL-2009-evaporative cooling.txt
# baral-2020-Mathematical.txt
# baral-2020-Thermodynamic and financial.txt
# bardineh etal-2018-Medical.txt
# Barnwal etal-2008-thermal greenhouse dryer.txt
# Barros etal-2013-land use.txt
# bensebaa etal-2016-potential application for solar thermal absorber.txt
# bert-2011-fuel cells.txt
# bhattacharyya etal-2010-adiabatic capillary tube in a transcritical CO2 system.txt
# Bi etal-2009-Ecological.txt
# Birnie etal-2013-effective air purification.txt
# Boncini etal-2008-Double Light Pipe.txt
# Bottarelli etal-2017-tile covering.txt
# bottarelli etal-2020-Solar gain.txt
# bottarelli-2012-Numerical.txt
# bottarelli-2019-Testing of a dualsource heat pump.txt
# bouaid etal-2012-Optimization.txt
# Boukhanouf etal-2013-generation s.txt
# Bozonnet etal-2013-urban fluxes.txt
# Budania etal-2013-solar absorption.txt
# burhan etal-2018-Energy distribution.txt
# Busato etal-2008-cogeneration modules.txt
# busato etal-2012-Energy and economic.txt
# busato etal-2013-Multisource.txt
# buyadgie etal-2015-Solar low.txt
# buyagbie etal-2012-Conceptual design.txt
# bwapwa etal-2019-Jet fuel.txt
# cai and yan-2018-The plannin.txt
# Chamchine etal-2013-integrated assesment.txt
# Chandiwala-2009-Sustainable Homes in the UK.txt
# chen and li-2020-A state of art meth.txt
# Chen etal-2008-constructional entransy.txt
# chen etal-2009-Research on ground coupled heat.txt
# chen etal-2010-An experimentaL.txt
# chen etal-2010-Development of photovoltaic thermal.txt
# chen etal-2012-Constructal.txt
# chen etal-2012-Internal.txt
# chen etal-2012-lessons learnt from an operating analysis.txt
# chen etal-2012-Optimal expansion.txt
# chen etal-2012-Thermodynamic.txt
# chen etal-2016-Modeling.txt
# chen etal-2016-Theoretical.txt
# chen etal-2018-Performance.txt
# chen-2018-Study on energy.txt
# chien-2014-Assessment.txt
# cho etal-2014-Energy.txt
# chong-2013-Comparing.txt
# chow-2012-The potential.txt
# Christian etal-2009-predictingdomestic.txt
# chu etal-2020-Effects of stripper.txt
# Chun etal-2008-novel thermodiode designs.txt
# chung and ju-2010-A hybrid design of VAWT.txt
# Ciampi etal-2013-energy performance.txt
# ciampi etal-2014-energy and economic analyses.txt
# colombo-2012-Carbon dioxide refrigeration with heat.txt
# Comarazamy etal-2013-impacts of urb.txt
# Cooke etal-2013-biomass energy crop feasibility.txt
# corberan etal-2018-Dual source.txt
# coskun etal-2009-Energy and exergy.txt
# cruikshank-2011-economic.txt
# cuce and cuce-2013-Optimization.txt
# cuce and cuce-2013-Theoretical investigation of hot box solar coo.txt
# cuce and riffat-2016-A comprehensive assessment of sectoral energy.txt
# Cuimin etal-2020-energy conservation.txt
# d'alessandro etal-2016-Innovative concretes for low carbon constructions.txt
# dakwale and ralegaonkar-2011-Review of carbon emission through buildings.txt
# Daniel C. Staley-2013-urban forests and solar power.txt
# darkwa and fraser-2012-Performance of an integrated solar absorption cooling system.txt
# Davies etal-2013-seawater.txt
# dayma etal-2013-Energetic and exergetic analyses of a transcritical N2O heat pump system.txt
# dien etal-2011-Biochemical processing of reed canarygrass into fuel ethanol.txt
# ding and riffat-2012-Thermochemical energy storage technologies for building applications.txt
# ding-2019-Comparison.txt
# Du etal-2017-impact of blades wrap energy.txt
# du-2011-electroca.txt
# durakovic and torlak-2016-Experimental.txt
# ebhota-2018-The place.txt
# eboka etal-2018-Detailed.txt
# eicker-2012-Large scal.txt
# elbaiuomy-2017-The impact.txt
# elmer etal-2016-Experimental.txt
# eloka and onunka-2020-Sustainable.txt
# elsayed-2013-Thermodynamic.txt
# elsayed-2014-Numerical investigation.txt
# Embaye etal-2014-effect of flow pulsation.txt
# enayatizade-2019-Techno econom.txt
# Ernest-2008-sun spot related climate variations.txt
# esfahankalteh-2020-Achieving.txt
# fadeyibi etal-2020-Ecological.txt
# Fan etal-2017-intermittent supply.txt
# Fan etal-2018-cooling load prediction.txt
# fang etal-2012-Characterization.txt
# fang etal-2017-Experimental.txt
# farikhah-2020- The effect.txt
# fazeli-2013-Analysing.txt
# feng etal-2010-Heating.txt
# feng etal-2010-steady-flow endoreversible heat.txt
# feng etal-2013-Constructal.txt
# ferron etal-2011-custom.txt
# fhazali etal-2017-Feasibility.txt
# filippeschi etal-2012-Feasibility.txt
# fritschi etal-2016-Efficiency.txt
# fu etal-2009-co2 emission.txt
# gago etal-2010-irradiation and temperatur.txt
# gan-2015-Impacts of dynam.txt
# gao etal-2010-concentrating PV modules.txt
# Gao etal-2013-A comparativ.txt
# gao etal-2018-Comparis.txt
# Ge etal-2009-water absorption.txt
# Gennaro-2014-climatechangeAndRespiratory.txt
# georges-2013-Design.txt
# ghabra-2017-The impac.txt
# ghalamchi-2016-Evolving.txt
# gharghani-2020-An experimental.txt
# ghazali-2017-Feasibilit.txt
# gong etal-2012-Emissions.txt
# gordeeva etal-2012-Composites.txt
# goshayeshi and chaer-2016-Comparison.txt
# graham etal-2012-Degradati.txt
# guo etal-2012-Numerical.txt
# Guo etal-2018-Surrounding rock control.txt
# guohui gan-2013-Dynami.txt
# gupta etal-2019-analysis of.txt
# gUPTA-2009-Moving towards.txt
# Gupta-2009-Sustainable energy technologies.txt
# gurler etal-2018-Experimental investigation.txt
# gurler-2020-longterm monitoring.txt
# haghighi and maerefat-2014-Design.txt
# hamdy etal-2010-simulation based optimisation.txt
# harikrishnan-2011-Effect of.txt
# harper etal-2019-Assessing socially.txt
# Harrison and Jiang-2017-energy performance.txt
# hegazy and helmi-2020-Spatial monitorin.txt
# hegazy and qurnfulah-2020-Thermal comfo.txt
# hegazy etal-2017-The living building.txt
# hegazy etal-2017-Towards.txt
# hegazy-2020-Toward efficient energy con.txt
# hemmingway and long-2012-Thermal re.txt
# herdt etal-2016-Newly invented biobased.txt
# Hessami-2008-rural residential building.txt
# hormazabal etal-2016-The performance.txt
# hsieh and cheng-2020-Effects o.txt
# hu etal-2016-Removal of carbon dioxi.txt
# huang etal-2011-Design analysis of a F.txt
# huang etal-2020-Comparative investig.txt
# hui and ma-2016-Analysis of environmental.txt
# hundt and reddy-2011-Algal biodiesel product.txt
# hyde-2016-Development.txt
# Ibrahim etal-2009-analysis of sola.txt
# Ibrahim Rizk Hegazy-2020-nano aerogel glazing.txt
# igbum etal-2019-Feasibility stud.txt
# Igunnu etal-2012-Produced wate.txt
# ikedi etal-2016-Numerical asse.txt
# indartono etal-2016-Improving photovoltaics.txt
# inyang-2020-Reactive.txt
# ismail-2012-energy eff.txt
# ivanova-2014-3D analysis of the incident diffuse irradiance.txt
# iwaro etal-2014-An integrated approac.txt
# Iwaro etal-2014-assessment design.txt
# iwaro etal-2015-Validation of integrate.txt
# jahnke etal-2013-First cycle simulations of t.txt
# jain and hindoliya-2016-Energy saving.txt
# jan etal-2013-climate necessity.txt
# janchen etal-2012-Preparation, hydrot.txt
# jareemit and canyookt-2020-Residential.txt
# jarimi etal-2018-Materials characterizatio.txt
# jarimi etal-2018-Materials characterization.txt
# Jarimi etal-2018-solar thermal.txt
# jarimi etal-2020-Review of sustainable method.txt
# jasen and marchetti-2012-Kinetic study of.txt
# javed and fahlen-2011-Thermal response.txt
# JENKINS-2009-cooling loads.txt
# ji etal-2014-Approach of a solar buil.txt
# jian yao-2012-Effect.txt
# Jiang etal-2009-utilizing bent heat pipes.txt
# jiang etal-2010-solar thermosyphon systems.txt
# jiang etal-2012-Current development o.txt
# jiang etal-2013- Design and performan.txt
# john raftery-2009-Sustainable.txt
# Jorge and Armando C. Oliveira-2006-solar.txt
# Jorge etal-2008-cogeneration ORC system.txt
# jorge-2009-water absorption.txt
# jorge-2010-linear Fresnel.txt
# joshi etal-2010-Analysis of energy and exergy.txt
# jouhara-2009-wraparound.txt
# jradi and riffat-2012-Medium temper.txt
# jradi-2014-Micro scale ORC based.txt
# kalogirus-2013-Building integration.txt
# Kan and Hu-2015-composite building.txt
# kan etal-2009-Ecological.txt
# kan etal-2010-Exergoeconomic performance.txt
# Karlessi etal-2013-thermo.txt
# kartal-2013-Comparison.txt
# kasaeian etal-2017-Investigation of the eff.txt
# kepekci etal-2020- Three dimension.txt
# kesten etal-2010-daylight performance.txt
# Khaled Saleh-2008-Chilean climate.txt
# Khandelwal etal-2007-hybrid photovoltaic.txt
# khennich etal-2013-Comparison of combined.txt
# khodaee etal-2019-Assessment of the level.txt
# khoshbazan etal-2018-Thermo economic analy.txt
# khzouz etal-2011-Characterizatio.txt
# kilavuz and dogan-2020-Economic growt.txt
# Kim etal-2009-cooling effect and potable water.txt
# kim-2013-the investigation of an openi.txt
# kiyota etal-2013-Analysis of greenhouse gase.txt
# kizilors and aydin-2020-Effect of therm.txt
# kler etal-2010-combined technolo.txt
# klunne and michael-2010-Increasing.txt
# knez etal-2014-A sustainable transport.txt
# kokogiannakis-2012-Impact of material surface.txt
# kong-2020-Optimal.txt
# kosa-2020-Dynamic and steady.txt
# kumar and reddy-2012-energy exe.txt
# kumar etal-2019-A review status on alternativ.txt
# kumar etal-2020-The role of nanot.txt
# Lalzad-2013-desalination plant.txt
# Laseinde and Ramere-2018-vertical support.txt
# lau etal-2012-A preliminary study o.txt
# law etal-2013-heat pump and an organic Rankine.txt
# lazzarin and noro-2016-Energy efficiency.txt
# Lazzarin etal-2008-electronic expansion valves.txt
# Lazzarin etal-2013-annual air conditioning.txt
# lazzarin etal-2018-Hybrid PCM aluminium foa.txt
# Lazzarin-2007-absorption chillers.txt
# Lazzarin-2007-Solar cooling plants.txt
# lee etal-2013-high rise.txt
# lee etal-2013-Rooftop photovoltaic.txt
# Lee etal-2017-Cooling combinations.txt
# lee etal-2020-Experimental.txt
# lee etal-2020-Performance estimation.txt
# li and dai-2019-Energy.txt
# li and liang-2018-The economi.txt
# li and shuan-2020-Research on freq.txt
# li and yang-2010-Energy and exergy analysis.txt
# li and zhang-2020-Developing the tran.txt
# li and zhang-2020-Ecological efficiency.txt
# li etal-2010-hybrid solar electricity system.txt
# li etal-2012-Experimental study on the di.txt
# li etal-2016-feasible energy saving analysis.txt
# li etal-2016-Performance.txt
# li etal-2016-Thermal analysis.txt
# li etal-2019-Effect of design.txt
# li etal-2019-low power data.txt
# li-2020-Analysis on.txt
# lian etal-2016-Simultaneous synthes.txt
# liang and shi-2020-Efficiency evaluatio.txt
# liao and wang-2012-Performance based lo.txt
# lim etal-2013-Design config.txt
# lin etal-2011-Ammonia water absorption cycle.txt
# lin etal-2018-Experimental study on im.txt
# lin-2016-Stratum ventilation a low c.txt
# ling etal-2013-The numerical s.txt
# Lingen-2013-cycle.txt
# lisha etal-2018-Structural rec.txt
# Liu etal-2009-comparative study.txt
# liu etal-2010-domestic biomas.txt
# Ma etal-2008-microencapsulated phase.txt
# maciel etal-2013-The impact.txt
# madvar etal-2018-Analysis.txt
# Maheshwari etal-2009-performance analysis.txt
# maheshwari-2009-Performance.txt
# mahmood etal-2019-Energy.txt
# malakhov-2010-Economic.txt
# maleki-2018-Modeling and optimum design.txt
# man etal-2010-Operation.txt
# marchetti-2010-Production.txt
# markus-2013-Advanced.txt
# marquiz-2013-analysis.txt
# maslennikov etal-2010-Advanced.txt
# mattera etal-2018-Online Energy Simulator.txt
# mccarthy-2011-Comparison of the perfor.txt
# mehrabian-2010-wet heat exchangers.txt
# mempouo-2010-Cod.txt
# meng etal-2010-Effects.txt
# meng etal-2010-Multiobjective analyses.txt
# Michel Gueldry-2018-Climate.txt
# michelle-2013-A preliminary.txt
# mohamed-2011-Exploring.txt
# Mohammad etal-2020-wind farm.txt
# mohan -2011-Parametric.txt
# Mohan etal-2008-air cooled hydrogen storage.txt
# mohan-2009-The performance.txt
# mojahedi etal-2020-Designing p.txt
# Mojtaba-2018-natural.txt
# molero-2013-Towards.txt
# mortazavi etal-2019-Analysis.txt
# moustafa etal-2018-Roof geometry.txt
# Mudie etal-2013-comercial kitchen.txt
# mukherijee-2012-Estimation.txt
# mumith-2016-Design.txt
# Newton etal-2011-nanoparticle.txt
# niu etal-2010-Experimental study on a CO2.txt
# Noro and Lazzarin-2017-heat pump system.txt
# nwanya-2011-Climatechange.txt
# nygard-2012-Review.txt
# oleg-2010-autonomous energy systems.txt
# Oleivera-2007-towards a renewable future.txt
# oliveira-2016-Anovel.txt
# oliveira-2017-GHG.txt
# omar and shaari-2009-Sizing verification.txt
# ong-2011-Experimental.txt
# ong-2014-Reverseflow.txt
# ong-2016-Performance.txt
# ong-2016-Review.txt
# ONG-2016-Reviewofsolar.txt
# onyelowe-2019-Experimental.txt
# onyelowe-2019-Recycling.txt
# onyelowe-2019-Strength.txt
# opubo-2013-Ahigh.txt
# oralli-2011-study.txt
# orhan etal-2011-Exergy analysis of heat exchangers.txt
# ouelhazi-2020-Parametric.txt
# oyieke-2018-Interfacial.txt
# oyieke-2019-Multilayered.txt
# oyieke-2020-Experimental.txt
# paine-2018-Evaluating.txt
# pandey etal-2011-Experimental.txt
# papadak-2013-Aparametric.txt
# patodi-2012-Performance.txt
# petra etal-2010-advanced zero emission plant.txt
# petra-2010-advancedzero.txt
# pike and slater-2011-examination of their.txt
# pillai-2013-Study.txt
# pilpola-2019-Energy.txt
# poese-2013-Performance.txt
# Prabhakant etal-2009-Energy payback time.txt
# Prabhakant etal-2009-evaluation.txt
# qi-2020-EER.txt
# qingyang-2020-Energy.txt
# qiu-2012-Experimental.txt
# qiu-2018-Numerical.txt
# rabah etal-2013-Experimental study of the urban.txt
# rahbar-2016-miniature.txt
# raj-2020-Design.txt
# ramadan etal-2016-Analysis.txt
# ramezanizadeh-2019-Modeling.txt
# ranjan-2013-Economic.txt
# ranjan-2016-Energy.txt
# rao-2012-Thermodynamic.txt
# rao-2013-Analysis.txt
# ratlamwala-2012-Comparative.txt
# Rattanongphisat-2008-Thermal separation.txt
# reay-2013-are the process industries.txt
# reay-2015-Thermal energy storage.txt
# Reddy etal-2016-Nanofluid and nanocomposite.txt
# Reddy-2009-low carbon buildings.txt
# redpath-2014-evacuated.txt
# reinoso-2012-Study.txt
# renato etal-2009-Energetic.txt
# Renato etal-2013-life cy.txt
# Renato Lazzarin-2007-Technological innovations.txt
# Renzato etal-2007-system based on water.txt
# rezaei-2018-Applying.txt
# ricci etal-2014-development.txt
# riffat and qiu-2011-A review.txt
# Riffat etal-2007-direct ground coupled absorber.txt
# Riffat etal-2013-experimental investigation.txt
# Riffat etal-2013-thermodynamical cooling sys.txt
# riffat-2011-Areview.txt
# riffat-2017-Overview.txt
# rodrigues-2013-Anovel.txt
# rodrigues-2016-Investigating.txt
# rogers-2011-Hydrogen.txt
# rogers-2012-Yawanalysis.txt
# Rojas-2013-Atrium building design.txt
# Rosemann and Kaase-2013-combined daylight.txt
# rossi-2012-Ethanol.txt
# saad-2019-Numerical.txt
# sabitha-2011-global.txt
# safira-2020-Thermal.txt
# sahlot and riffat-2016-Desiccant cooling systems.txt
# sahu-2017-parametric.txt
# salman-2020-Thermal.txt
# sampedro etal-2016-Spanish.txt
# sandhu-2011-Investigations.txt
# Santamouris-2008-built environment.txt
# Santana-2020-wind glazing.txt
# sawant-2011-Performance.txt
# serran-2016-Rammed.txt
# shakouri-2020-Thermodynamic.txt
# shamsapour-2020-Developing.txt
# shang etal-2016-Hybrid hydrogen.txt
# shang-2020-Ruralecotourism.txt
# Shanmugapriya etal-2018-solar linear fresnel.txt
# shao etal-2015-Wireless Energy.txt
# shao-2019-Geological.txt
# shatat-2015-retrofitting.txt
# shatat-2016-innovativepsychometric.txt
# shattat-2012-Water.txt
# shen etal-2013-Simulating.txt
# Shilliday etal-2009-Comparative energy.txt
# shuai-2018-Whatdo.txt
# shusheng-2020-lattice.txt
# sicre-2015-High.txt
# sicre-2015-Highefficiency.txt
# soares etal-2018-Evaluation of the performance.txt
# soares etal-2018-Evaluation.txt
# Someren etal-2017-lighting performance.txt
# song-2013-Control.txt
# Song-2020-coal dust.txt
# spataru-2010-Domestic energy and occupancy.txt
# Spencer-2007-predicting light pipe transmittance.txt
# srinivas-2020-anal.txt
# srivastav etal-2009-energy.txt
# stafell-2011-Lower.txt
# steve-2011-Hydrogen.txt
# su etal-2010-feasibility.txt
# suetal-2018-Nanosilicon.txt
# sukarno-2020-Multistage.txt
# Sultan etal-2020-vfa.txt
# sun-2014-Existing.txt
# sun-2019-Investigation.txt
# Sun-2020-water shed water pollution.txt
# sunetal-2019-Study.txt
# symes-2013-enhanced.txt
# taha-2013-Meteorological.txt
# tamer-2013-Optimization.txt
# Tangka etal-2013-asorption solar.txt
# tantasavasdi-2020-Impact.txt
# tao etal-2009-congregation.txt
# tasi-2013-Control.txt
# teixeira-2010-Temperature.txt
# Tham etal-2009-clear sky radiation data.txt
# tham-2011-Energy.txt
# TiezhouWu etal-2020-coordinated control.txt
# tiwari-2019-Entrans.txt
# tolooiyan-2012-preliminary.txt
# trevor-2016-Design.txt
# tu-2020-Comparative.txt
# Tufail-2020-confined rubberized concrete.txt
# Utlu and Onal-2017-waste heat recovery.txt
# utlu-2019-Thermophotovoltaic.txt
# vadodaria-2012-Inuseenergy.txt
# Vakilabadi etal-2018-renewable power gen.txt
# valdiserri-2018-Evaluation.txt
# Varga etal-2009-cooling system.txt
# varga-2010-Comparison.txt
# varga-2013-Readdressing.txt
# varga-2017-Ontheselection.txt
# varo-2013-Design.txt
# Vasiliev etal-2008-activated carbon.txt
# Vasiliev etal-2009-efficiency of fuel cells.txt
# veselov-2010-Impact.txt
# victor-2013-loop heat.txt
# Vivek-2008-energy and exergy.txt
# Vivekh etal-2015-Desalination.txt
# wajid-2019-Review.txt
# walnum-2011-Offdesign.txt
# wang and chi-2011-A laboratory.txt
# wang etal-2010-intercooled.txt
# wang etal-2010-pyrolysis process of corn straw.txt
# Wang etal-2013-power and efficiency.txt
# Wang etal-2013-power and power density.txt
# wang etal-2020-equalization.txt
# wang etal-2020-Study on.txt
# wang-2014-Performanc.txt
# wang-2017-Microstructure.txt
# wang-2019-Performance.txt
# wangabdullah-2011-Investigating.txt
# wangetal-2012-Superhydrophobic.txt
# wangetal-2012-Thermal.txt
# wangetal-2013-Failure.txt
# wangetal-2014-Feasibility.txt
# wangetal-2019-Fault.txt
# wangetal-2019-Research.txt
# wangetal-2019-Study.txt
# wangetal-2020-Research.txt
# wangetal-2020-Sound.txt
# wei-2014-CatalyticCO2.txt
# whiffen-2012-Areview.txt
# whiffen-2012-review.txt
# wongwatcharapa-2019-filtrative.txt
# woo etal-2009-The performance.txt
# wood etal-2010-residential building.txt
# worall-2011-CO2compression.txt
# wu etal-2010-thermoacoustic refrigeration.txt
# wu etal-2011-Hydrogen.txt
# wu etal-2011-Prediction.txt
# wuetal-2018-Indoor.txt
# wuetal-2020-Application.txt
# wuxiong-2014-Passive.txt
# xia-2016-Endoreversible.txt
# xiaetal-2010-Ecological.txt
# xiang-2015-Optimization.txt
# xiao etal-2010-retrofitted direct gain solar house.txt
# xiao-2012-reactive.txt
# xie etal-2008-Syngas CO.txt
# yadav etal-2020-Sustainable.txt
# yadav-2012-On the suitability.txt
# yali-2014-Simulation.txt
# yan etal-2020-energy.txt
# yandri-2018-Uniformity.txt
# Yang and Yutong-2007-photovoltaic application.txt
# Yang etal-2013-ecobuilding.txt
# yang-2012-heat.txt
# yang-2012-Performance.txt
# yang-2020-policy.txt
# Yee Chow-2009-zero carbon targets.txt
# yi etal-2009-atriums in subtropical climate.txt
# Yolanda-2020-determining.txt
# you-2020-Influences.txt
# yu-2018-Theeconomic.txt
# Yuanlong etal-2020-heating systems for.txt
# zeinelabdein-2018-Free.txt
# zeng-2012-Problems.txt
# zhai-2016-Sensitivity.txt
# zhan-2010-Numerical.txt
# zhang etal-2010-performanc.txt
# zhang etal-2012-sordption.txt
# Zhang etal-2015-heat transfer of energy.txt
# Zhang etal-2016-indoor air thermal.txt
# Zhang etal-2017-liquid dessicant cycle.txt
# Zhang etal-2018-revolutio.txt
# zhang-2012-Enhanced Hea.txt
# Zhang-2020-reconfigurable equilibrium.txt
# zhang-2020-Res.txt
# zhangetal-2012-Gascleaning.txt
# zhangetal-2013-Theoretical.txt
# zhangetal-2017-Annual.txt
# zhangetal-2020-Capacity.txt
# zhangetal-2020-Discrete.txt
# Zhao etal-2008-power and gas cogeneration.txt
# zhao-2014-Calculations.txt
# zhaoetal-2009-Dynamic performance.txt
# Zheng-2018-solar.txt
# zhong-2019-Technology.txt
# zhou-2009-thermocapillary.txt
# zhou-2012-Research.txt
# zhou-2018-Optimization analyses.txt
# zhou-2020-Cross.txt
# zhu-2012-Asimulation.txt
# zhu-2016-Performance.txt
# zhu-2020-The influence.txt
# Zhuetal-2020-aerolastic.txt
# zishang-2012-Assessment.txt
# Zisisetal-2006-heat.txt
# Zurigat-2007-Typical.txt

# %%
len(word2vec_input)
# Out:
# 525882

# %%
## Here we build the vector space with Word2Vec

SentenceCorpus = word2vec_input
word2vec_output = Word2Vec(SentenceCorpus, min_count=1)

# %%
## Save vector space

word2vec_output.save('adap_threat_w2v_model.txt')

# %% [markdown]
# ## Section 3. Use the vector semantic map to evaluate if the bags of words created in section 1 are ecologically valid

# %%
###  funtion to use word2vec to inquiry about the 10 most similar semantically words to each seed word in word_list

def get_word2vec_list(word_list,model):

  list_of_word2vec_lists = []
  for word in word_list:
    try:

      ## here is the crucial line - we are using the model that we trained to get the most similar words within our corpus
      list_vects=model.wv.most_similar([word],topn=10)

      new_list = []
      new_list +=[word]
      for item in list_vects:
        word1 = item[0]
        new_list += [word1]

      #print(new_list)
      #print('\n')
      list_of_word2vec_lists += [new_list]


    
    except KeyError:
      continue
  return(list_of_word2vec_lists)

# %%
## open vector space for english in the early modern period
model = Word2Vec.load('adap_threat_w2v_model.txt')

# %%
## get word2vec list of 10 most similar words for the climate bag of words

list_of_adaptation_w2v = get_word2vec_list(adaptation_list,model)

index =0
for w2v_list in list_of_adaptation_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['abide', 'flare-out', 'Bhaduri', 'deadlines—and', 'scholarship', '2031–2032', '5400', 'conservatives', 'managed', 'facility-level', 'displaced']
# 1 ['abutment', 'Evaporating', 'lift', '(Pa)', '(Pa),', '(8C)', 'frictional', '(kJ/kg)', 'allowable', '24.6', '[Pa]']
# 2 ['accept', 'encourage', 'consequences,', 'attract', 'express', 'consumers’', 'Poor', 'inbound', 'minister', 'trigger', 'ultimately']
# 3 ['acclimation', 'Payback', 'Apr.', 'CM', '(node', '(days,', '\x0cA.K.', '+2.0', 'inactivity', 'Mesh', '31.9']
# 4 ['acclimatisation', 'pouring', 'sleeve', 'upkeep,', '0.995', 'axi-symmetry', 'A/L,', 'created,', '‘classify’', '86.02,', '900;']
# 5 ['accountability', 'single-', 'HGHEs', 'shoreline', 'timing', 'geotechnics', 'emergencies', 'typology', 'background', 'nanopower', '4.22%']
# 6 ['adaptation', 'planning', 'sustainability', 'regional', 'practices', 'policies', 'risks', 'mitigation', 'SLR', 'health', 'long-term']
# 7 ['adaption', 'Less-progressive', 'zoning', 'Coronavirus', 'ethanol;', 'operators', 'Poor', 'regional,', 'aquatic', 'regulations,', 'cultural']
# 8 ['adherence', 'biodiesel,', 'actors', 'similarly', 'Just', 'bioboards', 'first,', 'SNG', 'pretreatment', 'people,', 'engineers']
# 9 ['adhesion', 'rubberized', '#2', 'Craig,', '(109', '(black', 'Fong,', 'Haroun', 'Palaeoclimatology,', 'Cavity', 'Vegetation']
# 10 ['adjustment', 'complexity', 'limiting', 'failure', 'reliability', 'identification', 'computing', 'privacy', 'limits', 'institutional', 'action']
# 11 ['administration', '‘Sustainable', 'Union’s', 'HEROTILE', 'companies.', 'Conversion,', 'policies.', '2011;36:3224–32.', 'Swiss', 'Britain,', '(Non']
# 12 ['advance', 'willingness', 'commitment', 'damages', 'innovation', 'engage', 'invest', 'ecosystems', 'strengthen', 'adaption', 'participate']
# 13 ['advocacy', '(SDCS)', 'Mx', 'attracted', 'Linacre', 'commercialized,', 'device-level', 'undergone', 'tremendous', 'game.', 'pledged']
# 14 ['affirm', 'summarises', '16],', 'lists', 'herein,', 'experimental,', 'questions,', 'summarizes', 'performances:', 'correctness', 'elastic–plastic']
# 15 ['aid', 'extend', 'assist', 'replace', 'examine', 'facilitate', 'establish', 'respond', 'modify', 'explore', 'alter']
# 16 ['anchor', 'Practising', '‘end-of-frame’', 'inactive', 'arbitrary', 'amphoteric', 'approximate', 'exclusive', 'odorless', 'regenerative,', 'eventual']
# 17 ['approval', 'governmental', 'humanity', 'weaknesses', 'conflict', 'manufacturers', 'reinforcement', 'constipation,', 'reversed', 'itself.', 'feedstock']
# 18 ['approving', 'visible;', 'exemplum,', 'explosion;', 'impenetrable', 'ideologue.', 'pragmatist', '\uf8f2C', '1026m3/r,', 'ObepME:', 'emblem']
# 19 ['assist', 'help', 'extend', 'continue', 'promote', 'alter', 'aid', 'invest', 'expand', 'exacerbate', 'go']
# 20 ['assurance', 'satisfaction,', '\x0cAssessment', 'konjac', 'sulfone)', 'constitutive', 'Wood,', 'conservatives’', 'Engine', 'minorities,', 'Filtration']
# 21 ['attachment', 'Spectrum', 'Centrality', 'CONICET),', 'AlN,', '17/07', 'Consultants.', 'Alexandra', '54.92', 'PP,', 'Methodological']
# 22 ['authorization', 'enacted', 'interviews', 'graduate', 'excluded', 'computers', 'personal', 'blending', 'discarded', 'errors,', 'filtered']
# 23 ['back', 'down', 'bottom', 'chamber', 'top', 'right', 'wick', 'outside', 'mixing', 'surrounding', 'goes']
# 24 ['backbone', 'explanation', 'kind', 'purpose', 'idea', 'choice', 'goal', 'semi-solid', 'creation', 'necessity', 'scope']
# 25 ['backing', 'titanates', '(such', '(Mn)', 'DSP', 'we,', 'CALP-NC).', 'flowable', 'and10%', 'possible,', 'well,']
# 26 ['base', 'reference', 'same', 'variable', 'working', 'measurement', 'basic', 'fixed', 'domain', 'reactor', 'single']
# 27 ['basement', '“not', 'frequencies', 'E_saved', '(relatively', 'þ208C', 'UW-L.', '+0.38C', 'interface,', 'regular', 'tÞ1=2']
# 28 ['bear', 'express', 'choose', 'inform', 'extend', 'encourage', 'realize', 'expand', 'sustain', 'adopt', 'undertake']
# 29 ['bench', 'set-up', 'setup.', 'rig.', 'model:', 'strain,', 'well-accredited', 'MRRs', 'threedimensional', 'study:', 'Zeolite/water']
# 30 ['block', 'type,', 'double', 'bank', 'deep', 'sand', 'bed', 'material,', 'hydraulic', 'shallow', 'cylinder']
# 31 ['boost', 'minimize', 'optimise', 'respond', 'regulate', 'maximize', 'monitor', 'begin', 'adapt', 'modernize', 'switch']
# 32 ['brace', 'adaptation."', 'irrigated', 'neglected,', 'category,', 'while,', 'financially', 'peninsulas', 'SRC', 'Potentiality', 'utilised']
# 33 ['bracket', '0.93359,', 'contradictory', 'respected.', 'reported.', 'Vconc,c', 'polyurethane-segmented', '5.4,', 'Pigments', 'Recuperators', 'women']
# 34 ['brass', 'Wafers', '(manufactured', 'ashes', 'sandy', 'processed', 'Samples', 'powders', 'Omega', '(doors', 'metered']
# 35 ['break', '44%', 'regular', 'grow', '248C', 'SAS', '36.52%', 'þ208C', 'frequencies', 'g·s−1', 'root']
# 36 ['carry', 'find', 'phased', 'heat/', 'carrying', 'try', 'triplicates', 'perform', 'carried', 'incorporate', 'figured']
# 37 ['champion', 'folds,', 'Alternately,', 'mn', '1:07', '(WCI)', '1^k2', 'uj', '~700', 'Wibert', 'mNCS']
# 38 ['change', 'change,', 'changes', 'change.', 'transition', 'rise', 'changing', 'overheating', 'negative', 'global', 'aviation’s']
# 39 ['conducting', 'dispersion', 'HGHE', 'stratified', 'discrete', 'geotechnics', 'selecting', 'motion', 'simulating', 'cavity,', 'computation']
# 40 ['confirm', 'reveal', 'highlight', 'demonstrate', 'verify', 'illustrate', 'finds', 'plans,', 'believe', 'specify', 'suggest']
# 41 ['corroborate', '90.8%.', 'excellent,', 'underline', 'pointed', 'EED,', 'follow-up', 'confirm', 'optimized.', 'suggest', 'predisposed']
# 42 ['cut', 'offset', 'equating', 'adjusted', 'initially', 'filtered', 'changed', '22%', 'decarbonise', 'grow', 'partially']
# 43 ['defend', 'moral', 'infrastructural', 'halogenated', 'regimes,', 'siliceous', 'Willingness', 'aromatic', 'waxes,', 'decisional', 'Mormann']
# 44 ['demand', 'requirement', 'demands', 'consumption', 'requirements', 'loads', 'prices', 'saving', 'usage', 'supply', 'price']
# 45 ['demonstrate', 'reveal', 'highlight', 'illustrate', 'explain', 'confirm', 'verify', 'relate', 'consider', 'ensure', 'suggest']
# 46 ['dependability', 'conservation.', 'balance,', 'demolition:', 'balance.', 'Net-zero', 'bottleneck', '[116].', 'embodied', 'meters:', 'Lehmanna']
# 47 ['detoxification', 'thereby,', 'Low-emission', 'pollutants,', 'breathing,', 'polluters,', 'hot/cold', 'behaviors,', 'infiltration.', 'Excess', 'beverage']
# 48 ['differentiation', 'glazings', 'links', 'relationships', 'joints', 'link', 'theme.', 'discontinuities', 'narrowed', 'relations', 'comparator']
# 49 ['direction', 'channel', 'direction,', 'region', 'middle', 'bottom', 'path', 'velocity', 'front', 'position', 'section']
# 50 ['disposal', 'waste,', 'recycling', 'raising', 'pre-treatment', 'demolition', 'liquefaction', 'biodiversity', 'products,', 'goods', 'bioenergy']
# 51 ['document', 'topology', 'bases', 'hypothesis', 'website.', 'Multi-Annual', 'calling', 'Italy).', 'framework.', 'language', 'examination']
# 52 ['documentation', '\uf0fc', 'Perspective', 'Jornal', 'DDR', 'Barry', 'three-part', 'Bibliotheca', 'supervised', 'article.)', '\x0cSustainable']
# 53 ['duty', 'pump,', 'capacity,', 'load,', 'heat-pump', 'capacity.', 'regenerative', 'loads,', 'simultaneous', 'Two-stage', 'minimization,']
# 54 ['empowerment', 'broadcasts', 'Azerbayejan', 'component’s', '95,', 'ASTMD', 'for)', 'feeling', 'Umuahia–Owerri', 'founding', 'parks,']
# 55 ['encourage', 'address', 'express', 'inform', 'enable', 'discuss', 'implement', 'accept', 'consequences,', 'reinforce', 'attract']
# 56 ['endorse', 'educate', '[10])', 'wanted', 'emphasize', 'Menzel', 'later.', '(2018)', 'optimally', 'pragmatic', 'encouragement']
# 57 ['endorsement', 'MFI', 'Silvertop', 'ARPA-E', 'exploratorium', '‘act', 'followed', 'accompanied', 'town)', 'auditorium', 'Wearcheck']
# 58 ['endure', 'withstand', 'cause', 'alleviate', 'attain', 'eliminate', 'reach', 'raise', 'resist', 'modify', 'relieve']
# 59 ['establish', 'examine', 'identify', 'explore', 'facilitate', 'select', 'describe', 'address', 'implement', 'define', 'understand']
# 60 ['establishment', 'creation', 'reconstruction', 'temporary', 'background', 'definitions', 'specification', 'biodiversity.', 'necessity', 'settlement', 'FAME']
# 61 ['executive', 'US.', 'Volatility', 'France', 'Bangkok', 'Los', 'Hypothesis', 'Riyadh,', 'Singapore', 'Greece', 'Pakistan']
# 62 ['fault', 'defining', 'planning,', 'institutional', 'ideas', 'MLG', 'dimensions.', 'acknowledging', 'precise', 'geotechnics', 'implementable']
# 63 ['finance', 'Guangdong,', 'FCH', 'anticipation', 'stimulation', 'Cancer', 'JU', 'reforestation', 'Shamirpet-Keesara', 'my', 'Premium']
# 64 ['foot', '(2005).', '1.44', 'Ni/Al2O3,', 'hours;', '90,', '21:00', 'Gambettola', 'capitalism,', 'Heft', 'Ouest,']
# 65 ['foundation', 'admixture', 'pavement', 'metaphor', 'supporting', 'library', 'high-density', 'cancer', 'object', 'ecofriendly', 'defining']
# 66 ['frequent', 'intense', 'prominent', 'severe', 'prevalent', 'room,', 'space,', 'flexible', 'immediate', 'frequently', 'WSM,']
# 67 ['fund', 'financing', 'Metropolis,', 'legislation,', 'cultural', 'funds', 'agencies,', 'foreign', 'Tariff', 'communities,', 'regional,']
# 68 ['funding', 'programme', 'Italian', 'Government', 'States', 'university', 'students', 'project,', 'USA', 'Scottish', 'Federal']
# 69 ['further', 'also', 'how', 'what', 'whether', 'problem', 'our', 'general', 'political', 'best', 'long-term']
# 70 ['governance', 'institutional', 'practices', 'barriers', 'considerations', 'SLR', 'initiatives', 'mechanisms', 'spatial', 'acceptability', 'theories']
# 71 ['governing', 'equations.', 'domain.', 'describing', 'equations,', 'solving', 'nonlinear', 'aforementioned', 'expressions', 'equations', 'weights']
# 72 ['government', 'community', 'policy', 'financial', 'actions', 'policies', 'national', 'public', 'international', 'future', 'CCS']
# 73 ['groundwork', 'force)', '(De', '3083', 'anticipatory', 'Almeria', 'Dinar', 'principles.', 'Copolymer', '(Cameron', 'Dakwale']
# 74 ['guarantee', 'realize', 'enable', 'sustain', 'ensure', 'bring', 'prove', 'maximize', 'lead', 'add', 'correspond']
# 75 ['guidance', 'economic,', 'advice', 'ideas', 'SLR', 'promotion', 'engineers', 'cultural', 'reconstruction', 'architects', 'guidelines']
# 76 ['handling', 'purification', 'dehumidification.', 'conditioning', 'cleaning', 'quality,', 'ventilating', 'conditioning,', 'refrigeration,', '(0.44', 'pest']
# 77 ['hanging', '3.84', 'flat,', 'Brazil’s', 'Secular,', '36.50', 'guide.', 'Mahmood4', 'Included', 'Rue', 'interval:']
# 78 ['help', 'assist', 'promote', 'effectively', 'address', 'enable', 'implement', 'make', 'improve', 'alleviate', 'alter']
# 79 ['hold', 'modify', 'migrate', 'barriers', 'strengthen', 'lose', 'alter', 'possibly', 'ecosystems', 'face', 'catch']
# 80 ['imperative', 'essential', 'urgent', 'unlikely', 'convenient', 'desirable', 'hard', 'beneficial', 'interesting', 'preferable', 'impossible']
# 81 ['insurance', 'taxes', 'tenants', 'expenditure', 'agreements', 'national,', 'enterprises', 'CSH', 'buses', 'Turkey', 'repair']
# 82 ['interference', 'insulation;', 'raising', 'Furniture,', 'machine,', 'uncemented', 'hydrophobic', 'ocean', 'wetlands,', 'relocation', 'vibration']
# 83 ['interposition', 'sub-channel', 'July;', 'format', 'surface;', 'encapsulated', 'vane', 'melt,', '\x0cComposites', 'pitched', 'self–healing']
# 84 ['intervention', 'riots', 'advancing', 'broken', 'your', 'planting', 'citizens', 'fungal', 'COVID-19', 'administrative', 'Coronavirus']
# 85 ['job', 'pressing', 'strategic', 'actors', 'CC', 'consumers’', 'HA2', 'Americans', '“a', 'politics', 'shaping']
# 86 ['judiciary', 'Coffee', 'animal', 'Katherine', 'Gas.', '(Al-Ismaily', '(Sullivan', 'Giridharan3', 'Realism,', 'Challenges', 'shelter-in-place']
# 87 ['jump', '(he)', 'Vertical', 'Design.]', 'meanings)', 'land-water', 'hierarchies.', 'secondly,', 'transcendent,', '(IMLDD).', '(North)']
# 88 ['justify', 'illuminate', 'contribute', 'incorporate', 'apply', 'consider', 'prior', 'owing', 'avoid', 'protect', 'adapt']
# 89 ['keeping', 'decreased,', 'lateral', 'reaching', 'failure', 'levels,', 'lowsensitive', 'changing', 'Cicchitti', 'downstream', 'immediately']
# 90 ['leap', 'LnCO2', 'spectroscopy.', 'he', 'regular', 'completion', 'once', 'quick', 'again,', 'k–ω', '=2ðt2']
# 91 ['legislation', 'achievements', 'consequences', 'concerns', 'SLR', 'authorities', 'citizens', 'universities', 'economic,', 'society', 'residents']
# 92 ['maintenance', 'investment', 'capital', 'costs,', 'cost,', 'life,', 'reliability', 'services', 'safety', 'costs', 'service']
# 93 ['management', 'transportation', 'strategies', 'mitigation', 'clean', 'implementation', 'existing', 'planning', 'security', 'manufacturing', 'sustainability']
# 94 ['mediation', '‘Formulation', 'inferences', 'Sahinidis', 'Kurt', 'Perturb', 'LII.', 'detection', 'Socialism.', '“Holocene', 'Reinhard']
# 95 ['mismanagement', 'hierachy', '(wood', 'brasileiras.”', '(Mahmood', 'Notable', 'micro/nano', 'Geopolitics', '294', 'Out', '1/2–']
# 96 ['obligation', 'grooves', 'electrodeposited', 'etching', 'https://academic.oup.com/ijlct/article/16/2/518/5998677', 'bought', 'lignin', 'flowthrough', 'MSS', 'Atmosphere', 'Appliance']
# 97 ['organisation', 'conjunction', 'accordance', 'places', 'collaboration', 'gaps', 'reacts', 'pro-', 'Assembly)', 'partnership', 'react']
# 98 ['organization', 'ecofriendly', 'council', 'territory', 'Lanka', 'accommodation', 'Guangxi', 'village', 'language', 'member', 'Plans']
# 99 ['oversight', 'suggest', 'revealed', 'indicate', 'Note', 'daggers', 'ide', 'defied', 'noticing', 'indicated', 'electricity-related']
# 100 ['pay', 'sell', 'continue', 'lose', 'add', 'cater', 'implement', 'accelerate', 'compensate', 'save', 'fulfill']
# 101 ['pitch', 'spacing', '1.8', 'width', 'diameter,', 'length,', 'red', 'diameter', '0.25', 'diameters', 'pitches']
# 102 ['pole', 'Expectations', 'humans', 'corrupt,', 'Openings', '2011)', '‘puffed-up', 'adopted,', 'met,', 'Council)', 'You']
# 103 ['policy', 'future', 'policies', 'planning', 'sustainability', 'community', 'social', 'security', 'economy', 'government', 'measures']
# 104 ['prerequisite', 'choice', 'explanation', 'option', 'plan', 'issue', 'framework', 'reasons.', 'scheme', 'idea', 'object']
# 105 ['promote', 'enable', 'address', 'implement', 'encourage', 'facilitate', 'contribute', 'alleviate', 'create', 'manage', 'reflect']
# 106 ['prove', 'introduce', 'implement', 'explain', 'overcome', 'alter', 'encourage', 'consider', 'apply', 'reflect', 'realize']
# 107 ['provide', 'allow', 'produce', 'create', 'achieve', 'give', 'perform', 'make', 'meet', 'get', 'require']
# 108 ['province', 'Hefei', 'category', 'village', 'Jiangsu', 'Guangxi', 'mother', 'Trinidad', 'organization', 'council', 'Los']
# 109 ['reassurance', 'delight', 'polarization,', 'dung', 'gender', 'USDOE’s', 'Septum', '£31', 'TDS,', 'toxic,', 'COPth,']
# 110 ['reliability', 'life,', 'complexity', 'durability', 'limits', 'adjustment', 'functionality', 'risk', 'acceptability', 'maintenance', 'flexibility']
# 111 ['remove', 'absorb', 'recover', 'disperse', 'prevent', 'evaporate', 'extract', 'enter', 'retain', 'dehumidify', 'protect']
# 112 ['requirement', 'demand', 'demands', 'requirements', 'consumption', 'district', 'usage', 'saving', 'loads', 'producing', 'required']
# 113 ['responsibility', 'applicability', 'economic,', 'prospect', 'regulatory', 'willingness', 'brain', 'shoreline', 'guiding', 'Gulf', 'Omani']
# 114 ['scaffold', 'ceramic', 'coated', 'Fe2O3', 'inverted', 'films', 'foil', 'super-hydrophobic', 'Cu-con', 'PTFE', '\x0cReconfigurable']
# 115 ['second', 'third', 'first', 'step', 'stage', 'location', 'term', 'calculation', 'whole', 'stage,', 'final']
# 116 ['shift', 'decline', 'rise', 'separator', 'trace', 'jet', '8%', 'transition', 'draw', 'delay', 'extending']
# 117 ['shifting', '1.9,', 'Crime', 'immediately', 'growing,', 'exceeding', 'age,', 'takeaway', 'pipeline', 'moves', '565']
# 118 ['shop', 'A)', 'doors,', 'LUMO', 'diluents', 'Ib', 'polystyrene', 'rc', 'inflicted', 'sheet,', '(bacteria']
# 119 ['shore', '‘extended', 'zone’', 'decrease,', 'eventual', 'HA', 'inactive', 'increase,', 'actually', 'leave', 'weigh']
# 120 ['show', 'indicate', 'showed', 'suggest', 'indicated', 'shows', 'showing', 'illustrate', 'reveal', 'demonstrate', 'demonstrates']
# 121 ['shunt', 'k)', 'com', 'lef', 'sh', '/s', '(W', '\uf8f8', 'sabs', 'L1', '\x03I']
# 122 ['sponsor', '(FP7/2007-2013),', 'MOE', '(RPS)', 'dark', '(DF228-137-1441).', 'Secretariate', '16-years-of-age', 'alluviation', 'ahistorical', 'contract']
# 123 ['sponsorship', 'Nations', 'Regional', 'Finance', 'Bank', 'Food', 'Fund.', 'United', 'Directive', 'Protection', 'U.S.']
# 124 ['stand', 'Potentiality', 'HCl,', 'SRC', 'two-and-a-half', 'while,', 'Liable', 'roads', 'PCR', 'preparing', 'synthesis,']
# 125 ['steering', 'systems/back-up', '2009;37:2498-504.', '[1–12].', 'injectors,', '“[The', 'fan-motor', 'Jew’s]', 'generation—a', '“effortlessly', '1.1-kWe']
# 126 ['stir', 'big', '“UW-L', '(0.1–3', '"Unquestionably', 'become', 'TRI', 'quiet', 'Mankind', 'tremendous', 'Imagine']
# 127 ['subscribe', 'Serfdom', '$3.5', 'Coming', '308310', 'quantitatively,', 'Democracy.', 'mass-dimensional', '1600%', 'Tends', '87.2%.']
# 128 ['subsidize', 'restructured', 'smartphone', 'are:', 'buildings;', '\x0cSpanish', 'solutions.', 'integration:', 'Identifying', 'leasing', 'activities,']
# 129 ['substantiate', 'pubs', 'AHU,', 'Kilavi', 'sold,', 'reserves—hype', '(63),', '23.0◦', 'cooling—these', 'UV-C', 'securitization.']
# 130 ['suffer', 'deviate', 'arise', 'come', 'pieced', 'Apart', 'learn', 'apart', 'arising', 'process—adapted', 'Unconfirmed']
# 131 ['supervising', 'chimney;', 'stills,', 'à', 'free-standing', 'lens;', 'Incident', 'slope;', 'forecasts.', 'pistachios', 'Midday']
# 132 ['supervision', 'economic,', 'legislation', 'colleges', 'attitudes', 'academic', 'government’s', 'funds', 'authorities', 'Ilorin', 'evolving']
# 133 ['support', 'financial', 'existing', 'planning', 'international', 'policy', 'suggestions', 'government', 'individual', 'search', 'experience']
# 134 ['supporting', 'governmental', 'shaping', 'geotechnics', 'pavement', 'CSPM', 'addressing', 'responsibility', 'consciousness', 'landscape', 'Second,']
# 135 ['surf', '16th,', 'Walnum*,', '‘free-rider', 'Vanoli2', 'migration)', 'CaCl2,', '−hh,out', 'administration.', 'Guy,', 'says.']
# 136 ['suspension', 'trioctylamine', '(PBA)', 'HSHX', 'coconut', 'potassium', 'butanol', 'n/a', 'admixture', 'ammonium', 'triglycerides']
# 137 ['sustain', 'address', 'overcome', 'modify', 'adopt', 'extend', 'enable', 'avoid', 'encourage', 'inform', 'resist']
# 138 ['switch', 'begin', 'respond', 'adjust', 'talk', 'Cradle', 'stabilize', 'catch', 'revert', 'expand', 'track']
# 139 ['tilt', 'inclination', 'angle', 'angles', 'plane', 'north-south', 'incidence', 'slope', 'rolling', 'axis', 'incident']
# 140 ['tolerate', 'politicized', '(308C),', 'Stipulations', 'Russians', '(jet', 'cause', 'be.', 'lamps)', 'UV-intensity', 'Miliband']
# 141 ['transfer', 'exchange', 'dissipation', 'conduction', 'diffusion', 'loss', 'heat-transfer', 'extraction', 'exchanger', 'leakage', 'friction']
# 142 ['transition', 'change,', 'narrow', 'solidification', 'chamber,', 'barrier', 'phase-change', 'change.', 'body', 'trench.', 'flame']
# 143 ['treatment', 'management', 'transportation', 'desalination', 'processes', 'use', 'planning', 'jet', 'existing', 'application', 'producing']
# 144 ['underpin', 'interests)', 'wrote', 'Alpha', '2500)', 'affirms', '(Labsphere', 'DRA', 'Molecules', '(2009)', 'recognised']
# 145 ['validate', 'verify', 'simplify', 'analyse', 'describe', 'examine', 'compute', 'undertake', 'interpret', 'analyze', 'characterize']
# 146 ['verify', 'validate', 'analyse', 'examine', 'simplify', 'describe', 'establish', 'analyze', 'characterize', 'illustrate', 'evaluate']
# 147 ['warrant', 'confer', 'relates', 'motivate', 'climate-friendly', 'specify', 'initiate', 'compress', 'amounting', 'wants', 'WHO']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with climate

relevant_adaptation_w2v_words = list( list_of_adaptation_w2v[i] for i in [0,3,4,5,6,8,10,15,19,28,31,32,43,46,47,55,58,70,71,76,78,82,92,93,103,105,116,133,134,137,140,142])
                                     
## Add all the words into one final bags of words
adaptation_BoW = [item for sublist in relevant_adaptation_w2v_words for item in sublist]

print(adaptation_BoW)
# Out:
# ['abide', 'flare-out', 'Bhaduri', 'deadlines—and', 'scholarship', '2031–2032', '5400', 'conservatives', 'managed', 'facility-level', 'displaced', 'acclimation', 'Payback', 'Apr.', 'CM', '(node', '(days,', '\x0cA.K.', '+2.0', 'inactivity', 'Mesh', '31.9', 'acclimatisation', 'pouring', 'sleeve', 'upkeep,', '0.995', 'axi-symmetry', 'A/L,', 'created,', '‘classify’', '86.02,', '900;', 'accountability', 'single-', 'HGHEs', 'shoreline', 'timing', 'geotechnics', 'emergencies', 'typology', 'background', 'nanopower', '4.22%', 'adaptation', 'planning', 'sustainability', 'regional', 'practices', 'policies', 'risks', 'mitigation', 'SLR', 'health', 'long-term', 'adherence', 'biodiesel,', 'actors', 'similarly', 'Just', 'bioboards', 'first,', 'SNG', 'pretreatment', 'people,', 'engineers', 'adjustment', 'complexity', 'limiting', 'failure', 'reliability', 'identification', 'computing', 'privacy', 'limits', 'institutional', 'action', 'aid', 'extend', 'assist', 'replace', 'examine', 'facilitate', 'establish', 'respond', 'modify', 'explore', 'alter', 'assist', 'help', 'extend', 'continue', 'promote', 'alter', 'aid', 'invest', 'expand', 'exacerbate', 'go', 'bear', 'express', 'choose', 'inform', 'extend', 'encourage', 'realize', 'expand', 'sustain', 'adopt', 'undertake', 'boost', 'minimize', 'optimise', 'respond', 'regulate', 'maximize', 'monitor', 'begin', 'adapt', 'modernize', 'switch', 'brace', 'adaptation."', 'irrigated', 'neglected,', 'category,', 'while,', 'financially', 'peninsulas', 'SRC', 'Potentiality', 'utilised', 'defend', 'moral', 'infrastructural', 'halogenated', 'regimes,', 'siliceous', 'Willingness', 'aromatic', 'waxes,', 'decisional', 'Mormann', 'dependability', 'conservation.', 'balance,', 'demolition:', 'balance.', 'Net-zero', 'bottleneck', '[116].', 'embodied', 'meters:', 'Lehmanna', 'detoxification', 'thereby,', 'Low-emission', 'pollutants,', 'breathing,', 'polluters,', 'hot/cold', 'behaviors,', 'infiltration.', 'Excess', 'beverage', 'encourage', 'address', 'express', 'inform', 'enable', 'discuss', 'implement', 'accept', 'consequences,', 'reinforce', 'attract', 'endure', 'withstand', 'cause', 'alleviate', 'attain', 'eliminate', 'reach', 'raise', 'resist', 'modify', 'relieve', 'governance', 'institutional', 'practices', 'barriers', 'considerations', 'SLR', 'initiatives', 'mechanisms', 'spatial', 'acceptability', 'theories', 'governing', 'equations.', 'domain.', 'describing', 'equations,', 'solving', 'nonlinear', 'aforementioned', 'expressions', 'equations', 'weights', 'handling', 'purification', 'dehumidification.', 'conditioning', 'cleaning', 'quality,', 'ventilating', 'conditioning,', 'refrigeration,', '(0.44', 'pest', 'help', 'assist', 'promote', 'effectively', 'address', 'enable', 'implement', 'make', 'improve', 'alleviate', 'alter', 'interference', 'insulation;', 'raising', 'Furniture,', 'machine,', 'uncemented', 'hydrophobic', 'ocean', 'wetlands,', 'relocation', 'vibration', 'maintenance', 'investment', 'capital', 'costs,', 'cost,', 'life,', 'reliability', 'services', 'safety', 'costs', 'service', 'management', 'transportation', 'strategies', 'mitigation', 'clean', 'implementation', 'existing', 'planning', 'security', 'manufacturing', 'sustainability', 'policy', 'future', 'policies', 'planning', 'sustainability', 'community', 'social', 'security', 'economy', 'government', 'measures', 'promote', 'enable', 'address', 'implement', 'encourage', 'facilitate', 'contribute', 'alleviate', 'create', 'manage', 'reflect', 'shift', 'decline', 'rise', 'separator', 'trace', 'jet', '8%', 'transition', 'draw', 'delay', 'extending', 'support', 'financial', 'existing', 'planning', 'international', 'policy', 'suggestions', 'government', 'individual', 'search', 'experience', 'supporting', 'governmental', 'shaping', 'geotechnics', 'pavement', 'CSPM', 'addressing', 'responsibility', 'consciousness', 'landscape', 'Second,', 'sustain', 'address', 'overcome', 'modify', 'adopt', 'extend', 'enable', 'avoid', 'encourage', 'inform', 'resist', 'tolerate ...

# %%
## get word2vec words for authoritarianism

list_of_threat_w2v = get_word2vec_list(threat_list,model)

index =0
for w2v_list in list_of_threat_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['alarm', 'EEV,', 'inactive', 'nanoreactor', '‘hydrogen', 'cellulose-bounded', 'innocent', 'illusion', 'five-day', 'underestimation', 'Summits']
# 1 ['approach', 'technique', 'method', 'algorithm', 'framework', 'methodology', 'tool', 'strategy', 'concept', 'problem', 'procedure']
# 2 ['assault', 'Essay', 'invoke', 'organism.3', '“Reflections', '(tH1)', 'all-silica', 'moiety', '(TR)', 'Volpe', '‘Research']
# 3 ['attack', '(TA,', '\x0cM.H.', 'beliefs', 'sexual', 'Rigby.', 'vastly', 'southeastern', 'age,', 'famines,', 'Zirconia']
# 4 ['attempt', 'effort', 'Analogous', 'opportunity', 'organism,', 'unexpected', 'answer', 'intuitive', 'deciding', 'H-pot', 'in-house']
# 5 ['avenue', 'party', 'Partnerships.', 'route', 'definite', 'versatile', '300L', 'metaphor', 'stepped', 'philosophical', 'HCFCs.']
# 6 ['bite', 'furnace', 'extractor', 'RFID', 'ideal', 'infinite', 'enclosure', 'massing,', 'ejector,', 'indirect', 'tenant']
# 7 ['blame', 'Discussion', 'Essays', '\x0cResearch', '“Next', 'Potential),', 'Rican', '(Tarrow', 'Globalization.', 'Rhodic', 'Lanham,']
# 8 ['bleeding', 'discouraged', 'formalin', '(Reprinted', 'preservative)', 'delegated', 'permission', '1955', 'spacers)', '7849', 'e-mail']
# 9 ['break', '44%', 'regular', 'grow', '248C', 'SAS', '36.52%', 'þ208C', 'frequencies', 'g·s−1', 'root']
# 10 ['bump', 'grouting', '£500/m2,', 'lab-scaled', 'divert', 'Experimentally', 'nomads)', 'owner,', 'insulate', 'herein,', 'mist/fog']
# 11 ['burn', 'Easy', 'xylose,', 'combustion,', 'restrictions,', 'induce', 'feeding', '(5980.0', '(reduced', '(Wmc)', 'credit)']
# 12 ['case', 'present', 'scenario', 'cases', 'view', 'reference', 'group', 'cases,', 'case.', 'comparison', 'basic']
# 13 ['causation', 'touted', 'bone', '3-((3-acetylphenyl)imino)indolin-2-one', '“Security', '(rated', '(NWTA)', 'NNC', 'Tanzania', 'BAF', 'Cason']
# 14 ['causing', 'effect,', 'thereby', 'causes', 'ignition', 'leading', 'content,', '(or', 'and/or', 'allowing', 'excessive']
# 15 ['caution', 'dealing', 'comply', 'comingled', 'u).', 'laden', 'contrasted', 'N2O.', 'diets,', 'interbreeding', '"Siding']
# 16 ['chance', 'threat', 'seriously', 'something', 'possibility', 'shares', 'hence,', 'damage', 'ability', 'capability', 'face']
# 17 ['charge', 'discharge', 'charging', 'primary', 'compressor', 'discharging', 'final', 'battery', 'heat-pump', 'frequency', 'regenerator']
# 18 ['coercion', 'Marin', 'Kazem', 'Adsorptionsgleichgewichte', '∂xj', '‘30–', '[PhD', 'Dx2', 'ðTÞ\x02\x03T0', 'Johnston', 'Characterisation']
# 19 ['corrode', 'be,', 'leave', 'happen', 'accelerate', 'neighborhoods', 'undermine', 'decline.', 'reduce.', 'occur.', 'weaken']
# 20 ['damage', 'exacerbate', 'ecosystems', 'hold', 'extent', 'reflect', 'continue', 'prevent', 'cause', 'harm', 'modify']
# 21 ['danger', 'instability', 'Oman', 'jackets', 'disease', 'country,', 'popularity', 'implication', 'automobiles', 'wetland', 'youth']
# 22 ['deformation', 'lateral', 'hydraulic', 'MRR', 'compressive', 'axial', 'stress', 'path', 'disturbance', 'consistency', 'rock']
# 23 ['detriment', 'attend.', 'Vicenza).', 'extent.', 'be.', 'lot', 'm-SOFCs.', 'outcome.', 'challenge', 'follow-up', 'FLC']
# 24 ['discourage', 'ecosystems', 'she', 'organisms', 'civic', 'locate', 'sell', 'provisions', 'rotate', 'humans', 'comprehend']
# 25 ['dislocation', 'xylan.', 'approached,', '1995),', 'WHA', 'condensers–', 'absorptivity.', '(SMER)', 'kinetics:', '(HRSG)', 'upgrade,']
# 26 ['distortion', 'Parana', 'wrote:', 'kWh/yr)', '2.437', '(0.000)∗', 'chaff,', '03/03', '\x02ð', '1.312', '20:00']
# 27 ['disturb', 'accelerates', 'bagasse', 'patterns,', 'convenient,', '[b5,t]', 'cyclohexane', 'prescribe', 'vapour,', 'species.', 'sugar.']
# 28 ['eat', 'Gambari,', 'Southeastern', 'gravel,', 'Spalling', 'colour,', 'Servility', 'A.R.', 'abortion—helped', '1991;17:95', 'pine']
# 29 ['example', 'opportunity', 'indicator', 'overview', 'explanation', 'object', 'option', 'prerequisite', 'scheme', 'dwelling', 'acronym']
# 30 ['exemplary', 'Righteous', 'Terrain', '26].', 'Thermionics', '(right)', '2006;31:2460–', 'worksheet', 'AR', 'Reynolds-average', 'umbrella']
# 31 ['exposure', 'normal', 'cover', 'sun', 'reaching', 'right', 'rain', 'relative', 'damage', 'face', 'course']
# 32 ['fault', 'defining', 'planning,', 'institutional', 'ideas', 'MLG', 'dimensions.', 'acknowledging', 'precise', 'geotechnics', 'implementable']
# 33 ['fire', 'raising', 'users’', 'identity', 'ecology', 'expansive', 'oxidative', 'Coronavirus', 'shoreline', 'lightweight', 'shrinkage']
# 34 ['fit', 'construct', 'perform', 'prove', 'select', 'subject', 'establish', 'connect', 'define', 'examine', 'find']
# 35 ['flare', 'effectively', 'tial', 'another', 'zero', 'sufficient', 'development).', 'further', 'thickeners', 'addition', 'product’s']
# 36 ['fracture', 'low-iron', 'cemented', 'lateritic', '(T4air-sim,', 'Hub', 'E-W', 'Unconfined', 'park,', 'Quantum', 'Window']
# 37 ['frost', 'forces', 'deformation', 'droplet', 'rock', 'falling', 'landslide', 'accumulation', 'propagation', 'opposite', 'heat-transfer']
# 38 ['gas', 'gas.', 'steam', 'gases', 'hydrogen', 'gas,', 'combustion', 'oil', 'CO2', 'refrigerant', 'methane']
# 39 ['harm', 'ecosystems', 'manage', 'potentially', 'ultimately', 'infrastructure', 'reliable,', 'effectively', 'actors', 'products,', 'possibly']
# 40 ['hazard', 'conductance.', 'unwanted', 'reservoirs,', 'transfer,', 'engines’.', 'waves,', 'pipes,', 'exchangers,', 'transfer.', 'collecting']
# 41 ['hit', 'posed', 'ended', 'fragmented', 'new-order', 'agreed', 'featured', 'Indicated', 'discovered', 'inaugurated', 'mosquitoes,']
# 42 ['hurt', 'Truth,”', 'enjoys', 'simpler,', '(GWP),', 'Afterward,', 'wreaks,', 'havoc', 'volatile.', 'researching', 'friendly,']
# 43 ['impair', 'ultimately', 'rogue', 'decline.', 'organisms', 'riders”', 'Khuzestan', 'be,', 'PB', 'definitely', 'corrode']
# 44 ['inducing', 'UDA,', 'NPPD,', 'elected', 'should,', 'public,', 'manual', '(Webersik', 'provincial', 'odour,', 'behenic']
# 45 ['induction', 'LED', 'CS', 'TSI', 'DI', 'LWC', '62%', 'DA', 'enforcing', 'Metropolis', 'defective']
# 46 ['influence', 'effects', 'effect', 'impact', 'influences', 'importance', 'impacts', 'behavior', 'stability', 'geometry', 'behaviour']
# 47 ['initiation', 'passenger', 'sub-channel', 'rate)', 'compressible', 'absence', 'subsurface', 'channel.', 'single-phase', 'wetlands.', 'GHE.']
# 48 ['injury', 'M.L.', '($/year)', 'Uri', '(Shibl,', 'armed', 'alkali-activated', 'Guy,', 'repealing', 'OLI', 'poly(ethyl']
# 49 ['insecurity', 'societal', 'Iran’s', 'SNG', '(Brown', 'shaping', 'lifestyle', 'civilization', 'shoreline', 'revitalization', 'financing']
# 50 ['invade', 'Xin', 'sp', 'Y2', 'LCBeEIA', 'Mouat', 'Da', '(DME)', 'BARAH10,', 'Files)', '79],']
# 51 ['jeopardize', '3450', 'leave', 'þ208C', 'woodfuel', 'rotate', 'deg)', 'Urgent', 'MANIT', 'Man—Man', 'occur.']
# 52 ['job', 'pressing', 'strategic', 'actors', 'CC', 'consumers’', 'HA2', 'Americans', '“a', 'politics', 'shaping']
# 53 ['lesson', 'RAP,', 'programs:', 'building:', 'hexagon', 'membrane-assisted', 'new,', 'day-dreamers', 'mature', 'hydrogen-fueled', 'fair']
# 54 ['matter', 'creating', 'conflict', 'threat', 'disease', 'severe', 'moving', 'action', 'serious', 'causing', 'effect,']
# 55 ['menace', 'essay', 'sub-policy', 'hypothesis.', '34].', 'regard,', 'district.', 'chapter', '“Whoever', 'anticipation', 'said.']
# 56 ['occupy', 'force,', 'emerge', 'giving', 'hence,', 'Comparatively', 'consequently,', 'eventually', 'er', 'more,', 'strains']
# 57 ['peril', 'formalin', 'Tobacco', 'Reprinted', 'cooked', '1972', 'troposphere’.', 'http://www.mathworks.com/matlabcentral/fileexchange/', '22.4%', 'preservative)', '1.286']
# 58 ['pick', '(outlined', '5;', '2b,', '>0', 'dehumidifi-', '4;', '12).', '4b', 'Qcond', '(24).']
# 59 ['pinch', 'dew', 'viewer', 'inflexion', 'Freezing', 'Flash', 'freezing', 'conduction;', '23.8◦', 'Melting', 'yaw']
# 60 ['problem', 'mechanism', 'way', 'framework', 'issue', 'concept', 'idea', 'technique', 'approach', 'choice', 'challenge']
# 61 ['pull', 'M6', 'seal', 'mg/L', 'als', 'move’', 'Fermentation', 'L.)', 'OCC', 'permanent', 'Lecturer']
# 62 ['puzzle', '[18].', 'calculation.', 'boundaries:', 'samples.', '†', '1961–2018.', 'runs.', 'data.', 'envisages', 'sensitivity']
# 63 ['risk', 'sustainability', 'political', 'human', 'lack', 'risks', 'benefits', 'regional', 'health', 'nature', 'issues']
# 64 ['run', 'separate', 'start', 'operate', 'applicable', 'repeated', 'extended', 'switched', 'continuously', 'generate', 'monitored']
# 65 ['rupture', 'placing', 'single-use', 'Copeland.', 'lifted', '10-m', 'high-speed', 'Edited', 'várzea', 'edited', 'Susan']
# 66 ['sending', 'Copeland.', 'appointed', 'Paints', '(Prepared', 'method’,', 'co-financed', 'edited', 'Clênio', 'IL1opt;E\x02_', 'owned']
# 67 ['spot', 'administrative', 'single-use', 'AAO', 'government,', 'RMA', '(former)', 'non-governmental', 'clinker', 'hostile', 'Manah,']
# 68 ['stake', 'Analogous', 'attempt', 'attic.', 'hook', 'ploughs,', 'GHI', 'Clinton', 'estimate', 'decompresses', 'rediscover']
# 69 ['storm', 'beverage', 'parks,', '\x0cProduced', '(LiBr/H2O)', 'sludge,', 'aeration', 'texture,', '\x0cAtmospheric', 'retention,', 'detention,']
# 70 ['strain', '(DA)', 'bending', 'CWP', 'timing', 'tip', 'deflection', 'upwind', 'trip', 'Fineness', '774.6']
# 71 ['strike', 'fall', 'grow', 'harvested', 'occur', 'leave', 'arise', 'come', 'Man—Man', 'coast,', 'indoors']
# 72 ['stroke', 'magnet', 'zero,', 'kg,', '1.8', 'mBD', 'inversely', '0.83', 'Boltzmann’s', 'ÞP\x02max', 'radius,']
# 73 ['submarine', 'refrigeration.', 'generation,', 'plants,', 'plants', 'compressors', 'here’,', 'generators', 'boilers', 'electronics', 'generating']
# 74 ['surprise', 'COVID19,', 'brought', 'faced', 'policy-makers', 'compensated', 'exacerbated', '2030;', 'stimulated', 'affected', '\x0249%']
# 75 ['surround', 'prevents', 'sun,', 'pool.', 'emitter', 'Qgen,', 'removes', 'high-temperature', 'exhausts', 'forming', 'grain']
# 76 ['threat', 'disease', 'spread', 'challenge', 'serious', 'acknowledging', 'big', 'society', 'extent', 'unique', 'man-made']
# 77 ['threaten', 'promotes', 'advocates', 'alters', 'organizations,', 'health,', 'favors', 'enterprises,', 'affirms', 'addresses', 'argues']
# 78 ['total', 'net', 'annual', 'percentage', 'daily', 'lowest', 'average', 'minimum', 'per', 'highest', 'primary']
# 79 ['touch', 'territory', 'council', 'sequence', 'flat,', 'E3.31', 'mid-terrace', '“Energy,', 'families', 'Again,', 'heart']
# 80 ['trauma', 'smoothness', 'POA', 'Orientation:', '40%)', 'Indies', 'fj', 'hI', 'phosphorous,', 'Radiative', '(2790']
# 81 ['trial', 'questionnaire', 'document', 'organized', 'discussed,', 'ECOTECT', 'time-step', 'verified', 'high-degree', 'fitting', 'platform']
# 82 ['trigger', 'Poor', 'confer', 'coaxing', 'accept', 'dictate', 'staffs', 'perceive', 'consciousness', 'restrictions,', 'fertile']
# 83 ['trouble', '"You', 'infections', 'counting', 'Peninsula,', '(Sharif', 'chances', 'hotels', 'patients', 'energyefficiency', '“malign”']
# 84 ['twist', 'Length', 'upstream', 'MOH:OA', 'Height', 'P-', '32.5', '(end', 'chickens', 'ceria', '“most']
# 85 ['venture', 'interpreted', 'one-off', 'soon', 'regarded', 'we,', 'well,', 'possible.', 'contend.', '15.06,', 'viewed']
# 86 ['vulnerability', 'Second,', 'govern', 'ecology', 'infrastructural', 'feeling', '(Brown', 'regional,', 'quarry', 'hydrogen-powered', 'shoreline']
# 87 ['warning', 'Utility', '1989,', 'Plus,', 'electricity—has', 'COORDICY.', 'Galápagos', 'Introducing', 'Is', 'Beside', '365mfc']
# 88 ['wound', 'steel.', 'Zhao,', 'high–strength', 'phosphate', 'enzymatic', 'Reclaimed', 'repealing', 'inflicted', '(UNI', 'BCG,']
# 89 ['wrong', 'children', 'Jordan,', 'SIPs', 'Khodra,', 'readers', 'guys', 'Peninsula,', 'fatal', 'soils,', 'TVF']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with prosociality
## in this example we choose indexes 3,6,9,11,13 and 14
relevant_threat_w2v_words = list( list_of_threat_w2v[i] for i in [0,2,3,7,14,15,19,20,21,22,23,24,25,26,27,31,32,39,40,42,43,48,49,50,51,55,57,60,63,65,71,70,76,77,82,83,86,87,88])


## Add all the words into one final bags of words
threat_BoW = [item for sublist in relevant_threat_w2v_words for item in sublist]

print(threat_BoW)
# Out:
# ['alarm', 'EEV,', 'inactive', 'nanoreactor', '‘hydrogen', 'cellulose-bounded', 'innocent', 'illusion', 'five-day', 'underestimation', 'Summits', 'assault', 'Essay', 'invoke', 'organism.3', '“Reflections', '(tH1)', 'all-silica', 'moiety', '(TR)', 'Volpe', '‘Research', 'attack', '(TA,', '\x0cM.H.', 'beliefs', 'sexual', 'Rigby.', 'vastly', 'southeastern', 'age,', 'famines,', 'Zirconia', 'blame', 'Discussion', 'Essays', '\x0cResearch', '“Next', 'Potential),', 'Rican', '(Tarrow', 'Globalization.', 'Rhodic', 'Lanham,', 'causing', 'effect,', 'thereby', 'causes', 'ignition', 'leading', 'content,', '(or', 'and/or', 'allowing', 'excessive', 'caution', 'dealing', 'comply', 'comingled', 'u).', 'laden', 'contrasted', 'N2O.', 'diets,', 'interbreeding', '"Siding', 'corrode', 'be,', 'leave', 'happen', 'accelerate', 'neighborhoods', 'undermine', 'decline.', 'reduce.', 'occur.', 'weaken', 'damage', 'exacerbate', 'ecosystems', 'hold', 'extent', 'reflect', 'continue', 'prevent', 'cause', 'harm', 'modify', 'danger', 'instability', 'Oman', 'jackets', 'disease', 'country,', 'popularity', 'implication', 'automobiles', 'wetland', 'youth', 'deformation', 'lateral', 'hydraulic', 'MRR', 'compressive', 'axial', 'stress', 'path', 'disturbance', 'consistency', 'rock', 'detriment', 'attend.', 'Vicenza).', 'extent.', 'be.', 'lot', 'm-SOFCs.', 'outcome.', 'challenge', 'follow-up', 'FLC', 'discourage', 'ecosystems', 'she', 'organisms', 'civic', 'locate', 'sell', 'provisions', 'rotate', 'humans', 'comprehend', 'dislocation', 'xylan.', 'approached,', '1995),', 'WHA', 'condensers–', 'absorptivity.', '(SMER)', 'kinetics:', '(HRSG)', 'upgrade,', 'distortion', 'Parana', 'wrote:', 'kWh/yr)', '2.437', '(0.000)∗', 'chaff,', '03/03', '\x02ð', '1.312', '20:00', 'disturb', 'accelerates', 'bagasse', 'patterns,', 'convenient,', '[b5,t]', 'cyclohexane', 'prescribe', 'vapour,', 'species.', 'sugar.', 'exposure', 'normal', 'cover', 'sun', 'reaching', 'right', 'rain', 'relative', 'damage', 'face', 'course', 'fault', 'defining', 'planning,', 'institutional', 'ideas', 'MLG', 'dimensions.', 'acknowledging', 'precise', 'geotechnics', 'implementable', 'harm', 'ecosystems', 'manage', 'potentially', 'ultimately', 'infrastructure', 'reliable,', 'effectively', 'actors', 'products,', 'possibly', 'hazard', 'conductance.', 'unwanted', 'reservoirs,', 'transfer,', 'engines’.', 'waves,', 'pipes,', 'exchangers,', 'transfer.', 'collecting', 'hurt', 'Truth,”', 'enjoys', 'simpler,', '(GWP),', 'Afterward,', 'wreaks,', 'havoc', 'volatile.', 'researching', 'friendly,', 'impair', 'ultimately', 'rogue', 'decline.', 'organisms', 'riders”', 'Khuzestan', 'be,', 'PB', 'definitely', 'corrode', 'injury', 'M.L.', '($/year)', 'Uri', '(Shibl,', 'armed', 'alkali-activated', 'Guy,', 'repealing', 'OLI', 'poly(ethyl', 'insecurity', 'societal', 'Iran’s', 'SNG', '(Brown', 'shaping', 'lifestyle', 'civilization', 'shoreline', 'revitalization', 'financing', 'invade', 'Xin', 'sp', 'Y2', 'LCBeEIA', 'Mouat', 'Da', '(DME)', 'BARAH10,', 'Files)', '79],', 'jeopardize', '3450', 'leave', 'þ208C', 'woodfuel', 'rotate', 'deg)', 'Urgent', 'MANIT', 'Man—Man', 'occur.', 'menace', 'essay', 'sub-policy', 'hypothesis.', '34].', 'regard,', 'district.', 'chapter', '“Whoever', 'anticipation', 'said.', 'peril', 'formalin', 'Tobacco', 'Reprinted', 'cooked', '1972', 'troposphere’.', 'http://www.mathworks.com/matlabcentral/fileexchange/', '22.4%', 'preservative)', '1.286', 'problem', 'mechanism', 'way', 'framework', 'issue', 'concept', 'idea', 'technique', 'approach', 'choice', 'challenge', 'risk', 'sustainability', 'political', 'human', 'lack', 'risks', 'benefits', 'regional', 'health', 'nature', 'issues', 'rupture', 'placing', 'single-use', 'Copeland.', 'lifted', '10-m', 'high-speed', 'Edited', 'várzea', 'edited', 'Susan', 'strike', 'fall', 'grow', 'harvested', 'occur', 'leave', 'arise', 'come', 'Man—Man', 'coast,', 'indoors', 'strain', '(DA)', 'bending', 'CWP', 'timing', 'tip', 'deflection', 'upwind', 'trip', 'Fineness', '774.6', 'threat',  ...

# %%
## An hypothetical bag of words was thus obtained, which can be used for frequency analyses
## See next script

print('adaptation',adaptation_BoW)
print('\n')
print('threat',threat_BoW)
# Out:
# adaptation ['abide', 'flare-out', 'Bhaduri', 'deadlines—and', 'scholarship', '2031–2032', '5400', 'conservatives', 'managed', 'facility-level', 'displaced', 'acclimation', 'Payback', 'Apr.', 'CM', '(node', '(days,', '\x0cA.K.', '+2.0', 'inactivity', 'Mesh', '31.9', 'acclimatisation', 'pouring', 'sleeve', 'upkeep,', '0.995', 'axi-symmetry', 'A/L,', 'created,', '‘classify’', '86.02,', '900;', 'accountability', 'single-', 'HGHEs', 'shoreline', 'timing', 'geotechnics', 'emergencies', 'typology', 'background', 'nanopower', '4.22%', 'adaptation', 'planning', 'sustainability', 'regional', 'practices', 'policies', 'risks', 'mitigation', 'SLR', 'health', 'long-term', 'adherence', 'biodiesel,', 'actors', 'similarly', 'Just', 'bioboards', 'first,', 'SNG', 'pretreatment', 'people,', 'engineers', 'adjustment', 'complexity', 'limiting', 'failure', 'reliability', 'identification', 'computing', 'privacy', 'limits', 'institutional', 'action', 'aid', 'extend', 'assist', 'replace', 'examine', 'facilitate', 'establish', 'respond', 'modify', 'explore', 'alter', 'assist', 'help', 'extend', 'continue', 'promote', 'alter', 'aid', 'invest', 'expand', 'exacerbate', 'go', 'bear', 'express', 'choose', 'inform', 'extend', 'encourage', 'realize', 'expand', 'sustain', 'adopt', 'undertake', 'boost', 'minimize', 'optimise', 'respond', 'regulate', 'maximize', 'monitor', 'begin', 'adapt', 'modernize', 'switch', 'brace', 'adaptation."', 'irrigated', 'neglected,', 'category,', 'while,', 'financially', 'peninsulas', 'SRC', 'Potentiality', 'utilised', 'defend', 'moral', 'infrastructural', 'halogenated', 'regimes,', 'siliceous', 'Willingness', 'aromatic', 'waxes,', 'decisional', 'Mormann', 'dependability', 'conservation.', 'balance,', 'demolition:', 'balance.', 'Net-zero', 'bottleneck', '[116].', 'embodied', 'meters:', 'Lehmanna', 'detoxification', 'thereby,', 'Low-emission', 'pollutants,', 'breathing,', 'polluters,', 'hot/cold', 'behaviors,', 'infiltration.', 'Excess', 'beverage', 'encourage', 'address', 'express', 'inform', 'enable', 'discuss', 'implement', 'accept', 'consequences,', 'reinforce', 'attract', 'endure', 'withstand', 'cause', 'alleviate', 'attain', 'eliminate', 'reach', 'raise', 'resist', 'modify', 'relieve', 'governance', 'institutional', 'practices', 'barriers', 'considerations', 'SLR', 'initiatives', 'mechanisms', 'spatial', 'acceptability', 'theories', 'governing', 'equations.', 'domain.', 'describing', 'equations,', 'solving', 'nonlinear', 'aforementioned', 'expressions', 'equations', 'weights', 'handling', 'purification', 'dehumidification.', 'conditioning', 'cleaning', 'quality,', 'ventilating', 'conditioning,', 'refrigeration,', '(0.44', 'pest', 'help', 'assist', 'promote', 'effectively', 'address', 'enable', 'implement', 'make', 'improve', 'alleviate', 'alter', 'interference', 'insulation;', 'raising', 'Furniture,', 'machine,', 'uncemented', 'hydrophobic', 'ocean', 'wetlands,', 'relocation', 'vibration', 'maintenance', 'investment', 'capital', 'costs,', 'cost,', 'life,', 'reliability', 'services', 'safety', 'costs', 'service', 'management', 'transportation', 'strategies', 'mitigation', 'clean', 'implementation', 'existing', 'planning', 'security', 'manufacturing', 'sustainability', 'policy', 'future', 'policies', 'planning', 'sustainability', 'community', 'social', 'security', 'economy', 'government', 'measures', 'promote', 'enable', 'address', 'implement', 'encourage', 'facilitate', 'contribute', 'alleviate', 'create', 'manage', 'reflect', 'shift', 'decline', 'rise', 'separator', 'trace', 'jet', '8%', 'transition', 'draw', 'delay', 'extending', 'support', 'financial', 'existing', 'planning', 'international', 'policy', 'suggestions', 'government', 'individual', 'search', 'experience', 'supporting', 'governmental', 'shaping', 'geotechnics', 'pavement', 'CSPM', 'addressing', 'responsibility', 'consciousness', 'landscape', 'Second,', 'sustain', 'address', 'overcome', 'modify', 'adopt', 'extend', 'enable', 'avoid', 'encourage', 'inform', 'resist' ...
#
#
# threat ['alarm', 'EEV,', 'inactive', 'nanoreactor', '‘hydrogen', 'cellulose-bounded', 'innocent', 'illusion', 'five-day', 'underestimation', 'Summits', 'assault', 'Essay', 'invoke', 'organism.3', '“Reflections', '(tH1)', 'all-silica', 'moiety', '(TR)', 'Volpe', '‘Research', 'attack', '(TA,', '\x0cM.H.', 'beliefs', 'sexual', 'Rigby.', 'vastly', 'southeastern', 'age,', 'famines,', 'Zirconia', 'blame', 'Discussion', 'Essays', '\x0cResearch', '“Next', 'Potential),', 'Rican', '(Tarrow', 'Globalization.', 'Rhodic', 'Lanham,', 'causing', 'effect,', 'thereby', 'causes', 'ignition', 'leading', 'content,', '(or', 'and/or', 'allowing', 'excessive', 'caution', 'dealing', 'comply', 'comingled', 'u).', 'laden', 'contrasted', 'N2O.', 'diets,', 'interbreeding', '"Siding', 'corrode', 'be,', 'leave', 'happen', 'accelerate', 'neighborhoods', 'undermine', 'decline.', 'reduce.', 'occur.', 'weaken', 'damage', 'exacerbate', 'ecosystems', 'hold', 'extent', 'reflect', 'continue', 'prevent', 'cause', 'harm', 'modify', 'danger', 'instability', 'Oman', 'jackets', 'disease', 'country,', 'popularity', 'implication', 'automobiles', 'wetland', 'youth', 'deformation', 'lateral', 'hydraulic', 'MRR', 'compressive', 'axial', 'stress', 'path', 'disturbance', 'consistency', 'rock', 'detriment', 'attend.', 'Vicenza).', 'extent.', 'be.', 'lot', 'm-SOFCs.', 'outcome.', 'challenge', 'follow-up', 'FLC', 'discourage', 'ecosystems', 'she', 'organisms', 'civic', 'locate', 'sell', 'provisions', 'rotate', 'humans', 'comprehend', 'dislocation', 'xylan.', 'approached,', '1995),', 'WHA', 'condensers–', 'absorptivity.', '(SMER)', 'kinetics:', '(HRSG)', 'upgrade,', 'distortion', 'Parana', 'wrote:', 'kWh/yr)', '2.437', '(0.000)∗', 'chaff,', '03/03', '\x02ð', '1.312', '20:00', 'disturb', 'accelerates', 'bagasse', 'patterns,', 'convenient,', '[b5,t]', 'cyclohexane', 'prescribe', 'vapour,', 'species.', 'sugar.', 'exposure', 'normal', 'cover', 'sun', 'reaching', 'right', 'rain', 'relative', 'damage', 'face', 'course', 'fault', 'defining', 'planning,', 'institutional', 'ideas', 'MLG', 'dimensions.', 'acknowledging', 'precise', 'geotechnics', 'implementable', 'harm', 'ecosystems', 'manage', 'potentially', 'ultimately', 'infrastructure', 'reliable,', 'effectively', 'actors', 'products,', 'possibly', 'hazard', 'conductance.', 'unwanted', 'reservoirs,', 'transfer,', 'engines’.', 'waves,', 'pipes,', 'exchangers,', 'transfer.', 'collecting', 'hurt', 'Truth,”', 'enjoys', 'simpler,', '(GWP),', 'Afterward,', 'wreaks,', 'havoc', 'volatile.', 'researching', 'friendly,', 'impair', 'ultimately', 'rogue', 'decline.', 'organisms', 'riders”', 'Khuzestan', 'be,', 'PB', 'definitely', 'corrode', 'injury', 'M.L.', '($/year)', 'Uri', '(Shibl,', 'armed', 'alkali-activated', 'Guy,', 'repealing', 'OLI', 'poly(ethyl', 'insecurity', 'societal', 'Iran’s', 'SNG', '(Brown', 'shaping', 'lifestyle', 'civilization', 'shoreline', 'revitalization', 'financing', 'invade', 'Xin', 'sp', 'Y2', 'LCBeEIA', 'Mouat', 'Da', '(DME)', 'BARAH10,', 'Files)', '79],', 'jeopardize', '3450', 'leave', 'þ208C', 'woodfuel', 'rotate', 'deg)', 'Urgent', 'MANIT', 'Man—Man', 'occur.', 'menace', 'essay', 'sub-policy', 'hypothesis.', '34].', 'regard,', 'district.', 'chapter', '“Whoever', 'anticipation', 'said.', 'peril', 'formalin', 'Tobacco', 'Reprinted', 'cooked', '1972', 'troposphere’.', 'http://www.mathworks.com/matlabcentral/fileexchange/', '22.4%', 'preservative)', '1.286', 'problem', 'mechanism', 'way', 'framework', 'issue', 'concept', 'idea', 'technique', 'approach', 'choice', 'challenge', 'risk', 'sustainability', 'political', 'human', 'lack', 'risks', 'benefits', 'regional', 'health', 'nature', 'issues', 'rupture', 'placing', 'single-use', 'Copeland.', 'lifted', '10-m', 'high-speed', 'Edited', 'várzea', 'edited', 'Susan', 'strike', 'fall', 'grow', 'harvested', 'occur', 'leave', 'arise', 'come', 'Man—Man', 'coast,', 'indoors', 'strain', '(DA)', 'bending', 'CWP', 'timing', 'tip', 'deflection', 'upwind', 'trip', 'Fineness', '774.6', 'th ...
