# %% [markdown]
# ## Section 1
# ### First we use word lists from psychometric tools and obtain synonyms and hyponyms using WordNet

# %%
## The first time you use this script, uncomment lines 3 and 5

# !pip install nltk
import nltk
nltk.download('all')
from nltk.corpus import wordnet as wn

# Here we can change the langauge of analysis
languages = ['eng']
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw-1.4.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2021.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet31.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
### Function to Generate synonyms and hyponyms using Wordnet

def generate_wordnet_list(word_base,languages,exclude_list):
  word_lists = []

  #iterate over languages
  for language in languages:
    word_list = []

    # iterate over words in the word_base list
    for word in word_base:

      ## iterate over different meanings of the word synsets
      for meaning in wn.synsets(word, pos=wn.NOUN+wn.VERB+wn.ADJ):
        if meaning.name() not in exclude_list:
          print(meaning)
          print(meaning.definition())
          print('\n')


          ## iterate over different synonyms and add them to list
          for synonym in meaning.lemmas(language):
            #print(synonym)

            ## if the synonym is no in the list add it
            if synonym.name() not in word_list:
              word_list.append(synonym.name())
              #print(synonym.name())

          ## iterate over hyponyms
          for hyponym in meaning.hyponyms():
            #print(hyponym.lemmas(language))

            ## iterate over synonyms of hyponyms
            for synonym_of_hyponym in hyponym.lemmas(language):
              #print(synonym_of_hyponym.name())

              ## if the synonym of the hyponym is no in the list add it
              if synonym_of_hyponym.name() not in word_list:
                word_list.append(synonym_of_hyponym.name())

    ## add the language-specific word list to the global word list, sort the words in alphabetic order   
    word_lists +=[sorted(word_list)]

  ## there are 3 lists now, one for each language, we iterate over the list of lists and print each
  for lst in word_lists:
    #print(lst)
    return(lst)

# %%
## Example of seed-words related to a target concept - for instance, prosociality. 
## In this case, I obtained based seed word list from:
# Ishaya, S., & Abaje, I. B. (2008). Indigenous people's perception on climate change and adaptation strategies in Jema'a local government area of Kaduna State, Nigeria. Journal of geography and regional planning, 1(8), 138.
# Ayalew, M. S., Demissie, G. D., Muchie, K. F., Tadesse, S., & Alemu, K. PERCEPTION OF CLIMATE CHANGE AND ASSOCIATED FACTORS AMONG RURAL DWELLERS OF GONDAR ZURIA DISTRICT, NORTHWEST ETHIOPIA.
word_base_climate = ['Drought','typhoon', 'landslide','flood','temperature','weather','environment','storm','rainfall','dry','adaptation','season','natural','ecosystems']
## Using the function above, we can obtain the list of synonyms and hyponyms of the seed words,
## We can also exclude word meanings that are irrelvant for the concept we want to measure

## For instance, 'quilt' is not related to prosociality, and we can add it to the exclusion list
## We run the script until all the words in the list of synsets displayed below have relevant meanings 

exclude_list_climate = ['landslide.n.01','flood.n.03','weather.v.01','weather.v.01','weather.v.03','dry.n.01','dry.s.02','dry.a.04','dry.a.05','dry.a.06','dry.a.07','dry.s.08','dry.s.09','dry.s.10','dry.s.12','dry.s.15','dry.s.16',
                       'adaptation.n.01','adaptation.n.03','season.n.03','season.v.01','season.v.02','temper.v.04','natural.n.01','natural.n.02','natural.n.03','natural.a.05','natural.s.06','natural.s.07','natural.s.08','natural.s.09','lifelike.s.02',
                       'dry.s.13','dry.s.14']
climate_list = generate_wordnet_list(word_base_climate,languages,exclude_list_climate)
# Out:
# Synset('drought.n.01')
# a shortage of rainfall
#
#
# Synset('drought.n.02')
# a prolonged shortage
#
#
# Synset('typhoon.n.01')
# a tropical cyclone occurring in the western Pacific or Indian oceans
#
#
# Synset('landslide.n.02')
# a slide of a large mass of dirt and rock down a mountain or cliff
#
#
# Synset('flood.n.01')
# the rising of a body of water and its overflowing onto normally dry land
#
#
# Synset('flood.n.02')
# an overwhelming number or amount
#
#
# Synset('flood.n.04')
# a large flow
#
#
# Synset('flood.n.05')
# the act of flooding; filling to overflowing
#
#
# Synset('flood_tide.n.02')
# the occurrence of incoming water (between a low tide and the following high tide)
#
#
# Synset('deluge.v.01')
# fill quickly beyond capacity; as with a liquid
#
#
# Synset('flood.v.02')
# cover with liquid, usually water
#
#
# Synset('flood.v.03')
# supply with an excess of
#
#
# Synset('flood.v.04')
# become filled to overflowing
#
#
# Synset('temperature.n.01')
# the degree of hotness or coldness of a body or environment (corresponding to its molecular activity)
#
#
# Synset('temperature.n.02')
# the somatic sensation of cold or heat
#
#
# Synset('weather.n.01')
# the atmospheric conditions that comprise the state of the atmosphere in terms of temperature and wind and clouds and precipitation
#
#
# Synset('weather.v.02')
# cause to slope
#
#
# Synset('weather.v.04')
# change under the action or influence of the weather
#
#
# Synset('upwind.s.01')
# towards the side exposed to wind
#
#
# Synset('environment.n.01')
# the totality of surrounding conditions
#
#
# Synset('environment.n.02')
# the area in which something exists or lives
#
#
# Synset('storm.n.01')
# a violent weather condition with winds 64-72 knots (11 on the Beaufort scale) and precipitation and thunder and lightning
#
#
# Synset('storm.n.02')
# a violent commotion or disturbance
#
#
# Synset('storm.n.03')
# a direct and violent assault on a stronghold
#
#
# Synset('ramp.v.01')
# behave violently, as if in state of a great anger
#
#
# Synset('storm.v.02')
# take by force
#
#
# Synset('storm.v.03')
# rain, hail, or snow hard and be very windy, often with thunder or lightning
#
#
# Synset('storm.v.04')
# blow hard
#
#
# Synset('storm.v.05')
# attack by storm; attack suddenly
#
#
# Synset('rain.n.01')
# water falling in drops from vapor condensed in the atmosphere
#
#
# Synset('dry.v.01')
# remove the moisture from and make dry
#
#
# Synset('dry.v.02')
# become dry or drier
#
#
# Synset('dry.a.01')
# free from liquid or moisture; lacking natural or normal moisture or depleted of water; or no longer wet
#
#
# Synset('dry.a.03')
# lacking moisture or volatile components
#
#
# Synset('dry.s.11')
# unproductive especially of the expected results
#
#
# Synset('adaptation.n.02')
# the process of adapting to something (such as environmental conditions)
#
#
# Synset('season.n.01')
# a period of the year marked by special events or activities in some field
#
#
# Synset('season.n.02')
# one of the natural periods into which the year is divided by the equinoxes and solstices or atmospheric conditions
#
#
# Synset('natural.a.01')
# in accordance with nature; relating to or concerning nature
#
#
# Synset('natural.a.02')
# existing in or produced by nature; not artificial or imitation
#
#
# Synset('natural.a.03')
# existing in or in conformity with nature or the observable world; neither supernatural nor magical
#
#
# Synset('natural.s.04')
# functioning or occurring in a normal way; lacking abnormalities or deficiencies
#
#
# Synset('ecosystem.n.01')
# a system formed by the interaction of a community of organisms with their physical environment

# %%
## This is a very broad list which includes all possible synonyms and hyponyms 
## related to the seed words we chose for climate

## As one can verify, this list needs prunning 
## some of it by excluding irrelevant synsets a priori (cell above), 
## but some of it can also be done manually a posteriori

print(climate_list)
# Out:
# ['Curie_point', 'Curie_temperature', 'Noachian_deluge', "Noah's_flood", 'Noah_and_the_Flood', 'Whitsun', 'Whitsuntide', 'Whitweek', 'absolute_temperature', 'absolute_zero', 'acclimation', 'acclimatisation', 'acclimatization', 'adaptation', 'adaption', 'adjustment', 'air', 'air_current', 'alluvion', 'ambiance', 'ambience', 'area', 'arena', 'atmosphere', 'atmospheric_condition', 'atmospheric_state', 'autumn', 'background', 'bad_weather', 'baseball_season', 'basketball_season', 'blizzard', 'blood_heat', 'blow-dry', 'body_temperature', 'boil', 'boiling_point', 'circumstance', 'cloudburst', 'cold', 'cold_weather', 'coldness', 'comfort_zone', 'conditions', 'context', 'current_of_air', 'debacle', 'dedifferentiation', 'dehumidify', 'dehydrate', 'deluge', 'desiccate', 'dew_point', 'differentiation', 'domain', 'domestication', 'downfall', 'downpour', 'drench', 'drip-dry', 'drizzle', 'drought', 'drouth', 'dry', 'dry_out', 'dry_season', 'dry_up', 'ecology', 'ecosystem', 'effusion', 'electric_storm', 'electrical_storm', 'element', 'elements', 'environment', 'environs', 'exhibition_season', 'exsiccate', 'fair_weather', 'fall', 'field', 'firestorm', 'fishing_season', 'flash_flood', 'flash_point', 'flashflood', 'flashpoint', 'flood', 'flood_tide', 'flow', 'flowage', 'football_season', 'force', 'freezing_point', 'frigidity', 'frigidness', 'glut', 'good_weather', 'growing_season', 'habitat', 'hailstorm', 'harvest', 'harvest_time', 'haying', 'haying_time', 'heat', 'high_season', 'high_temperature', 'hockey_season', 'holiday_season', 'home', 'home_ground', 'hot_weather', 'hotness', 'hunting_season', 'ice_storm', 'inclemency', 'inclementness', 'inundate', 'inundation', 'landslide', 'landslip', 'low_temperature', 'medium', 'melting_point', 'melting_pot', 'mercury', 'milieu', 'mizzle', 'monsoon', 'mudslide', 'natural', 'noreaster', 'northeaster', 'off-season', 'orbit', 'outpouring', 'overflow', 'oversupply', 'parch', 'parts', 'peak_season', 'pelter', 'precipitation', 'preseason', 'rage', 'rain', 'rain_shower', 'rainfall', 'rainstorm', 'rainy_season', 'ramp', 'rising_tide', 'rockslide', 'room_temperature', 'rough-dry', 'run_dry', 'scene', 'scope', 'scorch', 'sear', 'season', 'seedtime', 'setting', 'sheepshearing', 'shower', 'silver_storm', 'simmer', 'snowstorm', 'soaker', 'social_season', 'specialisation', 'specialization', 'sphere', 'spin-dry', 'spray-dry', 'spring', 'springtime', 'storm', 'street', 'submerge', 'summer', 'summertime', 'sunshine', 'surprise', 'surround', 'surroundings', 'swamp', 'temperateness', 'temperature', 'tempest', 'thaw', 'thawing', 'the_Flood', 'theatrical_season', 'thunderstorm', 'time_of_year', 'torrent', 'tumble_dry', 'typhoon', 'upwind', 'violent_storm', 'warming', 'warmth', 'waterspout', 'wave', 'weather', 'weather_condition', 'wind', 'windstorm', 'winter', 'wintertime']

# %%
# ## THREAT

# #Ishaya, S., & Abaje, I. B. (2008). Indigenous people's perception on climate change and adaptation strategies in Jema'a local government area of Kaduna State, Nigeria. Journal of geography and regional planning, 1(8), 138.
# #Pickson, R. B., & He, G. (2021). Smallholder Farmers’ Perceptions, Adaptation Constraints, and Determinants of Adaptive Capacity to Climate Change in Chengdu. SAGE Open. https://doi.org/10.1177/21582440211032638

# exclude_list_threat = ['vulnerable.s.02','decreasing.a.02','poor_people.n.01','hapless.s.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','switch.v.03','change.v.05','exchange.v.01','transfer.v.06','deepen.v.04','change.v.10','challenge.n.01','challenge.n.02','challenge.n.03','challenge.n.04','challenge.n.05','challenge.v.01','challenge.v.02','challenge.v.03','challenge.v.04','diminish.v.02','waste.n.01','waste.n.02','waste.n.05','waste.v.01','waste.v.02','neutralize.v.04','consume.v.03','godforsaken.s.01','critical.a.01',
#                       'critical.a.03','critical.s.04','battle.n.01','gamble.v.01','competitiveness.n.01','fight.n.04','fight.n.05','contend.v.06','pest.n.03','supplanting.n.01','translation.n.07','displacement.n.04','displacement.n.07','loss.n.05','loss.n.06','personnel_casualty.n.01','refuse.v.02','refuse.v.01','decline.v.07','obstruct.v.02','flimsy.s.03''constraint.n.01','constraint.n.03','negative.n.01',
#                        'negative.n.02','veto.v.01','negative.a.04','negative.s.06','damaging.s.02','negative.s.08','vulnerable.s.02','decreasing.a.02','poor.a.02','vulnerable.s.02','poor_people.n.01','poor.a.02','poor.a.03','incidence.n.02','annihilating.s.02','change.v.05','change.v.06','exchange.v.01','transfer.v.06']

# word_base_threat = ['unpredictable', 'risk', 'hindrances', 'Lack','vulnerable','decreasing','Poor','incidence','devastating','changing','challenges','repercussions' 'scarcity', 'diminishing', 'waste', 'critical','fight','disaster','exacerbated','severity','adverse','pest','depletion','endanger','displacement','loss','decline','impeded','fragile','inundation','constraints','negative','problem']
# threat_list = generate_wordnet_list(word_base_threat,languages,exclude_list_education)

# %%
## DAMAGE

#Stewart A. E. (2021). Psychometric Properties of the Climate Change Worry Scale. International journal of environmental research and public health, 18(2), 494. https://doi.org/10.3390/ijerph18020494

exclude_list_damage = ['price.n.02','personnel_casualty.n.01','worry.v.05','worry.v.06','effect.n.04','effect.n.05','affect.n.01','involve.v.01','feign.v.01','severe.s.04','reverence.v.01','stress.n.01','stress.n.03','stress.n.05','stress.v.01','stress.v.02','try.v.07','depression.n.05','depression.n.08','depression.n.09','extreme.n.01','extreme_point.n.01','extreme.s.04','damage.n.02','risk.n.02','gamble.v.01','sensitivity.n.03','fear.n.03']

word_base_damage = ['damage','loss','worry','effect','affect','outbreak','severe','paralyzed','difficult','fear','stress','anxiety','depression','extreme','threat','risks','sensitivity']
damage_list = generate_wordnet_list(word_base_damage,languages,exclude_list_damage)
# Out:
# Synset('damage.n.01')
# the occurrence of a change for the worse
#
#
# Synset('damage.n.03')
# the act of damaging something or someone
#
#
# Synset('wrong.n.02')
# any harm or injury resulting from a violation of a legal right
#
#
# Synset('damage.v.01')
# inflict damage upon
#
#
# Synset('damage.v.02')
# suffer or be susceptible to damage
#
#
# Synset('loss.n.01')
# something that is lost
#
#
# Synset('loss.n.02')
# gradual decline in amount or activity
#
#
# Synset('loss.n.03')
# the act of losing someone or something
#
#
# Synset('loss.n.04')
# the disadvantage that results from losing something
#
#
# Synset('loss.n.05')
# the experience of losing a loved one
#
#
# Synset('loss.n.06')
# the amount by which the cost of a business exceeds its revenue
#
#
# Synset('passing.n.02')
# euphemistic expressions for death
#
#
# Synset('concern.n.04')
# something or someone that causes anxiety; a source of unhappiness
#
#
# Synset('worry.n.02')
# a strong feeling of anxiety
#
#
# Synset('worry.v.01')
# be worried, concerned, anxious, troubled, or uneasy
#
#
# Synset('worry.v.02')
# be concerned with
#
#
# Synset('worry.v.03')
# disturb the peace of mind of; afflict with mental agitation or distress
#
#
# Synset('concern.v.02')
# be on the mind of
#
#
# Synset('consequence.n.01')
# a phenomenon that follows and is caused by some previous phenomenon
#
#
# Synset('impression.n.02')
# an outward appearance
#
#
# Synset('effect.n.03')
# an impression (especially one that is artificial or contrived)
#
#
# Synset('effect.n.06')
# a symptom caused by an illness or a drug
#
#
# Synset('effect.v.01')
# produce
#
#
# Synset('effect.v.02')
# act so as to bring into existence
#
#
# Synset('affect.v.01')
# have an effect upon
#
#
# Synset('affect.v.02')
# act physically on; have an effect upon
#
#
# Synset('affect.v.05')
# have an emotional or cognitive impact upon
#
#
# Synset('outbreak.n.01')
# a sudden violent spontaneous occurrence (usually of some undesirable condition)
#
#
# Synset('severe.s.01')
# intensely or extremely bad or unpleasant in degree or quality
#
#
# Synset('hard.s.04')
# very strong or vigorous
#
#
# Synset('austere.s.01')
# severely simple
#
#
# Synset('dangerous.s.02')
# causing fear or anxiety by threatening great harm
#
#
# Synset('severe.s.06')
# very bad in degree or extent
#
#
# Synset('paralyze.v.01')
# make powerless and unable to function
#
#
# Synset('paralyze.v.02')
# cause to be paralyzed and immobile
#
#
# Synset('paralytic.s.02')
# affected with paralysis
#
#
# Synset('difficult.a.01')
# not easy; requiring great physical or mental effort to accomplish or comprehend or endure
#
#
# Synset('unmanageable.a.02')
# hard to control
#
#
# Synset('fear.n.01')
# an emotion experienced in anticipation of some specific pain or danger (usually accompanied by a desire to flee or fight)
#
#
# Synset('concern.n.02')
# an anxious feeling
#
#
# Synset('fear.v.01')
# be afraid or feel anxious or apprehensive about a possible or probable situation or event
#
#
# Synset('fear.v.02')
# be afraid or scared of; be frightened of
#
#
# Synset('fear.v.03')
# be sorry; used to introduce an unpleasant statement
#
#
# Synset('fear.v.04')
# be uneasy or apprehensive about
#
#
# Synset('tension.n.01')
# (psychology) a state of mental or emotional strain or suspense
#
#
# Synset('stress.n.04')
# difficulty that causes worry or emotional tension
#
#
# Synset('anxiety.n.01')
# (psychiatry) a relatively permanent state of worry and nervousness occurring in a variety of mental disorders, usually accompanied by compulsive behavior or attacks of panic
#
#
# Synset('anxiety.n.02')
# a vague unpleasant emotion that is experienced in anticipation of some (usually ill-defined) misfortune
#
#
# Synset('depression.n.01')
# a mental state characterized by a pessimistic sense of inadequacy and a despondent lack of activity
#
#
# Synset('depression.n.02')
# a long-term economic state characterized by unemployment and low prices and low levels of trade and investment
#
#
# Synset('natural_depression.n.01')
# a sunken or depressed geological formation
#
#
# Synset('depression.n.04')
# sad feelings of gloom and inadequacy
#
#
# Synset('low.n.01')
# an air mass of lower pressure; often brings precipitation
#
#
# Synset('depressive_disorder.n.01')
# a state of depression and anhedonia so severe as to require clinical intervention
#
#
# Synset('depression.n.10')
# pushing down
#
#
# Synset('extreme.s.01')
# of the greatest possible degree or extent or intensity
#
#
# Synset('extreme.s.02')
# far beyond a norm in quantity or amount or degree; to an utmost degree
#
#
# Synset('extreme.s.03')
# beyond a norm in views or actions
#
#
# Synset('menace.n.01')
# something that is a source of danger
#
#
# Synset('threat.n.02')
# a warning that something unpleasant is imminent
#
#
# Synset('threat.n.03')
# declaration of an intention or a determination to inflict harm on another
#
#
# Synset('terror.n.02')
# a person who inspires fear or dread
#
#
# Synset('hazard.n.01')
# a source of danger; a possibility of incurring loss or misfortune
#
#
# Synset('risk.n.03')
# the probability of becoming infected given that exposure to an infectious agent has occurred
#
#
# Synset('risk.n.04')
# the probability of being exposed to an infectious agent
#
#
# Synset('risk.v.01')
# expose to a chance of loss or damage
#
#
# Synset('sensitivity.n.01')
# (physiology) responsiveness to external stimuli; the faculty of sensation
#
#
# Synset('sensitivity.n.02')
# the ability to respond to physical stimuli or to register small physical amounts or differences
#
#
# Synset('sensitivity.n.04')
# susceptibility to a pathogen
#
#
# Synset('sensitivity.n.05')
# the ability to respond to affective changes in your interpersonal environment

# %%
print(damage_list)
# Out:
# ['Coriolis_effect', 'accomplish', 'act_upon', 'action', 'acuteness', 'adventure', 'affect', 'afflict', 'affright', 'aftereffect', 'aftermath', 'agitated_depression', 'alarm', 'alienate', 'anaclitic_depression', 'angst', 'antenna', 'anxiety', 'anxiousness', 'apprehension', 'apprehensiveness', 'arouse', 'attack', 'austere', 'awaken', 'backdate', 'backwash', 'bandwagon_effect', 'bang_up', 'basin', 'bear_on', 'bear_upon', 'bed', 'bell_the_cat', 'bilge', 'blemish', 'blue_devils', 'blue_funk', 'blues', 'bother', 'bottom', 'brace', 'branch', 'break', 'breaking_point', 'bring_to_bear', 'brisance', 'brood', 'bruise', 'bugaboo', 'bummer', 'burden', 'burn', 'business', 'butterfly_effect', 'by-product', 'byproduct', 'calm', 'capitulation', 'care', 'carry', 'carry_out', 'carry_through', 'castration_anxiety', 'change', 'chill', 'click', 'clinical_depression', 'cloud', 'coattails_effect', 'color', 'colour', 'commination', 'concern', 'consequence', 'consternation', 'corrode', 'cramp', 'crater', 'creeps', 'cut_up', 'damage', 'dangerous', 'deep', 'defacement', 'default', 'defensiveness', 'defloration', 'deflower', 'deformation', 'dejection', 'demoralisation', 'demoralization', 'dent', 'departure', 'depression', 'depressive_disorder', 'deprivation', 'despondence', 'despondency', 'detriment', 'diathesis', 'difficult', 'discomfiture', 'discommode', 'discomposure', 'disconcertion', 'disconcertment', 'disconsolateness', 'disfiguration', 'disfigurement', 'dismay', 'disoblige', 'disquiet', 'disquietude', 'distort', 'distortion', 'disturb', 'domino_effect', 'draw', 'dread', 'dwell', 'dysphoria', 'dysthymia', 'dysthymic_depression', 'eat', 'eat_away', 'eat_on', 'economic_crisis', 'edginess', 'effect', 'effectuate', 'encumbrance', 'endanger', 'endangerment', 'endogenous_depression', 'energise', 'energize', 'engrave', 'epidemic', 'epilation', 'erode', 'eruption', 'event', 'excite', 'execute', 'exit', 'exogenous_depression', 'expiration', 'expose', 'exteroception', 'extreme', 'fall', 'fallout', 'fear', 'fearfulness', 'feeler', 'figure', 'financial_loss', 'flaw', 'forfeit', 'forfeiture', 'frequency_response', 'fret', 'fright', 'frisson', 'frost', 'fulfil', 'fulfill', 'funk', 'fuss', 'get', 'going', 'grave', 'grievous', 'habitus', 'hard', 'harm', 'harvest', 'hasten', 'hazard', 'headache', 'health_hazard', 'heartsickness', 'helplessness', 'hit', 'hit_home', 'hole', 'hollow', 'horror', 'hurt', 'hydrolise', 'hydrolize', 'hypersensitivity', 'hypochondria', 'hypochondriasis', 'hysteria', 'image', 'impact', 'impair', 'impairment', 'impress', 'impression', 'incommode', 'inconvenience', 'incumbrance', 'induce', 'inebriate', 'infect', 'influence', 'ingrain', 'injure', 'inquietude', 'insecurity', 'instill', 'interest', 'interoception', 'intimidation', 'intoxicate', 'irruption', 'issue', 'jar', 'jaundice', 'jeopardize', 'jeopardy', 'jitteriness', 'jumpiness', 'knock-on_effect', 'knockout', 'ladder', 'lay_on_the_line', 'legal_injury', 'life-threatening', 'load', 'loosen_up', 'loss', 'low', 'low_spirits', 'lowland', 'major_depressive_episode', 'make_relaxed', 'mangle', 'mar', 'mark', 'materialisation', 'materialization', 'megrims', 'melancholia', 'melancholy', 'menace', 'misgive', 'misgiving', 'moral_hazard', 'mouse_click', 'move', 'mutilate', 'nag', 'natural_depression', 'nervousness', 'neurotic_depression', 'niggle', 'obsess', 'occupational_hazard', 'occupy', 'oceanic_abyss', 'offset', 'offshoot', 'offspring', 'onus', 'oppression', 'oppressiveness', 'outbreak', 'outcome', 'outgrowth', 'overanxiety', 'palsy', 'panic', 'panic_attack', 'paper_loss', 'paralyse', 'paralytic', 'paralyze', 'paralyzed', 'passing', 'perceptiveness', 'peril', 'perk_up', 'photosensitivity', 'pierce', 'placebo_effect', 'position_effect', 'precipitate', 'predisposition', 'process', 'product', 'psychotic_depression', 'put_on_the_line', 'put_out', 'qualm', 'queer', 'quiver', 'radiosensitivity', 'ravel', 'reactive_depression', 'reactivity', 'recrudescence', 'red', 'red_ink', 'redound', 'reducing', 're ...

# %% [markdown]
# ## Section 2: Generate a semantic vector map with word2vec

# %%
from gensim.models.word2vec import Word2Vec
import os
from os import path

## This function organizes corpus as list of sentences, and each sentence as a list of words,
## as input to the function WordVec

## Collect preprocessed texts in txt format
root_folder = os.getcwd()
print(root_folder)

## This will be a list of clean sentences
word2vec_input = []

## This iterates over your path, folders and subfolders looking for txt files
for path, subdirs, files in os.walk(root_folder):
    for file in files:
        if '.txt' in file and 'model' not in file:
            print(file)
            name = os.path.join(path, file)
        
            file_text = open(name, encoding = 'utf-8',errors='ignore').read()

            ## this creates the list of paragraphs - lines
            text_list_paragraphs = file_text.split('\n')

            ## this will clean the paragraphs further -- getting read of \r at the end of the line
            for paragraph in text_list_paragraphs:
                #print (paragraph)
                
                paragraph = paragraph.replace('\r', '')

                ## we add the paragraphs to the word2vec input list
                word2vec_input += [paragraph.split(' ')]
            
                #print(word2vec_input)
# Out:
# /content
# Santana-2020-wind glazing.txt
# chen etal-2010-Development of photovoltaic thermal.txt
# Dhahri etal-2021-effect of inlet outlet on thermal performa.txt
# pike and slater-2011-examination of their.txt
# law etal-2013-heat pump and an organic Rankine.txt
# Riffat etal-2013-experimental investigation.txt
# sahlot and riffat-2016-Desiccant cooling systems.txt
# alamier-2020- Synthesi.txt
# Embaye etal-2014-effect of flow pulsation.txt
# Jiang etal-2009-utilizing bent heat pipes.txt
# aleknaviviute-2016-Towards clean.txt
# hormazabal etal-2016-The performance.txt
# onyelowe-2019-Strength.txt
# herdt etal-2016-Newly invented biobased.txt
# Wang and Zhang-2021-Decision and coordination.txt
# sadeghzadeh-2021-novelexergy.txt
# Budania etal-2013-solar absorption.txt
# ahmed-2018-Design methodology.txt
# auid etal-2013-Organic Rankine cycles.txt
# Shilliday etal-2009-Comparative energy.txt
# man etal-2010-Operation.txt
# Zhang etal-2018-revolutio.txt
# kim-2013-the investigation of an openi.txt
# utlu-2019-Thermophotovoltaic.txt
# Chun etal-2008-novel thermodiode designs.txt
# Michel Gueldry-2018-Climate Change and public opinion.txt
# lv etal-2020-Theoretic analysis and.txt
# cruikshank-2011-economic.txt
# li etal-2021-Analysis of deep borehole heat exchanger with horizontal branch wells for building heating.txt
# gUPTA-2009-Moving towards.txt
# wood etal-2010-residential building.txt
# li etal-2012-Experimental study on the di.txt
# zhou-2009-thermocapillary.txt
# Bi etal-2009-Ecological.txt
# Zhang etal-2016-indoor air thermal.txt
# ranjan-2013-Economic.txt
# haghighi and maerefat-2014-Design.txt
# elbaiuomy etal-2017-The impact of architectural spaces.txt
# ouelhazi-2020-Parametric.txt
# Oleivera-2007-towards a renewable future.txt
# pandey etal-2011-Experimental.txt
# xiao-2012-reactive.txt
# onyelowe-2019-Experimental.txt
# jorge-2009-water absorption.txt
# yadav-2012-On the suitability.txt
# mempouo etal-2010-Code for Sustainable Homes.txt
# alsallal-2010-Daylighting and visual performance.txt
# hegazy etal-2021-Global trends in sustainabil.txt
# Azad-2008-Split heat pipe heat.txt
# whiffen-2012-Areview.txt
# xie etal-2008-Syngas CO.txt
# reay-2013-are the process industries.txt
# fhazali etal-2017-Feasibility of vertical photovoltaic system on high rise building in Malaysia.txt
# Reza-2021-heat gas pressure reduction.txt
# gharghani-2020-An experimental investigation into a novel.txt
# lv etal-2019-The prototype construction an.txt
# Newton etal-2011-nanoparticle.txt
# kan etal-2009-Ecological performance optimization.txt
# gordeeva etal-2012-Composites salt inside porous matrix for adsorption heat transformation.txt
# Arif etal-2012-exergy analysis.txt
# xiong-2021-Deep.txt
# liu etal-2021-Flame propagation and CO CO2 generation characteristics of lignite dust explosion in horizontal pipeline.txt
# birjandi etal-2021-Thermal conductivity.txt
# Sun-2020-water shed water pollution.txt
# awe etal-2021-Carbon management for savanna.txt
# alm-2020-Quantum chemica.txt
# harper etal-2019-Assessing socially.txt
# sampedro etal-2016-Spanish.txt
# Harrison and Jiang-2017-energy performance.txt
# zhao-2021-BIM.txt
# taha-2013-Meteorological.txt
# rad-2021-Thequantitative.txt
# climate-2004-migration.txt
# bANSAL-2009-evaporative cooling.txt
# liu and shan-2021-Research on ener.txt
# Aprea etal-2012-exergy an.txt
# rogers-2011-Hydrogen.txt
# zeinelabdein-2018-Free.txt
# shao-2021-Numerical.txt
# mehrabian-2010-wet heat exchangers.txt
# opubo-2013-Ahigh.txt
# chen etal-2012-Optimal expansion.txt
# oyieke-2020-Experimental.txt
# su etal-2010-feasibility.txt
# Liu etal-2021-dust propagation.txt
# pillai-2013-Study.txt
# aydin etal-2015-Numerical analysis of solar.txt
# JENKINS-2009-cooling loads.txt
# kiyota etal-2013-Analysis of greenhouse gase.txt
# Tao et al-2021-multimodal.txt
# spataru-2010-Domestic energy and occupancy.txt
# jareemit and canyookt-2020-Residential.txt
# alkhalidi etal-2020-Using Wood.txt
# chien-2014-Assessment.txt
# joshi etal-2010-Analysis of energy and exergy.txt
# fazeli and gillott-2013-Analysing the effects of seasonal variation on.txt
# lou etal-2021-A study of the s.txt
# gan-2015-Impacts of dynamic interactions on the predicted thermal performance of earth air heat exchangers for preheating, cooling and v.txt
# Dewanto etal-2021-greenhouse heating cooling.txt
# harikrishnan etal-2011-Effect of solution temperature and.txt
# chong-2013-Comparing.txt
# hegazy etal-2017-The living building.txt
# yangwang-2021-Information.txt
# elsayed etal-2013-Thermodynamic performance of Kalina cycle system.txt
# Busato etal-2008-cogeneration modules.txt
# chen and zhang-2021-Research on control.txt
# aldali-2011-Solar absorber tube analysis.txt
# soares etal-2018-Evaluation.txt
# jarimi etal-2018-Materials characterization.txt
# walnum-2011-Offdesign.txt
# varga-2013-Readdressing.txt
# ghalamchi etal-2016-Evolving ICA and HGAPSO algorithms for prediction of outlet temperatures of constructed solar chimney.txt
# bottarelli-2012-Numerical.txt
# annadurai etal-2018-Experimental.txt
# liu etal-2020- Study of the effect of surface wettability on droplet impact on spherical surfaces.txt
# Wang etal-2013-power and efficiency.txt
# Khandelwal etal-2007-hybrid photovoltaic.txt
# kilavuz and dogan-2020-Economic growt.txt
# Cooke etal-2013-biomass energy crop feasibility.txt
# Boukhanouf etal-2013-generation s.txt
# wuetal-2021-Research.txt
# Lulin Zhang-2021-solar intelligent vehicle.txt
# kumar etal-2019-A review status on alternativ.txt
# wu etal-2021-rapid harmonic detection method.txt
# bottarelli-2019-Testing of a dualsource heat pump.txt
# qiu-2012-Experimental.txt
# rogers-2012-Yawanalysis.txt
# farikhah-2020- The effect of mean pressure on the performance of a single-stage heat-driven thermoacoustic cooler.txt
# chen etal-2012-Internal.txt
# Mojtaba etal-2018-natural gas mgt in enhanced oil rec.txt
# worall-2011-CO2compression.txt
# gong etal-2012-Emissions and thermal efficiency investigation.txt
# Sikiru-2021-FarmerHerders.txt
# Mansour etal-2021-using sustainable dvt indicators.txt
# iwaro etal-2015-Validation of integrate.txt
# ding and riffat-2012-Thermochemical energy storage technologies for building applications.txt
# alyousef and varnham-2010-Saudi Arabia.txt
# chen etal-2018-Performance.txt
# woo etal-2009-The performance.txt
# zhaoetal-2021-BIM.txt
# chen-2018-Study on energy.txt
# zhong-2019-Technology.txt
# shang-2020-Ruralecotourism.txt
# tamer-2013-Optimization.txt
# Noro and Lazzarin-2017-heat pump system.txt
# ong-2016-Performance.txt
# abdul-2012-Mod.txt
# Rosemann and Kaase-2013-combined daylight.txt
# ning etal-2021-Research on flexible job shop scheduling.txt
# guo etal-2012-Numerical simulation of dynamics of droplet impact on heated flat solid surface.txt
# Zhen-2021-retrofit.txt
# eboka etal-2018-Detailed design and optimization of a sustainable micro algal biofuel process plant.txt
# Vasiliev etal-2009-efficiency of fuel cells.txt
# Barros etal-2013-land use.txt
# wang etal-2020-Study on.txt
# zhangetal-2017-Experimental.txt
# bert-2011-fuel cells.txt
# Ufuk etal-2021-Intelligent.txt
# Ajay-2009-simultaneous.txt
# molero mesa etal-2013-Towards the generation of distributed electric power.txt
# li and zhang-2020-Ecological efficiency.txt
# enayatizade-2019-Techno economic evaluation of a new CCHP system with a hydrogen production unit.txt
# lee etal-2020-Performance estimation.txt
# xiao etal-2010-retrofitted direct gain solar house.txt
# rossi-2012-Ethanol.txt
# bottarelli etal-2020-Solar gain.txt
# Zhao etal-2008-power and gas cogeneration.txt
# yali-2014-Simulation.txt
# Utlu and Onal-2017-waste heat recovery.txt
# Wang etal-2013-power and power density.txt
# ahmad-2016-Investigation of the ef.txt
# ling etal-2013-The numerical s.txt
# ong-2011-Experimental.txt
# sunetal-2019-Study.txt
# Tianyi et al-2021-building thermal system.txt
# zhangetal-2012-Study.txt
# tao etal-2009-congregation.txt
# ashley-2016-direct absorbing.txt
# wongwatcharapa-2019-filtrative.txt
# riffat-2011-Areview.txt
# gao etal-2018-Comparison of the solar PV cooling system and other cooling systems.txt
# zhangetal-2012-Gascleaning.txt
# xiaetal-2010-Ecological.txt
# feng etal-2010-Heating load and COP optimizations.txt
# wang and chi-2011-A laboratory.txt
# trevor-2016-Design.txt
# coskun etal-2009-Energy and exergy.txt
# dayma etal-2013-Energetic and exergetic analyses of a transcritical N2O heat pump system.txt
# jain and hindoliya-2016-Energy saving.txt
# shatat-2016-innovativepsychometric.txt
# cai and yan-2018-The plannin.txt
# Gennaro-2014-climatechangeAndRespiratory.txt
# wangetal-2020-Sound.txt
# zhao-2021-Performance.txt
# marchetti-2010-Production.txt
# bwapwa etal-2019-Jet fuel.txt
# Suyong et al-2021-Coevolutionary game.txt
# nygard-2012-Review.txt
# Zhang-2020-reconfigurable equilibrium.txt
# baral-2020-Thermodynamic and financial.txt
# papadak-2013-Aparametric.txt
# wangetal-2019-Research.txt
# hui and ma-2016-Analysis of environmental.txt
# alsallal-2018-Daylighting performan.txt
# zhangetal-2020-Discrete.txt
# gao etal-2010-concentrating PV modules.txt
# lin etal-2011-Ammonia water absorption cycle.txt
# filippeschi etal-2012-Feasibility of periodic thermosyphons for environmentally friendly ground source cooling applications.txt
# alshaibani and li-2021-Sky ty.txt
# neupane-2021-Optimal.txt
# Zurigat-2007-Typical.txt
# alexander-2013-solid sorption.txt
# hegazy-2020-Toward efficient energy con.txt
# wuetal-2018-Indoor.txt
# hegazy etal-2021-Assessment of urban growth of Jeddah.txt
# shakouri-2020-Thermodynamic.txt
# Varga etal-2009-cooling system.txt
# faisal etal-2021-Machine learning approach to extract building footprint from high resolution images.txt
# meng etal-2010-Multiobjective analyses.txt
# almutairi etal-2011-Cycling durability studies.txt
# ricci etal-2014-development.txt
# azad-2012-heat pipe heat exchanger.txt
# Lalzad-2013-desalination plant.txt
# zhaoetal-2021-Performance.txt
# Ibrahim etal-2009-analysis of sola.txt
# xu-2021-Pricing.txt
# fadeyibi etal-2020-Ecological footprint for environmental sustainability in Ilorin Metropolis, Kwara State, Nigeria.txt
# chen etal-2009-Research on ground coupled heat.txt
# shamsapour-2020-Developing.txt
# wang etal-2010-pyrolysis process of corn straw.txt
# sudprasert-2021-Study.txt
# Ge etal-2009-water absorption refrigeration system.txt
# Maheshwari etal-2009-performance analysis.txt
# abo-2012-Microaerobic.txt
# hemmingway and long-2012-Thermal re.txt
# yousefetal-2021-Perspective.txt
# wangetal-2019-Study.txt
# markus-2013-Advanced.txt
# Vivekh etal-2015-Desalination.txt
# elsayed etal-2014-Numerical investigation of turbulent flow heat transfer and pressure drop of AL2O3 water nanofluid in helically coiled tub.txt
# khzouz etal-2011-Characterization of Ni Cu based catalysts.txt
# dhindsa etal-2021-performance analysis of basin type vertical multiple effect diffusion solar still integrated with solar pond.txt
# wu etal-2010-thermoacoustic refrigeration.txt
# yang-2012-Performance.txt
# lee etal-2013-high rise.txt
# angrisani etal-2013-the influence of cooling air.txt
# zhangandwang-2020-Thermal.txt
# dakwale and ralegaonkar-2011-Review of carbon emission through buildings.txt
# yang-2020-policy.txt
# Mattheos Santamouris-2021-urban warning.txt
# li and dai-2019-Energy saving and emission reduct.txt
# klunne and michael-2010-Increasing sustainability of rural community.txt
# chow-2012-The potential.txt
# liu etal-2010-domestic biomass boiler under normal.txt
# Deependra etal-2021-microhydrop.txt
# Jorge and Armando C. Oliveira-2006-solar.txt
# tasi-2013-Control.txt
# qiu-2018-Numerical.txt
# ana etal-2010-Performance simulation.txt
# zhou-2012-Research.txt
# Yuanlong etal-2020-heating systems for.txt
# zhangandpeng-2021-Research.txt
# mohan etal-2011-Parametric studies on coupled columns of liquid desiccant.txt
# lisha etal-2018-Structural rec.txt
# Lazzarin etal-2008-electronic expansion valves.txt
# janchen etal-2012-Preparation, hydrot.txt
# gurler-2020-longterm monitoring.txt
# aaditya-2012-Climate responsive.txt
# maslennikov etal-2010-Advanced.txt
# li and liang-2018-The economi.txt
# Someren etal-2017-lighting performance.txt
# lee etal-2020-Experimental evaluations on the outdoor air.txt
# Yang etal-2013-ecobuilding.txt
# jiao and wang-2021-Shore power vs low sulfur.txt
# ferron etal-2011-custom design and application consequences in an office environment.txt
# sun-2014-Existing.txt
# Prabhakant etal-2009-evaluation.txt
# ma and riffat-2010-lat heat pipe.txt
# eloka and onunka-2020-Sustainable design of bagasse biomass flow reclamation control using bifurcated chute.txt
# shen etal-2013-Simulating.txt
# sawant-2011-Performance.txt
# li and shuan-2020-Research on freq.txt
# ali ahmadi-2016-Modeling solubility of carb.txt
# poese-2013-Performance.txt
# guo etal-2021-Design and performance experiment of radial inflow turbine expander for organic Rankine cycle system.txt
# zhangetal-2021- Co-evolutionary game.txt
# Kim etal-2009-cooling effect and potable water.txt
# Sultan etal-2020-vfa.txt
# zhangetal-2020-Capacity.txt
# jiang etal-2012-Current development o.txt
# abubakar-2021-corporate response.txt
# wangetal-2020-Research.txt
# Amit-2021-rooftop photov.txt
# li etal-2010-hybrid solar electricity system.txt
# zhangetal-2019-Effect.txt
# oliveira-2016-Anovel.txt
# hu etal-2016-Removal of carbon dioxi.txt
# chen and li-2021-Research on feature.txt
# Riffat etal-2007-direct ground coupled absorber.txt
# li-2020-Analysis on the monitoring system of energy conservation and comfort in office buildings based on internet of things.txt
# safira-2020-Thermal.txt
# Sudaporn-2021-water soaked.txt
# Lingen-2013-cycle.txt
# dien etal-2011-Biochemical processing of reed canarygrass into fuel ethanol.txt
# ranjan-2016-Energy.txt
# busato etal-2013-Multisource.txt
# lin-2021-Energy management strategy f.txt
# jouhara-2009-wraparound heat pipes in ventilation.txt
# xiang-2015-Optimization.txt
# esfahankalteh-2020-Achieving wind comfort through window design in residential building.txt
# Zhang-2021-dry capillary radiant.txt
# salman-2020-Thermal.txt
# Bozonnet etal-2013-urban fluxes.txt
# afrasiabian-2019-analysis.txt
# yunus-2021-Performance.txt
# alkhalidi etal-2019-Energy efficient cooling.txt
# Renato Lazzarin-2007-Technological innovations.txt
# Dongyue Xiao-2021-photovotaic grid.txt
# Bottarelli etal-2017-tile covering.txt
# shao etal-2015-Wireless Energy.txt
# rabah etal-2013-Experimental study of the urban.txt
# chen etal-2012-lessons learnt from an operating analysis.txt
# kler etal-2010-combined technology for production.txt
# meng etal-2010-Effects of heat reservoir temperatures.txt
# Santamouris-2008-built environment.txt
# zhu-2016-Performance.txt
# srinivas-2020-anal.txt
# hegazy and helmi-2020-Spatial monitorin.txt
# Tham etal-2009-clear sky radiation data.txt
# ong-2014-Reverseflow.txt
# li etal-2016-Performance study of a static low concentrati.txt
# Xiaoling-2021-mediating effect.txt
# zhang-2021-Resear.txt
# maciel etal-2013-The impact.txt
# colombo-2012-Carbon dioxide refrigeration with heat.txt
# javed and fahlen-2011-Thermal response.txt
# khennich etal-2013-Comparison of combined.txt
# sandhu-2011-Investigations.txt
# ding etal-2019-Comparison work about different empirical formulas.txt
# sabitha-2011-global.txt
# Iwaro etal-2014-assessment design.txt
# ascione etal-2016-Design.txt
# wu etal-2011-Hydrogen.txt
# wangetal-2013-Failure.txt
# wangetal-2014-Feasibility.txt
# Mamdouh-2021- exergoenvironmental analyses.txt
# yuan_etal-2021-Investigatio.txt
# sicre-2015-Highefficiency.txt
# Reddy-2009-low carbon buildings.txt
# kartal and oncel-2013-Comparison of sustainable information technologies for companies.txt
# chen etal-2016-Modeling.txt
# jiang etal-2013- Design and performan.txt
# shang etal-2016-Hybrid hydrogen.txt
# Ali-2021-carbon emission.txt
# zhou-2018-Optimization analyses.txt
# igbum etal-2019-Feasibility stud.txt
# redpath-2014-evacuated.txt
# maheshwari-2009-Performance.txt
# ramadan etal-2016-Analysis.txt
# Adrian-2020-OECDCountries.txt
# jradi and riffat-2012-Medium temper.txt
# reay-2015-Thermal energy storage.txt
# chen etal-2012-Constructal.txt
# ratlamwala-2012-Comparative.txt
# zhu-2012-Asimulation.txt
# marquiz-2013-analysis.txt
# shusheng-2020-lattice.txt
# mohamed etal-2011-Exploring the adoption of low carbon technologies by Scottish housing associations.txt
# zhangetal-2013-Theoretical.txt
# ebhota and tabakov-2018-The place of small hydropower electrification scheme in socioeconomic stimulation of Nigeria.txt
# fang etal-2012-Characterization and performance of novel.txt
# hsieh and cheng-2020-Effects o.txt
# petra-2010-advancedzero.txt
# zhan-2010-Numerical.txt
# lin-2016-Stratum ventilation a low c.txt
# petra etal-2010-advanced zero emission plant.txt
# assad-2020-Renewable.txt
# Yee Chow-2009-zero carbon targets.txt
# Allison-2014-thermal energy storage.txt
# jan etal-2013-climate necessity.txt
# buyagbie etal-2012-Conceptual design.txt
# imam etal-2021-An automatic.txt
# Riffat etal-2013-thermodynamical cooling sys.txt
# alayietal-2020-Technical and environmental.txt
# Spencer-2007-predicting light pipe transmittance.txt
# shao-2019-Geological.txt
# rezaei-2018-Applying.txt
# Du etal-2017-impact of blades wrap energy.txt
# cuce and cuce-2013-Theoretical investigation of hot box solar coo.txt
# kan etal-2010-Exergoeconomic performance.txt
# bardineh etal-2018-Medical.txt
# ong-2016-Review.txt
# tham-2011-Energy.txt
# patodi-2012-Performance.txt
# qi-2020-EER.txt
# amhadi and assaf-2019-Assessment.txt
# Daniel C. Staley-2013-urban forests and solar power.txt
# zhaoetal-2009-Dynamic performance.txt
# omar and shaari-2009-Sizing verification.txt
# sakhri-2021-Therma.txt
# Gupta and Chandiwala-2009-Sustainable Homes in the UK.txt
# qian-2021-Air.txt
# Chamchine etal-2013-integrated assesment.txt
# Song-2020-coal dust.txt
# liu etal-2012-Analysis on the development prospect of natural gas utilization in Shenzhen.txt
# Cuimin etal-2020-energy conservation.txt
# yang-2021-Application.txt
# mohan etal-2009-The performance simulation of air cooled.txt
# wangetal-2012-Thermal.txt
# arslan-2013-Characterization.txt
# Andrea and Francis-2020-tropical climate.txt
# chu etal-2020-Effects of stripper.txt
# victor-2013-loop heat.txt
# you-2020-Influences.txt
# Jorge etal-2008-cogeneration ORC system.txt
# lee etal-2013-Rooftop photovoltaic (PV) systems.txt
# assad-2021-Energy and exergy analyses of singl.txt
# liang and shi-2020-Efficiency evaluation and optimiza.txt
# hegazy and qurnfulah-2020-Thermal comfo.txt
# zishang-2012-Assessment.txt
# zeng-2012-Problems.txt
# varo-2013-Design.txt
# maleki-2018-Modeling and optimum design.txt
# tu-2020-Comparative.txt
# Davies etal-2013-seawater.txt
# zhu-2020-The influence.txt
# gago etal-2010-irradiation and temperature, and.txt
# zhai-2016-Sensitivity.txt
# cuce and cuce-2013-Optimization.txt
# hegazy etal-2017-Towards green cities in developing countries.txt
# Benedict-2021-neocorporatism.txt
# Renato etal-2013-life cy.txt
# jiang etal-2010-solar thermosyphon systems.txt
# ONG-2016-Reviewofsolar.txt
# ramezanizadeh-2019-Modeling.txt
# avgerinos -2013-Computational study.txt
# kumar etal-2020-The role of nanot.txt
# oleg-2010-autonomous energy systems.txt
# yan etal-2020-energy.txt
# varga-2017-Ontheselection.txt
# Zarqa-2021-Climate.txt
# Karlessi etal-2013-thermo.txt
# darkwa and fraser-2012-Performance of an integrated solar absorption cooling system.txt
# Comarazamy etal-2013-impacts of urb.txt
# Abu-2009-compression.txt
# tuetal-2021-Experimental.txt
# lazzarin and noro-2016-Energy efficiency.txt
# li and wu-2021-The impact of social norms.txt
# afonso-2013-Tracer gas.txt
# shatat-2015-retrofitting.txt
# chen and li-2020-A state of art meth.txt
# elmer etal-2016-Experimental evaluation of a liquid.txt
# li etal-2019-Effect of design parameters on thermal performance of integrated phase change material blind system.txt
# mumith-2016-Design.txt
# xiangetal-2021-Perceived.txt
# knez etal-2014-A sustainable transport solution for a Slovenia town.txt
# cakir-2021-Anew approach.txt
# hagazy etal-2021-Global trends in sustain.txt
# hamdy etal-2010-simulation based optimisation.txt
# RIA JHOANNA-2021-adaptations.txt
# Ciampi etal-2013-energy performance.txt
# nwanya-2011-Climatechange.txt
# Gao etal-2013-A comparative study of carbon footprint and assessment standards.txt
# veselov-2010-Impact.txt
# aldali-2011-energetic.txt
# Renzato etal-2007-system based on water.txt
# lau etal-2012-A preliminary study o.txt
# mattera etal-2018-Online Energy Simulator.txt
# Zhan-2021-source load frequency.txt
# yang-2012-heat.txt
# lin etal-2018-Experimental study on im.txt
# Ibrahim Rizk Hegazy-2020-nano aerogel glazing.txt
# feng etal-2013-Constructal optimization of a disc shaped body with cooling.txt
# reinoso-2012-Study.txt
# kong etal-2020-Optimal design of the solar tracking system of parabolic trough concentrating collectors.txt
# whiffen-2012-review.txt
# cho etal-2014-Energy.txt
# mojahedi etal-2020-Designing p.txt
# Avil and David-2021-Carbon storage.txt
# Djongmo et al-2021-Carbon management.txt
# buyadgie etal-2015-Solar low.txt
# abdelal-2021-Floating an assessment.txt
# akyuz-2010-Energetic.txt
# chung and ju-2010-A hybrid design of VAWT.txt
# An etal-2014-Efficiency of household.txt
# shan etal-2021-impact.txt
# ghabra etal-2017-The impact of the building envelope on the energy efficiency of residential tall buildings in Saudi Arabia.txt
# Qing-2021-storageicrogidr m.txt
# li etal-2016-Thermal analysis of PCM filled glass windows in hot summer and cold winter area.txt
# georges etal-2013-Design of a small scale organic Rankine cycle engine used in a solar power plant.txt
# Khaled Saleh-2008-Chilean climate.txt
# Vasiliev etal-2008-activated carbon.txt
# corberan etal-2018-Dual source.txt
# Christian etal-2009-predictingdomestic.txt
# varga-2010-Comparison.txt
# yu-2018-Theeconomic.txt
# Kan and Hu-2015-composite building.txt
# chen etal-2012-Thermodynamic.txt
# abedi-2021-Investigating.txt
# sicre-2015-High.txt
# peng-2021-Thefuture.txt
# qingyang-2020-Energy.txt
# gupta etal-2019-analysis of hydrogen enriched compressed natural gas.txt
# ahmadi-2020-Portfolio optimization.txt
# luo etal-2019-Efficient optimized desig.txt
# malakhov-2010-Economic.txt
# tantasavasdi-2020-Impact.txt
# Ashouri etal-2015-organic rankine cycle.txt
# luo etal-2018-Performance of rock soil slope reinforcemen.txt
# Ufuk-2021-intelligent energy optimization.txt
# niu etal-2010-Experimental study on a CO2.txt
# wangetal-2021-Novel.txt
# Boncini etal-2008-Double Light Pipe.txt
# oralli-2011-study.txt
# fu etal-2009-co2 emission.txt
# yandri-2018-Uniformity.txt
# alkhalidi-2020- Do green buildings.txt
# gokce etal-2021-Intelligent energy optimization system development and validation for German building types.txt
# agyeni-2012-Experimenta.txt
# d'alessandro etal-2016-Innovative concretes for low carbon constructions.txt
# Reddy etal-2016-Nanofluid and nanocomposite.txt
# Hessami-2008-rural residential building.txt
# chen etal-2016-Theoretical.txt
# wang-2021-Study.txt
# Shanmugapriya etal-2018-solar linear fresnel.txt
# Fan etal-2018-cooling load prediction.txt
# Amanda Sabo-2016-impacts and response.txt
# ning-2021-Study.txt
# Yanglux-2021-lowcarbon.txt
# suetal-2018-Nanosilicon.txt
# feng etal-2010-steady-flow endoreversible heat.txt
# kalogirus-2013-Building integration.txt
# Zhuetal-2020-aerolastic.txt
# shattat-2012-Water.txt
# Zhang etal-2017-liquid dessicant cycle.txt
# rahbar-2016-miniature.txt
# Lazzarin-2007-Solar cooling plants.txt
# hundt and reddy-2011-Algal biodiesel product.txt
# Jarimi etal-2018-solar thermal.txt
# ana etal-2019-Energy assessment.txt
# zhoul-2021-Astudy.txt
# Zhezhi-2021-luminescent.txt
# Tufail-2020-confined rubberized concrete.txt
# indartono etal-2016-Improving photovoltaics.txt
# li and zhang-2020-Developing the tran.txt
# jradi-2014-Micro scale ORC based.txt
# wangabdullah-2011-Investigating.txt
# Liqiang etal-2021-frequency tracking.txt
# xiao-2021-Frequency.txt
# onyelowe-2019-Recycling.txt
# harjunowibowo etal-2021-Experime.txt
# rady-2021-Design.txt
# sahu-2017-parametric.txt
# zhou-2020-Cross.txt
# Zheng-2018-solar.txt
# Tangka etal-2013-asorption solar.txt
# Dunia E. Santiago-2021-Energy use in hotels.txt
# khoshbazan etal-2018-Thermo economic analy.txt
# zhang-2020-Res.txt
# wang-2019-Performance.txt
# zhaoetal-2021-Performance charact.txt
# jarimi etal-2020-Review of sustainable method.txt
# song-2013-Control.txt
# wang-2014-Performanc.txt
# mukherijee-2012-Estimation.txt
# kosa-2020-Dynamic and steady state analysis of steam reforming of methane to hydrogen.txt
# kokogiannakis-2012-Impact of material surface.txt
# lazzarin etal-2018-Hybrid PCM aluminium foa.txt
# paine-2018-Evaluating.txt
# Chen and Zhang-2021-energy storage system.txt
# wu etal-2011-Prediction.txt
# wu-2021-Decision.txt
# li etal-2016-feasible energy saving analysis.txt
# hyde etal-2016-Developments in the quality of treated greywater.txt
# mehrpooya etal-2021-A novel hybrid.txt
# wangetal-2012-Superhydrophobic.txt
# Ma etal-2008-side emitting.txt
# gurler etal-2018-Experimental investigation.txt
# almosawi-2020-Synergistic effect of.txt
# ikedi etal-2016-Numerical asse.txt
# ahmadi-2016-Thermodynamic anal.txt
# busato etal-2012-Energy and economic.txt
# Rattanongphisat-2008-Thermal separation.txt
# lu and chen-2019-Numerical study on hea.txt
# podder-2021-Integrated.txt
# li and chen-2021-A design of low.txt
# khodaee etal-2019-Assessment of the level.txt
# saad-2019-Numerical.txt
# altinkaynak-2021-Exergetic pe.txt
# huang and tang-2021-Estimation of.txt
# mortazavi etal-2019-Analysis.txt
# barrubeeah-2021-Design.txt
# yi etal-2009-atriums in subtropical climate.txt
# Ma etal-2008-microencapsulated phase.txt
# wang etal-2010-intercooled.txt
# zhao-2014-Calculations.txt
# chen etal-2010-An experimentaL.txt
# sharma-2021-Economic.txt
# rao-2013-Analysis.txt
# Liu etal-2009-comparative study.txt
# wang etal-2021-Study of chemical looping.txt
# Vivien etal-2021-Heat Waves.txt
# alwetaishi-2019-Sustainable ap.txt
# renato etal-2009-Energetic and economic savings.txt
# Mohammad etal-2020-wind farm.txt
# symes-2013-enhanced.txt
# BarbierAndHochard-2010-CCandSocialEquality.txt
# bensebaa etal-2016-potential application for solar thermal absorber.txt
# alqahtani-2020-Building enve.txt
# Zhang etal-2015-heat transfer of energy.txt
# zhang etal-2012-sordption.txt
# maher etal-2021-Effect.txt
# zhangetal-2017-Annual.txt
# fritschi etal-2016-Efficiency increase in carbon dioxide refrigeration technology with parallel compression.txt
# huang etal-2020-Comparative investig.txt
# alayietal-2021-Energy analysis of vacuu.txt
# sukarno-2020-Multistage.txt
# zhangetal-2019-Research.txt
# wajid-2019-Review.txt
# moustafa etal-2018-Roof geometry.txt
# Ning-2021-decarbonization.txt
# liu etal-2013-Analysis of factors affecting CO2 emissions by civil buildings in China's urban areas.txt
# jian yao-2012-Effect of variable ventilation modes on.txt
# xiao-2021-Frequencyconversion.txt
# Rojas-2013-Atrium building design.txt
# eicker and klein-2012-Large scale renewable energy integration within energy efficient urban areas.txt
# TiezhouWu etal-2020-coordinated control.txt
# jahnke etal-2013-First cycle simulations of t.txt
# ciampi etal-2014-energy and economic analyses.txt
# zhangetal-2018-numericalinvestigation.txt
# ma etal-2019-A study on condensation simulation for.txt
# Mudie etal-2013-comercial kitchen.txt
# zhangetal-2018-Theimpact.txt
# wang etal-2021-Novelphase.txt
# tolooiyan-2012-preliminary.txt
# fang etal-2017-Experimental investigation of evacuated heat pipe solar collector efficiency using phase change fluid.txt
# abdel-2013-Ski.txt
# jarimi etal-2018-Materials characterizatio.txt
# assad etal-2021-Energy.txt
# burhan etal-2018-Energy distribution.txt
# shuai-2018-Whatdo.txt
# oyieke-2018-Interfacial.txt
# vadodaria-2012-Inuseenergy.txt
# wang-2017-Microstructure.txt
# awogbemi etal-2019-Comparative stud.txt
# Yuan etal-2021-green ecological residential.txt
# kumar and reddy-2012-energy exergy environment.txt
# zhang etal-2010-performanc.txt
# wuetal-2020-Application.txt
# agrawal-2011-Flow characteristics.txt
# ivanova-2014-3D analysis of the incident diffuse irradiance.txt
# Igunnu etal-2012-Produced water treatment technologies.txt
# papoyan-2021-Energy.txt
# Lazzarin-2007-absorption chillers.txt
# awogbemi etal-2020-Optimization of FAME.txt
# Laseinde and Ramere-2018-vertical support.txt
# ahmadi-2016-Applying.txt
# tang-2021-compound.txt
# soares etal-2018-Evaluation of the performance.txt
# santiago-2021-Energy use in hotels.txt
# Yolanda-2020-determining.txt
# alayietal-2020-Energy.txt
# wei-2014-CatalyticCO2.txt
# inyang and lokhat-2020-Reactive extraction of propionic acid.txt
# liu and wang-2021-The impact.txt
# Lazzarin etal-2013-annual air conditioning.txt
# lim etal-2013-Design config.txt
# climate and dis-2015-disease.txt
# huang etal-2011-Design analysis of a F.txt
# bouaid etal-2012-Optimization.txt
# altan etal-2019-An experimental study roof.txt
# ning-2021-Logistics.txt
# zhang-2012-Enhanced Hea.txt
# lv etal-2020-Non uniform sizing of PV cells.txt
# liu etal-2020-Analysis of the influencing mechanism of command and control instruments on adopting energy consumption monitoring technol.txt
# Prabhakant etal-2009-Energy payback time.txt
# Lee etal-2017-Cooling combinations.txt
# ghazali-2017-Feasibility of a vertical photovoltaic system on a high rise building in Malaysia.txt
# lian etal-2016-Simultaneous synthes.txt
# kesten etal-2010-daylight performance.txt
# li and yang-2010-Energy and exergy analysis.txt
# oliveira-2017-GHG.txt
# gokce etal-2021-Economic, social and environmental impact analysis of an indigenously developed energy optimization system for German of.txt
# climate-2015-change.txt
# teixeira-2010-Temperature.txt
# madvar etal-2018-Analysis.txt
# Yang and Yutong-2007-photovoltaic application.txt
# liao and wang-2012-Performance based lo.txt
# sun-2019-Investigation.txt
# mccarthy-2011-Comparison of the perfor.txt
# wuxiong-2014-Passive.txt
# orhan etal-2011-Exergy analysis of heat exchangers.txt
# Gupta-2009-Sustainable energy technologies.txt
# stafell-2011-Lower carbon cars by reducing dissipation.txt
# aleknaviciute-2012-Plasma assis.txt
# riffat and qiu-2011-A review.txt
# Mohan etal-2008-air cooled hydrogen storage.txt
# du-2011-electroca.txt
# rao-2012-Thermodynamic.txt
# oyieke-2019-Multilayered.txt
# kizilors and aydin-2020-Effect of therm.txt
# michelle bottarelli-2013-A preliminary testing of a flat panel ground heat exchanger.txt
# xiaoandwu-2021-Dischargecurve.txt
# kasaeian etal-2017-Investigation of the eff.txt
# Barnwal etal-2008-thermal greenhouse dryer.txt
# Vakilabadi etal-2018-renewable power gen.txt
# pilpola-2019-Energy.txt
# mahmood etal-2019-Energy.txt
# Zisisetal-2006-heat.txt
# jorge and oleivera-2010-linear Fresnel solar collector.txt
# john raftery-2009-Sustainable energy technologies.txt
# rodrigues-2016-Investigating.txt
# Ernest-2008-sun spot related climate variations.txt
# Baljit etal-2020-performance study.txt
# Fan etal-2017-intermittent supply.txt
# Birnie etal-2013-effective air purification.txt
# ji etal-2014-Approach of a solar buil.txt
# maher etal-2021-Effectof.txt
# serran-2016-Rammed.txt
# tiwari-2019-Entrans.txt
# alqahtani-2019-The effect.txt
# xia-2016-Endoreversible.txt
# goshayeshi and chaer-2016-Comparison of copper and glass oscil.txt
# baitule and sudhakar-2017-Solar powered green campus.txt
# valdiserri-2018-Evaluation.txt
# Guo etal-2018-Surrounding rock control.txt
# Amanda-2016-Water Sensitive Planning Practices.txt
# maparanyanga and lokhat-2021-Modelling.txt
# baral-2020-Mathematical.txt
# wang etal-2020-equalization.txt
# raj-2020-Design.txt
# Jaeryoung et al-2021-Exploring the feasibility.txt
# bhattacharyya etal-2010-adiabatic capillary tube in a transcritical CO2 system.txt
# iwaro etal-2014-An integrated approac.txt
# han etal-2021-Experimental comparison.txt
# li etal-2019-low power data transfer and fusion algorithm for building energy consumption monitoring.txt
# avgerinos-2016-Effect.txt
# agrawal-2012-Study.txt
# avgerinos etal-2016-Experimental stu.txt
# rodrigues-2013-Anovel.txt
# ayou etal-2013-Analysis.txt
# riffat-2017-Overview.txt
# jasen and marchetti-2012-Kinetic study of.txt
# Vivek-2008-energy and exergy.txt
# wangetal-2019-Fault.txt
# Chen etal-2008-constructional entransy.txt
# anestopoulou etal-2016-On the development.txt
# steve-2011-Hydrogen.txt
# yadav etal-2020-Sustainable green campus in NEPAL.txt
# graham etal-2012-Degradation of biomass fuels during artificial storage in a laboratory environment.txt
# cuce and riffat-2016-A comprehensive assessment of sectoral energy.txt
# ismail-2012-energy eff.txt
# srivastav etal-2009-energy.txt
# atmaca etal-2021-CFD analysis.txt

# %%
len(word2vec_input)
# Out:
# 964809

# %%
## Here we build the vector space with Word2Vec

SentenceCorpus = word2vec_input
word2vec_output = Word2Vec(SentenceCorpus, min_count=1)

# %%
## Save vector space

word2vec_output.save('climate_w2v_model.txt')

# %% [markdown]
# ## Section 3. Use the vector semantic map to evaluate if the bags of words created in section 1 are ecologically valid

# %%
###  funtion to use word2vec to inquiry about the 10 most similar semantically words to each seed word in word_list

def get_word2vec_list(word_list,model):

  list_of_word2vec_lists = []
  for word in word_list:
    try:

      ## here is the crucial line - we are using the model that we trained to get the most similar words within our corpus
      list_vects=model.wv.most_similar([word],topn=10)

      new_list = []
      new_list +=[word]
      for item in list_vects:
        word1 = item[0]
        new_list += [word1]

      #print(new_list)
      #print('\n')
      list_of_word2vec_lists += [new_list]


    
    except KeyError:
      continue
  return(list_of_word2vec_lists)

# %%
## open vector space for english in the early modern period
model = Word2Vec.load('climate_w2v_model.txt')

# %%
## get word2vec list of 10 most similar words for the climate bag of words

list_of_climate_w2v = get_word2vec_list(climate_list,model)

index =0
for w2v_list in list_of_climate_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['acclimation', '60-day', 'INPUT', '–5', 'Tgo', '2−y', 'Column', 'Layout', 'isopentane)', '403', 'MATHEMATICAL']
# 1 ['acclimatisation', 'preparation', 'accountability', 'community-based', '(OAC)', 'Yjt—flows', 'contingency', 'arrangements', 'PERN.', 'design—professional’s', 'Statutes']
# 2 ['adaptation', 'mitigation', 'policies', 'strategies', 'investments', 'policy', 'implementation', 'planning', 'measures', 'policies,', 'implementing']
# 3 ['adaption', 'adaptation', 'foster', 'materialize', 'impetus', '‘information', 'community’s', 'adaptation,', 'intentional', 'obstacle', 'responding']
# 4 ['adjustment', 'encroachment', 'inertia', 'incentive', 'determining', 'estimation', 'equilibrium', 'consistency', 'transformation', 'expansion', 'dynamic']
# 5 ['air', 'water', 'air.', 'airflow', 'desiccant', 'indoor', 'air,', 'groundwater', 'evaporation', 'outdoor', 'liquid']
# 6 ['area', 'area,', 'floor', 'region', 'roof', 'length', 'zone', 'area.', 'wall', 'south', 'size']
# 7 ['arena', 'Ebinat', 'forests.21', 'Bottiere-Chenaie', 'discussion,', 'Observatory;', 'open-air', '2-D', 'Bs.As.,', '2001-02,', 'anti-Semitic']
# 8 ['atmosphere', 'atmosphere,', 'gases', 'oceans', 'ice', 'dioxide', 'evaporation', 'sunlight', 'ammonia', 'snow', 'exhaust']
# 9 ['autumn', 'isochoric', 'overcast', '8-h', 'semiconductor,', 'anti-Semitic', 'interminable', 'erroneous', 'spotty', 'harvest—are', 'highway']
# 10 ['background', 'discussion', 'representation', 'interpretation', 'identification', 'methodology', 'quantitative', 'scientific', 'mapping', 'literature', 'language']
# 11 ['boil', 'evaporate', '71◦', 'regenerate', 'circulate', 'preheat', '(Dhreheat)', 'transferred', 'attached', 'fetch', 'pumped']
# 12 ['circumstance', 'stratum.', 'abstract', 'reason.', 'RD', 'details:', 'seemingly', '(MDI).', 'non-retrogressive,', 'huge,', 'fragmented']
# 13 ['cold', 'hot', 'humid', 'warm', 'dry', 'ground', 'wet', 'winter', 'summer', 'tank', 'condensation']
# 14 ['conditions', 'conditions,', 'condition', 'conditions.', 'parameters', 'pressures', 'patterns', 'zones', 'occupants', 'zone', 'locations']
# 15 ['context', 'absence', 'situations', 'nature', 'addressing', 'scope', 'migration,', 'importance', 'recognition', 'mobility', 'aftermath']
# 16 ['dehumidify', 'illuminate', 'moist', 'purificative', 'pre-heat', 'weaken', 'humidify', 'condense', 'dehumidifying', '[244].', 'degrade']
# 17 ['dehydrate', '(LiCl)', 'gel-water', 'Aluminum', 'polyvinyl', 'Russ', 'fume,', 'silicate', 'electroless', 'gel/molecular', '(LiBr)']
# 18 ['deluge', 'rivalling', 'Bhawani', 'Middlesex', 'ca5162en.pdf.', 'communauté', '21:00', 'Vivien', 'Abdur', 'Threatens', 'jaal']
# 19 ['desiccate', '1983;26:231–', 'Temp.', 'selfassembled', 'g/m2', 'monolayers', 'HUMOR10,', 'degree(◦', 'org/10.1073/pnas.1816020116.', 'bulbs.', 'K21)']
# 20 ['differentiation', 'extension', 'barrier', 'desire', 'object', 'frame', 'representation', 'choice', 'route', 'fit', 'rationale']
# 21 ['domain', 'blade', 'rotor', 'mesh', 'direction', 'location', 'characteristic', 'chamber', 'variable', 'gradient', 'motion']
# 22 ['domestication', '(0.26', '(aluminium),', '1252', 'edible', 'relatives,', 'out-of-control', '(CH3CHO', 'weight/ml)].', 'Cheery', '2-intensive']
# 23 ['downfall', 'Armando’s', '2011;3:67–86.', 'irritation,', 'Pin,a', 'infestation,', '$/GJ', '\x00m\x002\x001\x00m\x00-\x001\x00', 'soon,', 'beef,', 'Kongarchapatara']
# 24 ['downpour', 'Malley', 'would,', 'Gabr', 'hh33−h', 'Belhamel', 'McKinney', 'Alvina', 'objections.', 'Morrissey,', '(2°C)']
# 25 ['drought', 'storm', 'severe', 'droughts', 'flooding', 'floods', 'drought,', 'storms', 'devastating', 'cyclones', 'rainfall']
# 26 ['dry', 'wet', 'warm', 'cold', 'winter', 'summer', 'hot', 'rain', 'rainy', 'ice', 'snow']
# 27 ['ecology', 'Root', 'treaties,', '\x0cAssessment', 'economics,', 'x)U12', 'Framing', 'Prevalence', 'Settlement', 'Ontology', 'disorganized']
# 28 ['ecosystem', 'marine', 'biodiversity', 'agricultural', 'resource', 'agriculture,', 'biological', 'ecological', 'ecosystems,', 'infrastructure', 'ecosystems']
# 29 ['element', 'component', 'geometry', 'principle', 'characteristic', 'structure', 'parameter', 'type', 'arrangement', 'dimension', 'configuration']
# 30 ['elements', 'components', 'features', 'shapes', 'dimensions', 'parameters', 'functions', 'variables', 'categories', 'types', 'configurations']
# 31 ['environment', 'environment,', 'environment.', 'climate,', 'nature', 'spaces', 'infrastructure', 'ecological', 'long-term', 'environments', 'environments,']
# 32 ['environs', '(EMF)', 'entirety.', '0.16/', 'brethren', 'thick;', 'simplicity;', 'Asbestos', 'specializations', 'homes)', '−0.4,']
# 33 ['fall', 'occur', 'reach', 'happen', 'disappear', 'move', 'survive', 'devolve', 'deteriorate', 'turn', 'remain']
# 34 ['field', 'laboratory', 'core', 'measurement', 'geometry', 'series', 'testing', 'test', 'direction', 'Rhino;', 'location']
# 35 ['firestorm', 'Gatlinburg,', 'Tenn.,', '70-cm', 'Tocantins,', 'oils:', '1493,', 'reduzir', 'paper/', 'Tsunami)', '15-W']
# 36 ['flashpoint', 'alliancebuilding', "Protocol's", '1-2%', '(298.15–', 'interconnections', 'wheel)', 'interpolated', '1990-1992', 'wedged', '5.2–5.8']
# 37 ['flood', 'flooding', 'vegetation', 'drought,', 'storm', 'river', 'heavy', 'forest', 'acute', 'coastal', 'fire']
# 38 ['flow', 'airflow', 'mixing', 'flows', 'evaporation', 'dehumidifier', 'turbulent', 'transfer', 'evaporator', 'liquid', 'channel']
# 39 ['force', 'return', 'flows', 'turn', 'reaction', 'drive', 'expansion', 'shape', 'formation', 'cover', 'movement']
# 40 ['habitat', 'biodiversity', 'erosion', 'fish', 'deforestation', 'desertification,', 'injuries,', 'ecosystems,', 'salinity', 'noise', 'erosion,']
# 41 ['hailstorm', '1.001)', '2388', 'TCD', 'I_b}', 'Ẇpump2', '(Tsec', 'Ẋ', 'b19', '\x03TPinch,VG', 'θt']
# 42 ['harvest', 'family’s', 'lost', 'off', 'home', 'eat', 'homes', 'selling', 'feed', 'house', 'running']
# 43 ['heat', 'sensible,', 'finite-heat', 'heat,', 'rock)', 'Heat', 'heat.', 'counterflow', '2017;157:462–76.', 'cooling', 'mass']
# 44 ['home', 'family', 'village', 'homes', 'families', 'staying', 'sold', 'home,', 'nearby', 'harvest', 'shelter']
# 45 ['inundate', 'intensify', 'confine', 'deltas', 'handle', 'accommodate', 'sustain', 'out-migration,”', 'flee', 'weaken', 'front-line']
# 46 ['inundation', 'prolonged', 'degraded', 'wildfires,', 'pastoral', 'blooms', 'Mid-West,', 'fires,', 'landslides', 'intrusion', 'mangrove']
# 47 ['landslide', '95447', 'sonic,', 'Desert,', 'mg21', 'fitting,', 'decrement', 'Européen', 'PCM-façade', 'fell—', 'namely;']
# 48 ['medium', 'uniform', 'bed', 'barrier', 'catalyst', 'reservoir', 'PCM', 'space', 'low', 'soils', 'stable']
# 49 ['mercury', 'polypropylene', 'sodium', 'kg/s)', 'detached)', 'Formation', 'slotting', 'Function', 'PMF', 'prefermenter', 'ammonium']
# 50 ['milieu', '(Solar', 'Hodge', 'Luther', '(embodied', 'JLM.', 'saving;', 'Þ0:8.', 'Storage;', '(MEPCM', '1995;55:389–']
# 51 ['monsoon', 'season,', 'winter', 'droughts', 'heatwaves', 'rainy', 'seasons', 'hurricanes', 'prolonged', 'summers', 'storm']
# 52 ['natural', 'geological', 'direct', 'oil', 'weather-related', 'forest', 'biological', 'nature', 'climate-related', 'damage', 'physical']
# 53 ['orbit', 'flows', 'atmosphere', 'atmosphere,', 'sunlight', 'liquid', 'radiative', 'groundwater', 'injected', 'formation', 'droplet']
# 54 ['outpouring', 'nationhood,', '0.296', '[…]', 'childhood.', 'Konya.', '(J/g', 'drought.”', 'people.”', 'Ngaoundere.', 's−1).']
# 55 ['overflow', 'kill,', 'AA)', 'displace', 'sidewall', 'subvert', 'Highways', 'deteriorate', 'freeze', 'inflict', 'tarnish']
# 56 ['oversupply', 'crack', '“orange”', 'climate-boosted', 'tarp', 'abdomen,', 'throughout.', 'climate-security', 'presidency.”', 'Pinterest', 'condense']
# 57 ['parch', 'shrivel', 'swell', 'Greenland,', 'intrusion,', 'acidify', '(Iowa,', 'erosion).', 'monsoons,', 'farmlands;', 'Caldor']
# 58 ['parts', 'regions', 'cities', 'regions,', 'cities,', 'De-construction', 'region', 'Montserrat.', 'areas', 'cases', 'locations']
# 59 ['precipitation', 'rainfall', 'pollen', 'rainfall,', 'Arctic', 'melting', 'snow', 'precipitation,', 'droughts', 'temperatures,', 'ice']
# 60 ['rage', 'stadium', 'liters/year', 'parrots', 'painted', 'sack', 'purple', 'soccer', '"Jingles"', 'frontier,', 'hamlet']
# 61 ['rain', 'ice', 'storm', 'snow', 'season', 'dry', 'heavy', 'melting', 'rainfall', 'rains', 'storms']
# 62 ['rainfall', 'precipitation', 'droughts', 'ocean', 'snow', 'ice', 'rainfall,', 'melting', 'floods', 'pollen', 'Arctic']
# 63 ['rainstorm', 'A4;', 'emission)', '\x00t\x002\x00r\x001\x00b\x00\x03s\x001\x00\x03s\x002\x00\x03s\x003\x00\x03E\x00V\x00A\x00\x03P\x00V\x00', '\x00r\x002\x00f\x00r\x002\x00b\x00\x03s\x001\x00\x03s\x002\x00\x03s\x003\x00\x03E\x00V\x00A\x00\x03P\x00V\x00', '\x00N\x00i\x00s\x00h\x00i\x00o\x00k\x00a\x00', 'Sarrafoglu.', 'disabilities.75', 'Ni-Al2O3', 'LDMC-C:', 'half-circumference']
# 64 ['ramp', 'begin', 'cut', 'rustle', 'pick', 'start', 'soak', 'keep', '15–20', 'meet', 'help']
# 65 ['rockslide', 'prototypal', 'astute', 'incubator', '∼90%.', '‘identifier’', 'honeybee', 'understand-', '“unadjusted', 'airport;', 'expeimental']
# 66 ['scene', 'hillside', 'hanged', 'neck,', 'backlash', 'flames', 'Maoist', 'CaCl2.6H2O', 'gardener', 'yardstick', 'lanyard']
# 67 ['scope', 'necessity', 'importance', 'complexity', 'existence', 'recognition', 'applicability', 'relevance', 'choice', 'purpose', 'sense']
# 68 ['season', 'winter', 'summer', 'season,', 'rain', 'spring', 'rainy', 'periods', 'days', 'seasons', 'warm']
# 69 ['setting', 'set', 'giving', 'scaled', 'taking', 'applying', 'target', 'introducing', 'controlled', 'assigning', 'vehicle']
# 70 ['shower', 'cheetah', 'bite', 'father', 'sons', 'pistons', 'live”', 'traveled', 'Tovosoa,', 'anticipated)', 'born']
# 71 ['snowstorm', 'territory."', '"uncharted', 'negotiations,', 'Blog’.42', 'pads.', 'modify.', 'accounts,', '1600s', '“Republican', '600-year']
# 72 ['sphere', 'LiCl', 'PUZ', 'R123', 'R290', '1.31', 'R236fa', 'R600a,', 'FE', 'sandwich', 'filler']
# 73 ['spring', 'winter', 'season', 'rainy', 'summer', 'winter,', 'sunny', 'season,', 'snow', 'February,', 'summer,']
# 74 ['storm', 'flooding', 'drought,', 'floods', 'droughts', 'storms', 'drought', 'heavy', 'severe', 'prolonged', 'floods,']
# 75 ['street', 'park', 'orientation', 'spaces', 'center', 'roof', 'splint,', 'tent', 'classroom', 'interior', 'canyon']
# 76 ['submerge', 'defy', 'flooding,[35]', 'storms,[34]', 'increase.[36]', 'underwater.', 'challenging.[note', 'crystals.', 'Pentagon', 'suffer.', 'bring,"']
# 77 ['summer', 'winter', 'season', 'season,', 'rainy', 'periods', 'night', 'warm', 'dry', 'sunny', 'spring']
# 78 ['summertime', 'inlet/outlet', 'hydrology,', 'mortality,', 'Likely,', 'farmlands;', 'photochemical', 'frame;', 'evaporation,', 'downpours,', 'Outlet']
# 79 ['sunshine', 'mid-day', 'durations', 'sunny', 'rainy', 'cloudy', 'lengths', 'lux', 'periods,', 'time)', '30–60']
# 80 ['surprise', 'devours', 'rest.”)', 'architect.', 'knew', 'absurd', 'hj', 'option,', 'believing', 'coaxialspiral', 'angry']
# 81 ['surround', 'retains', 'connects', 'underlines', 'broadening', 'discloses', 'violate', 'transcend', 'remark', 'fantasy', 'integrates']
# 82 ['surroundings', 'adhesion', 'gasifier', 'analytically', 'vermiculite', 'windows)', 'water)', 'studs', 'CWP', '15.8', 'shrub']
# 83 ['swamp', 'mangrove-saltwater', 'luggage', 'boron', 'finances,', 'self-employment.', 'residues,', 'services)', 'waste;', 'aerosolized', 'looted']
# 84 ['temperature', 'temperatures', 'temperature,', 'temperature.', 'velocity', 'humidity', 'pressure', 'Temperature', 'speed', 'concentration', 'inlet']
# 85 ['thaw', '(1,10)', 'furthermore,', 'Superheated', 'ΔTh', 'landslides;', '12000', 'LPST,', 'CPE,W', 'limit:', 'Confidence],']
# 86 ['thawing', 'permafrost', '584(7822),', 'dehydrogenation', 'ice.', '2007b).', 'Midwest,', 'unpredictability', 'displacements.', 'suburb.', 'methane.']
# 87 ['typhoon', "beings'", 'specify,', 'evapotranspiration,', '“tiomenas”', 'littoral', '“distress', 'community-centered,', 'unpredictability', '2011;95:2994', 'Slow']
# 88 ['upwind', 'Universitet,', 'decompression', 'B-B,', 'Jiangxi,', 'archive;', 'Pa)', 'Jhinguri,', 'Rostamian', 'Slab', '∂A']
# 89 ['warming', 'warming,', 'warming.', "warming's", 'AGW', '“Acting', 'Bambrick,', 'rise', 'detrending', 'humans', 'trend']
# 90 ['warmth', 'runoff', 'progressively', 'slowing', '41.92°C', 'salinity', '180°C', 'risks”', 'crime', 'synthesis-gases', 'fumes']
# 91 ['wave', 'wave,', 'dome', 'rejection.', 'waves', 'swamped', '116-degree', 'onslaught', 'flus', 'eclipsing', 'transformers.']
# 92 ['weather', 'events', 'climatic', 'patterns', 'events,', 'extreme', 'drought', 'rainfall', 'climate-related', 'severe', 'droughts']
# 93 ['wind', 'lighting', 'grid', 'irradiance', 'wind,', 'cell', 'occupancy', 'diffuse', 'sun', 'normal', 'horizontal']
# 94 ['winter', 'summer', 'season', 'season,', 'rainy', 'dry', 'spring', 'winter,', 'warm', 'night', 'monsoon']
# 95 ['wintertime', 'finite-rate', 'flushes', 'W22,', '\x0cAtmospheric', 'x(m)', '221-232.', '‘Miniature', 'systems)', 'Eref,', 'Spiral']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with climate

relevant_climate_w2v_words = list( list_of_climate_w2v[i] for i in [1,2,3,5,8,9,13,14,16,17,19,22,24,25,26,27,28,31,32,35,37,38,40,41,43,47,51,52,53,59,61,62,63,65,68,71,73,74,77,78,79,84,85,86,87,89,90,92,93,94,95])


## Add all the words into one final bags of words
climate_BoW = [item for sublist in relevant_climate_w2v_words for item in sublist]

print(climate_BoW)
# Out:
# ['acclimatisation', 'preparation', 'accountability', 'community-based', '(OAC)', 'Yjt—flows', 'contingency', 'arrangements', 'PERN.', 'design—professional’s', 'Statutes', 'adaptation', 'mitigation', 'policies', 'strategies', 'investments', 'policy', 'implementation', 'planning', 'measures', 'policies,', 'implementing', 'adaption', 'adaptation', 'foster', 'materialize', 'impetus', '‘information', 'community’s', 'adaptation,', 'intentional', 'obstacle', 'responding', 'air', 'water', 'air.', 'airflow', 'desiccant', 'indoor', 'air,', 'groundwater', 'evaporation', 'outdoor', 'liquid', 'atmosphere', 'atmosphere,', 'gases', 'oceans', 'ice', 'dioxide', 'evaporation', 'sunlight', 'ammonia', 'snow', 'exhaust', 'autumn', 'isochoric', 'overcast', '8-h', 'semiconductor,', 'anti-Semitic', 'interminable', 'erroneous', 'spotty', 'harvest—are', 'highway', 'cold', 'hot', 'humid', 'warm', 'dry', 'ground', 'wet', 'winter', 'summer', 'tank', 'condensation', 'conditions', 'conditions,', 'condition', 'conditions.', 'parameters', 'pressures', 'patterns', 'zones', 'occupants', 'zone', 'locations', 'dehumidify', 'illuminate', 'moist', 'purificative', 'pre-heat', 'weaken', 'humidify', 'condense', 'dehumidifying', '[244].', 'degrade', 'dehydrate', '(LiCl)', 'gel-water', 'Aluminum', 'polyvinyl', 'Russ', 'fume,', 'silicate', 'electroless', 'gel/molecular', '(LiBr)', 'desiccate', '1983;26:231–', 'Temp.', 'selfassembled', 'g/m2', 'monolayers', 'HUMOR10,', 'degree(◦', 'org/10.1073/pnas.1816020116.', 'bulbs.', 'K21)', 'domestication', '(0.26', '(aluminium),', '1252', 'edible', 'relatives,', 'out-of-control', '(CH3CHO', 'weight/ml)].', 'Cheery', '2-intensive', 'downpour', 'Malley', 'would,', 'Gabr', 'hh33−h', 'Belhamel', 'McKinney', 'Alvina', 'objections.', 'Morrissey,', '(2°C)', 'drought', 'storm', 'severe', 'droughts', 'flooding', 'floods', 'drought,', 'storms', 'devastating', 'cyclones', 'rainfall', 'dry', 'wet', 'warm', 'cold', 'winter', 'summer', 'hot', 'rain', 'rainy', 'ice', 'snow', 'ecology', 'Root', 'treaties,', '\x0cAssessment', 'economics,', 'x)U12', 'Framing', 'Prevalence', 'Settlement', 'Ontology', 'disorganized', 'ecosystem', 'marine', 'biodiversity', 'agricultural', 'resource', 'agriculture,', 'biological', 'ecological', 'ecosystems,', 'infrastructure', 'ecosystems', 'environment', 'environment,', 'environment.', 'climate,', 'nature', 'spaces', 'infrastructure', 'ecological', 'long-term', 'environments', 'environments,', 'environs', '(EMF)', 'entirety.', '0.16/', 'brethren', 'thick;', 'simplicity;', 'Asbestos', 'specializations', 'homes)', '−0.4,', 'firestorm', 'Gatlinburg,', 'Tenn.,', '70-cm', 'Tocantins,', 'oils:', '1493,', 'reduzir', 'paper/', 'Tsunami)', '15-W', 'flood', 'flooding', 'vegetation', 'drought,', 'storm', 'river', 'heavy', 'forest', 'acute', 'coastal', 'fire', 'flow', 'airflow', 'mixing', 'flows', 'evaporation', 'dehumidifier', 'turbulent', 'transfer', 'evaporator', 'liquid', 'channel', 'habitat', 'biodiversity', 'erosion', 'fish', 'deforestation', 'desertification,', 'injuries,', 'ecosystems,', 'salinity', 'noise', 'erosion,', 'hailstorm', '1.001)', '2388', 'TCD', 'I_b}', 'Ẇpump2', '(Tsec', 'Ẋ', 'b19', '\x03TPinch,VG', 'θt', 'heat', 'sensible,', 'finite-heat', 'heat,', 'rock)', 'Heat', 'heat.', 'counterflow', '2017;157:462–76.', 'cooling', 'mass', 'landslide', '95447', 'sonic,', 'Desert,', 'mg21', 'fitting,', 'decrement', 'Européen', 'PCM-façade', 'fell—', 'namely;', 'monsoon', 'season,', 'winter', 'droughts', 'heatwaves', 'rainy', 'seasons', 'hurricanes', 'prolonged', 'summers', 'storm', 'natural', 'geological', 'direct', 'oil', 'weather-related', 'forest', 'biological', 'nature', 'climate-related', 'damage', 'physical', 'orbit', 'flows', 'atmosphere', 'atmosphere,', 'sunlight', 'liquid', 'radiative', 'groundwater', 'injected', 'formation', 'droplet', 'precipitation', 'rainfall', 'pollen', 'rainfall,', 'Arctic', 'melting', 'snow', 'precipitation,', 'droughts', 'temperatures,', 'ice', 'rain', 'ice', 'storm', 'snow', 'season',  ...

# %%
## get word2vec words for authoritarianism

list_of_damage_w2v = get_word2vec_list(damage_list,model)

index =0
for w2v_list in list_of_damage_w2v:
  print(index, w2v_list)
  index +=1
# Out:
# 0 ['accomplish', 'validate', 'analyse', 'refine', 'formulate', 'simplify', 'famers.', 'derail', 'resolve', 'listen', 'verify']
# 1 ['action', 'action,', 'efforts', 'commitments', 'actions', 'measures', 'collective', 'policy', 'policies', 'leadership', 'governments']
# 2 ['affect', 'alter', 'exacerbate', 'threaten', 'trigger', 'cause', 'disrupt', 'contribute', 'aggravate', 'worsen', 'modify']
# 3 ['aftermath', 'midst', 'outbreak', 'Horn', 'Ida', 'highlands', 'Delta', 'Bay', 'context', 'ITCZ,', 'northwest']
# 4 ['alarm', 'ringing', 'bell', 'Ethernet.', 'Case1-Rig', 'Brexit),', 'UDP/IP', 'Case3-Rig', '110,000', 'dominion', 'Rioboo']
# 5 ['alienate', 'rancor', 'express', 'trait:', 'adsorb', 'less’.', 'devote', 'follow,', '[38];', 'denialism', 'threat"']
# 6 ['antenna', '2014;4:553–73.', 'silica)', 'Stick', 'Herve', 'autoencoder', 'Spanou', 'Decision-Making', 'Bedriñana,', '100–2000', 'Wooden']
# 7 ['anxiety', 'conflict,', 'events,', 'violence,', 'attitudes,', 'shocks', 'exacerbation', 'mental', 'culture,', 'psychosocial', 'chronic']
# 8 ['apprehension', 'embezzler', 'Caribbean34,', '12.989', '9–11', 'Spearheaded', '\x00L\x00u\x00o\x001\x00*\x00,\x00', 'dQg', 'Sangbangi', 'Fernández', '[*]']
# 9 ['arouse', 'exaggerate', 'adsorb', 'devote', 'fishes,', 'corals”', '39.1◦', 'detriment', 'belong', 'bricks).', 'less’.']
# 10 ['attack', 'window,', 'birthday', 'backlash', 'comedian', 'sister', 'hanged', 'blockade', 'mattress', 'hillside', '1920-22']
# 11 ['austere', 'practicalities.', 'island’', '\x07\x07\x07Climate', 'prosperity”', 'complement', 'Applicants', '--remittances', 'glycogen-accumulating', 'parameterize', 'liberate']
# 12 ['awaken', 'hitched', 'Salvador)', '116,000', 'ers', '1869', 'smooth/bubbling', 'responses.143', '“Barriers', 'wagon', '25,000.']
# 13 ['backwash', '(Wdc)', 'Creation', '“Resident', 'Injection', 'ASHVE', 'bio-diesel', 'Fly', 'lignin', 'cloths', '1948;47:339–']
# 14 ['basin', 'shallow', 'U-tube', 'evacuated', 'tower', 'wax', 'disinfection', 'finned', 'roof,', 'high-temperature', 'ponds']
# 15 ['bed', 'packed', 'reactor', 'tube', 'wick', 'plate', 'cylinder', 'layer', 'copper', 'absorber', 'capillary']
# 16 ['blues', 'much-recycled', '–1.66X2', '1920s', 'SAPO,', 'theatre', 'Fortes.', '\x0cK.S.', '(2016°),', 'Lauro', 'Feedrate']
# 17 ['bother', 'ndia', 'Liberaltarianism', 'GUATEMALA.', 'EC-funded', 'overt', '<http://web.', 'necessitating', 'authority-order', 'ARM', 'acknowledgement']
# 18 ['bottom', 'entrance', 'exit', 'top,', 'height', 'sun', 'port', 'depth', 'bottom,', 'openings', 'outlet']
# 19 ['brace', 'adaptation."', 'Shaftesbury,', 'tolerance—these', 'drinks)', '67]', '79.76', 'reason;', 'excuses', '£2889', 'toiling']
# 20 ['branch', 'semi-permeable', 'tile)', 'pitched', 'spirit', 'glass.', 'AP', 'BOS', 'gateway', '358988', 'Konigsallee,']
# 21 ['break', 'evolve', 'qualms.', 'go', 'supplier', 'save', 'enter', 'message,', 'begin', 'upside', 'push']
# 22 ['burden', 'likelihood', 'prevalence', 'population,', 'proportion', 'consequences', 'brunt', 'burdens', 'impacts', 'incidence', 'impact']
# 23 ['burn', 'transfers,', 'lose,', '(27%),', 'Substrates', 'algal', 'fuel,', '(mineral', 'factories,', 'cars,', 'forestry/forest']
# 24 ['business', 'society', 'private', 'community', 'foreign', 'supporting', 'institutions', 'military', 'formal', 'culture', 'public']
# 25 ['by-product', '‘liberaltarianism’', 'museum.', 'transducer.', 'predator,', 'snarling', 'F.A', '52-year-old', 'candidate?', 'paper/', '‘Agriculture']
# 26 ['byproduct', 'CHE,', 'profound,', 'by-product', 'ammoniate', 'Millar', 'zone”—not', '“existential”', '“transition', 'prototypal', 'Matlab/C']
# 27 ['calm', 'sunshine', 'rainy', 'ambient):', 'decrement', 'upturn', 'lake', 'belt', 'LTC', 'sheets,', 'low-density']
# 28 ['capitulation', 'inactivism—though', 'micro-VAWTs', 'passport”', 'sweating.', 'climate-focused', 'libertarians?', 'impious', 'wouldn’t', 'co-authored),', "don't"]
# 29 ['care', 'services', 'education,', 'services,', 'housing,', 'safety', 'women’s', 'healthy', 'service', 'needs,', 'consumers']
# 30 ['carry', 'find', 'carrying', 'check', 'lay', 'lowerincome', 'speak', 'seek', 'send', 'participate.', 'heat/']
# 31 ['change', 'change,', 'crisis', 'change.', 'changing', 'change—the', 'negative', 'change”', 'changes', 'crisis.', 'deep-seated']
# 32 ['chill', '(subprogramme', 'RM4:', 'pD2v;e', 'yuan/kg', 'Shamsapour,', 'Qaux,', 'Risselada', '(chiller)', 'QHW', '@t']
# 33 ['click', 'commenting', 'worldbank.org.', '‘Create', '{{subject}}', 'link:', 'MF-DCCA', 'presentation.', 'download', 'clicking', 'instructions']
# 34 ['cloud', 'snow', 'sunlight', 'ozone', 'melting', 'groundwater', 'ice', 'evaporation', 'static', 'dust', 'rainfall']
# 35 ['color', 'victims', 'numbers', 'brunt', 'symptoms', 'exposed', 'disproportionately', 'illness', 'millions', 'poor', 'islands']
# 36 ['colour', 'single-', 'hygroscopic', 'substrate', 'MEPCM', 'ARI', 'studs', 'thicker', 'benzene', 'vegetated', 'microcapsules']
# 37 ['concern', 'concerns', 'issue', 'challenge', 'threat', 'challenges', 'debate', 'consensus', 'issues', 'reality', 'implications']
# 38 ['consequence', 'result', 'driver', 'epoch,', 'acts', 'result,', 'signpost', 'bi-modality', 'waterlogging', 'mono-causal', 'source/sink,']
# 39 ['corrode', 'necessitate', 'withstand,', 'deltas', 'seal', 'exist.)', 'recall,', 'exacerbate.', '‘poison’', 'co-occur', 'Definitely']
# 40 ['crater', 'Llopango.', '(paras', 'Earthquakes,', '(Boulder:', 'Season,', '281,', 'SARAH', 'Kolkata', 'Shale', 'Biosens']
# 41 ['creeps', 'hemisphere.', 'movements.', '2337.', 'Hemisphere.', 'scandalous', 'Rico.', 'coil).', 'Israel-Palestine,', 'Poland.', 'Lake.']
# 42 ['damage', 'degradation', 'loss', 'potentially', 'threats', 'crop', 'shocks', 'exposure', 'biodiversity', 'hazards', 'erosion']
# 43 ['dangerous', 'severe', 'catastrophic', 'comfortable', 'costly', 'becoming', 'susceptible', 'frequent', 'fragile', 'intense', 'digestion,']
# 44 ['deep', 'large', 'huge', 'small', 'concrete', 'traditional', 'particular', 'wider', 'strong', 'big', 'tree']
# 45 ['default', 'teeth', 'distinguishing', 'concordance', 'USCmax', '31.58C', 'interconnection', 'bonding', 'divergence', 'CDW.', 'tiles:']
# 46 ['deformation', 'damping', 'lateral', 'shear', 'modulus', 'MRR', 'elastic', 'confinement', 'deflection', 'axial', 'flame']
# 47 ['dent', 'investment/maintenance', 'nontraditional', '(Housing', 'medium-temperature', 'Sawdust', 'retool', '2014;79:161–70.', 'fats)', '(RES)-E', '2012;125:158–64.']
# 48 ['departure', 'Aside', 'thereon', 'scratch;', 'Apart', 'http://www.tainstruments.com/product.', 'Hailing', 'http://unstats.un.org/unsd/gender/default.html', 'hailing', 'viewpoint', 'UK-US']
# 49 ['depression', 'ill-health,', '(PTSD),', 'underemployment', 'water-borne', 'cancer,', 'depression,', 'post-traumatic', 'irritations', 'exacerbation', 'waterborne']
# 50 ['deprivation', 'unemployment,', 'semiconductor–modified', '(Swilling', 'exacerbation', 'injury,', 'restoration).’', 'machinery,', 'Coe', 'PERN.', 'outlay']
# 51 ['detriment', '“winnable”', '3.8-kg', ',Ac∗', 'act)', ',sc∗', 'beads,', 'fill”', 'donate,”', 'Pseudo-second-order', 'return.”33']
# 52 ['difficult', 'necessary', 'easier', 'easy', 'hard', 'impossible', 'harder', 'desirable', 'beneficial', 'convenient', 'feasible']
# 53 ['dismay', "Nakate's", '71%),', 'end-use.', '8).The', '10.4%,', '‘source', '14.4%', 'ignorance,', '7°C.', 'specify-']
# 54 ['distort', 'prohibit', 'reward', 'prejudice', 'steal', 'procedural', 'tangled', 'devise', 'licenses', 'tection', 'penalize']
# 55 ['distortion', 'sub-cell’s', 'SALP,', 'initialization.', 'M2þ(OH)22X', 'kl3', 'Type-I', '2500)', 'ecodistrict)', 'factor)', '15.0b']
# 56 ['disturb', 'prohibit', 'elicit', 'diminish', 'Potau', 'deplete', 'reserves,', 'obstruct', 'labour;', 'Okan', 'infect']
# 57 ['draw', 'extend', 'speak', 'deliver', 'hold', 'bring', 'apply', 'get', 'check', 'learn', 'reflect']
# 58 ['dread', '\x00E\x00n\x00v\x00i\x00r\x00o\x00n\x00m\x00e\x00n\x00t\x00', '73.8', 'Art.', '(0.368)', '–56.', '(0.001,', 'ISCC', '\x00L\x00i\x00u\x00*\x00,\x00', 'Þ=', '2010/11']
# 59 ['dwell', 'Superplasticizers', '2015;102:117–28.', '“set”', '‘‘lithium', 'condition);', 'Milan),', 'convertible', 'context', 'ArabMuslim', '(NG)']
# 60 ['eat', 'leave', 'send', 'hear', 'buy', 'cook', 'sell', 'sent', 'attend', 'stay', 'fend']
# 61 ['effect', 'impact', 'influence', 'effects', 'effectiveness', 'effect,', 'behaviour', 'uncertainty', 'behavior', 'characteristics', 'impacts']
# 62 ['effectuate', '2000–2010', 'aggressively,', 'migration-climate', 'ΔhFG', '\x0cPotential', 'detection.', 'me,’”', '(RFSSC)', '(Jaspal', '\x024%']
# 63 ['endanger', 'enjoy', 'afford', 'mention', 'realize', 'renew', 'pretend', 'do', 'tell', 'sufficient;', 'bolster']
# 64 ['endangerment', 'library,', '“individuals”', 'brutishness', 'values’', 'anaemia', 'pitfalls', 'educated,', 'girls;', 'demonstrations,', 'showcase']
# 65 ['energize', 'accessibility,', 'exclusion,', 'undermining', 'obstetric', "Hurricane's", 'games,', 'languages;', 'nonfinancial', 'spiritual', 'reinforcing']
# 66 ['epidemic', 'Leone,', 'Guet', 'nent', 'Tigray', '(UNEP/ICIMOD', 'Sauce,', 'Namib', 'invasion', 'million);', 'surg-']
# 67 ['erode', 'spark', 'Beetle-caused', 'campus)', 'prosperity”', 'marketable', 'inhibit', 'state-business-society', 'island’', 'aggravate', 'subvert']
# 68 ['eruption', '1208', 'confluence', 'popularity', 'mi-', 'destabilisations', 'photoelectrocatalytic', 'connotations', 'architecture”', 'Recognising', 'potentially']
# 69 ['event', 'phenomenon', 'events', 'unprecedented', 'event,', 'issue', 'situation', 'opening', 'shock', 'displacement', 'drought']
# 70 ['execute', ',Ac∗', 'fourth-order', 'develop,', 'Analytics', '23.28C,', 'devise', 'characterise', 'formulate', '“leakage”', 'guilt,']
# 71 ['exit', 'inlet', 'saturation', 'outlet', 'inlet,', 'pressure,', 'downstream', 'saturated', 'separator', 'chamber', 'evaporator']
# 72 ['expiration', '\x0215%,', 'conceiving', 'complaints;[14]', 'complains', 'falter,', 'sentiment,', 'inferential,', 'Compounded', 'greening,', 'charities...']
# 73 ['expose', 'utilize', 'steer', 'ammunition', 'belong', 'induce', 'accommodate', 'attract', 'starve', 'correspond', 'kill']
# 74 ['extreme', 'severe', 'events', 'climate-related', 'droughts', 'extremes', 'weather', 'patterns', 'intense', 'flooding', 'drought,']
# 75 ['fall', 'occur', 'reach', 'happen', 'disappear', 'move', 'survive', 'devolve', 'deteriorate', 'turn', 'remain']
# 76 ['fallout', 'wedge', 'bulge', 'Baffler', 'distract', 'deepest', 'population’s', 'database,2', 'inception', 'criticism', 'clamping']
# 77 ['fear', 'claim', 'seriously', 'cancer', 'feel', 'danger', 'feeling', 'lot', 'victims', 'fears', 'reality']
# 78 ['figure', 'table', 'trend', 'graph', 'scenario', 'chapter', 'Proposition', 'Fig.', 'Figure', 'figure,', 'year.']
# 79 ['fright', 'punctuality,', 'self-purification', '(36.48C)', 'swathes', 'ascendancy', 'cohorts', 'installer', 'uproot', 'plans;', 'areas.34']
# 80 ['frost', 'lateral', 'flame', 'droplet', 'axial', 'filling', 'inner', 'solidification', 'coolant', 'outer', 'oscillating']
# 81 ['fulfil', 'apply', 'extend', 'accommodate', 'exploit', 'guarantee', 'fulfill', 'eliminate', 'relieve', 'deliver', 'expand']
# 82 ['fulfill', 'realize', 'apply', 'extend', 'accept', 'overcome', 'guarantee', 'join', 'fulfil', 'adjust', 'perform']
# 83 ['fuss', 'fangs', 'handy,', 'bared,', 'nonresident', 'German-English', "Louis'", 'Melinda', 'Davin,', 'E20/tons,', 'Arias']
# 84 ['get', 'go', 'keep', 'enter', 'find', 'survive', 'choose', 'draw', 'stop', 'stay', 'send']
# 85 ['going', 'trying', 'willing', 'ready', 'hard', 'sure', 'able', 'impossible', 'getting', 'enough', 'thought']
# 86 ['grave', 'preventable,', 'reef', 'unstable', 'marginalisation', 'Pandemic.”', 'malaria', 'exercise,', '“land', 'microsphere.', 'foregone']
# 87 ['grievous', 'boxcutters', 'multi-horizontal', '120°', 'ðhg', 'Penalties', 'ZnO,', "Love'", 'tunable', '\x00W\x00o\x00n\x00g\x00', 'detached)']
# 88 ['hard', 'easy', 'difficult', 'doing', 'going', 'necessary', 'really', 'sure', 'everyone', 'always', 'trying']
# 89 ['harm', 'exacerbate', 'exclude', 'alter', 'undermine', 'raise', 'threats', 'intensify', 'trigger', 'prevent', 'retreat']
# 90 ['harvest', 'family’s', 'lost', 'off', 'home', 'eat', 'homes', 'selling', 'feed', 'house', 'running']
# 91 ['hasten', '(bottom-up)', 'meters—enough', 'survive?', '35.2%', 'chronological', 'livelihoods.79', '(Archer', 'keep', 'appease', 'rustle']
# 92 ['hazard', 'stress', 'geological', 'occurrence', 'modification', 'strokes,', 'drought,', 'conduction', 'disasters:', 'occupants,', 'formation']
# 93 ['headache', 'puppet', 'okay,”', 'Luisa', 'Hillhorst', 'Vanessa', 'Barriers,', '(Duffield', 'inspirational,"', 'Neubauer,', 'Confession']
# 94 ['helplessness', 'spokespeople,', 'methyl-5-benzoyl-2-benzimidazole', 'https://academic.oup.com/ijlct/article/7/3/215/754675', 'never-ending', 'https://academic.oup.com/ijlct/article/6/4/277/665421', 'EPS', 'gap’', 'client,', 'server;', 'sðTÞ']
# 95 ['hit', 'hardest', 'harmed', 'felt', 'affected', 'impacted', 'experienced', 'worst', 'bushfires', 'triggered', 'destroyed']
# 96 ['hole', 'exits', 'trickle', 'mat', 'ridge', 'truck', 'hillside', 'probe', 'lake', 'flake', 'miro']
# 97 ['hollow', 'corrugated', 'polyethylene', 'alumina', 'straw,', 'ceramic', 'glazing,', 'mud', 'coating,', 'stainless', 'SiC']
# 98 ['horror', 'revolutionary', 'municipality', 'solidifies', 'moment,', 'PSNP,', 'oldest', 'swam', '(Dt)', 'thread', 'well-connected']
# 99 ['hurt', 'reduce,', 'afford', 'less,', '“free', 'reallocate', 'hyper-capitalists', 'definitely', '35.6', 'take.', 'builders']
# 100 ['hysteria', 'grow?', 'saviors.', 'measure”', 'delivered,', 'change.[102]', 'warms.', '3.7.2', 'migrant.', 'cobenefits.', 'change—the']
# 101 ['image', 'experiment', 'definition', 'algorithm', 'outcome', 'procedure', 'calculation', 'expression', 'object', 'argument', 'foundation']
# 102 ['impact', 'effect', 'effects', 'influence', 'impacts', 'consequences', 'influences', 'behavior', 'implications', 'benefits', 'burden']
# 103 ['impair', 'inhibit', 'aggravate', 'provoke', 'prolong', 'destroy', 'disrupt', 'stimulate', 'degrade', 'weaken', 'lessen']
# 104 ['impairment', 'overhaul', '"power', 'impede', 'goals.”', 'skew', 'personalities', 'obstacle', 'realities.', 'contexts.123', 'countrymen']
# 105 ['impress', 'livestock,"', 'Depending', 'knowledge:', 'Focusing', 're-reading', 'physical–mechanical', '(q7)', 'church’s', 'depended', 'tacked']
# 106 ['impression', 'rhetoric', 'citations"', 'suggestion', 'handheld', 'fostered', 'elaborated', 'optimism', 'proof', 'merit', 'actuaries']
# 107 ['inconvenience', 'impart', 'miti-', 'overwhelms', 'families.145', 'violate', 'complained', 'gests', 'realisation', 'realities.', 'bind']
# 108 ['induce', 'aggravate', 'modify', 'Iceland’s', 'weaken', 'provoke', 'disrupt', 'worsen', 'necessitate', 'deltas', 'illuminate']
# 109 ['infect', '55´E.', '4=good,', '(GBV)', 'Otte,', '3=satisfactory,', 'consular', 'yeast,', 'emotions,', '(116,', 'childcare.']
# 110 ['influence', 'effect', 'impact', 'behavior', 'influences', 'effects', 'uncertainty', 'behaviour', 'importance', 'strain', 'stability']
# 111 ['inquietude', 'multi-extreme', 'sity', 'smoothness', '6300', 'interdependence', 'transformers:', 'Medicaid', 'chemicals.’', 'Matlab10.', 'environmentally-displaced']
# 112 ['insecurity', 'insecurity,', 'hardship', 'insecurity.', 'security', 'vulnerability,', 'mitigation-price', 'inequality', 'shortages', 'crises', 'piles']
# 113 ['instill', 'adsorbers:', '2016;124:163–76.', '‘leapfrog’', 'noncooperative', '20-kW', 'multicomponent-fluid', 'stills—the', 'commissioning:', '‘posi-', 'workbench.']
# 114 ['interest', 'issue', 'understanding', 'investment', 'importance', 'improvement', 'incentive', 'recognition', 'acceptance', 'participation', 'progress']
# 115 ['intimidation', 'gifts,', 'petty', '57.3%', 'reintroduced', 'Ehrenmann,', '61–110', 'dye', 'chalky', 'rails.', 'distressed']
# 116 ['issue', 'reality', 'problem', 'challenge', 'topic', 'situation', 'issue,', 'concern', 'debate', 'question', 'consensus']
# 117 ['jar', 'coins', 'landholding,', 'sister,', 'four-by-four', '“royally', 'drove', 'face,', '(para', "others'", 'Asiah']
# 118 ['jeopardize', 'Makhviladze', 'p.82.', 'DeLucia,', 'Diamantis,', 'Koutnik,', '1363–1370', '(0.165)', '\x0cR', '\x00t\x00e\x00c\x00h\x00n\x00i\x00q\x00u\x00e\x00', 'Logist']
# 119 ['jeopardy', 'Flights', 'Micha', '\x0223', '“Tal', 'Frames', 'then:', 'Churning', 'Fifty-seven', 'Beatles', 'mh']
# 120 ['life-threatening', 'diarrheal', 'cancer,', 'contamination,', 'kidney', 'dehydration.', 'cholera', 'malaria,', 'suicidality.', 'waterborne', 'occurrences']
# 121 ['load', 'loads', 'mode', 'charge', 'charging', 'output', 'operation', 'battery', 'heating', 'load,', 'COP']
# 122 ['loss', 'losses', 'destruction', 'damage', 'leakage', 'latent', 'formation', 'intensity', 'accumulation', 'stress', 'excess']
# 123 ['low', 'high', 'higher', 'lower', 'minimal', 'large', 'medium', 'substantial', 'limited', 'small', 'good']
# 124 ['lowland', 'non-algae', 'north-eastern', 'cocoa', '9AB', 'Bedroom', 'sprawling', 'populated,', 'darker', 'drought-stricken', 'Valley,']
# 125 ['mark', 'supranational,', 'grandchildren,', '“struggling', '“make', 'homophobic', 'act.', 'Up', 'heaven.', 'brainstorm', 'summarise']
# 126 ['menace', 'self-stereotype', 'Berkelman,', 'derivatives', 'HuffPost', 'grip', 'replication', 'LDDS.', 'CRI,', 'terraces', 'odour']
# 127 ['move', 'seek', 'migrate', 'go', 'travel', 'stay', 'struggle', 'moving', 'survive', 'participate', 'evolve']
# 128 ['nervousness', 'investor-grade', '(improved', 'ushers', '(IAA).', 'Duminil,', 'installer', 'change.84', 'pro\x02', '45.8', 'pathogen,']
# 129 ['occupy', 'running,', 'intense,', 'fertile', 'logic)', 'die,"', 'Sometimes,', 'acidic,', 'disappear', 'thicken', 'thus,']
# 130 ['offset', 'harmful', 'contribute', 'reduce', 'absorb', 'minimize', 'alter', 'yield', 'reducing', 'avoid', 'maximize']
# 131 ['offshoot', 'Khatijite', 'sect,', 'asymmetric-anisotropic', 'ensemble', 'RR', 'leaf,', 'politician,', 'Versuche', 'AGS', 'Technosynesis']
# 132 ['onus', 'foods:', '\x0cResearch', 'occasion,', 'Essays', 'FOX', 'credit;', 'weekdays,', 'indebtedness.', '\x0cHV', 'behalf']
# 133 ['oppression', 'harshest', 'harmed', 'triggered', 'weather-proofing', 'threatened', 'self-reliance', 'hindered', 'borne', 'process/industrial', 'hardest']
# 134 ['outbreak', 'Ida', 'beetle', 'midst', 'aftermath', 'Ethiopia', 'Midwest,', 'worsened', 'Afghanistan', 'Syria', 'witnessed']
# 135 ['outcome', 'indicator', 'explanation', 'definition', 'examination', 'image', 'aspect', 'object', 'assumption', 'agent', 'reality']
# 136 ['palsy', 'ulcer', 'throat,', '2P2', '.PH2', 'courtesy', '2017;144:262–75.', 'Garden.', 'frightening', '.Pco', 'ŻHX-2']
# 137 ['panic', 'booklet', 'birthday', 'paused', 'winning', 'Rhoda,', 'shortfall', 'neighbor', 'idea,', 'fix.', 'fight.']
# 138 ['paralyzed', '(de)regulation;', '2017YFB0903201)', 'Healthy,', '“Capacity', 'https://www.yjc.ir.', 'Zero’', '"Democrats', '(NERC)', 'Fulbright', 'Ruhr']
# 139 ['passing', 'flowing', 'discharged', 'fed', 'passed', 'passes', 'R-12', 'desiccator', 'heated', 'carbonized', 'flows']
# 140 ['peril', 'Dakotas', 'fast-spreading', 'convert."[272]', '31.258N', '589.7', '(extraction,', 'thereon', 'hurries', 'misuse.', 'http://unstats.un.org/unsd/gender/default.html']
# 141 ['pierce', '(bottom', 'sleeve-type', '(ppb)', 'snowpack', '6.11', 'highs', '+2.0', '201,', '¼15.6', 'Plasterboard']
# 142 ['precipitate', 'personalization', 'capital)', 'Owner/developer', 'Probably', 'Definitely', '2.6,', 'seal', 'GCR,', 'ratify,', 'troublesome']
# 143 ['predisposition', '5.12', '‘fair’', 'Cambourne,', 'delighted', 'God,', '47.6', 'Crores', '(VCs)', 'τwk', '‘truthful’,']
# 144 ['process', 'method', 'device', 'technique', 'solution', 'processes', 'scheme', 'mechanism', 'process.', 'process,', 'concept']
# 145 ['product', 'replacement', 'recycling', 'manufacturer', 'vehicle', 'unit', 'charge', 'requirement', 'price', 'weight', 'gross']
# 146 ['reactivity', 'Inter-relationship', '694', 'H·', 'bond', 'Midst', '14°N,', '4°N', '5–18◦', '\x07Limited', 'business;']
# 147 ['red', 'Pt', 'blue', 'UV', 'nanowires', 'pore', 'spacing', 'coarse', 'ceria', 'sand', 'wick']
# 148 ['reducing', 'reduce', 'minimizing', 'lowering', 'improving', 'limiting', 'reduction', 'decreasing', 'increasing', 'reductions', 'reduced']
# 149 ['register', 'carmakers', 'litres,', 'maltreatment', '1080', 'self-enforcing', 'GaInAs', 'X1,', 'bookmark', 'Rowley', 'Mercedes']
# 150 ['relax', 'listen', 'extend', '(w•x', 'revert', 'swallow,”', 'belong', '57.2°C', 'thesis…The', 'commit', 'crawl,']
# 151 ['release', 'formation', 'extraction', 'trap', 'atmosphere,', 'exhaust', 'separation', 'accumulation', 'combustion', 'source,', 'pyrolysis']
# 152 ['repercussion', 'drivers,', 'impact,', 'toughness', 'dichotomy).', 'Marketing,', 'outcomes,', 'policies,”', 'impacts,', 'attitude', 'portrayal']
# 153 ['response', 'addition', 'failure', 'responding', 'displacement', 'relation', 'responses', 'measure', 'challenge', 'context', 'short-term']
# 154 ['responsiveness', 'change’[32]', 'crisis:', 'socially-inclusive', 'change/', 'Administration;', 'change</h1>', 'change-migration', 'challenges.22', 'distance”', 'change;']
# 155 ['restiveness', 'strife.', 'shifts.', 'environment-oriented', 'sectors.', 'encephalitides.', 'observatories', 'networks:', 'challenges.165', 'buildings—use', 'features.']
# 156 ['result', 'cause', 'consequence', 'phenomenon', 'presence', 'decrease', 'pattern', 'situation', 'experience', 'decline', 'trend']
# 157 ['risk', 'risks', 'vulnerability', 'risk.', 'climate-related', 'risk,', 'consequences', 'likelihood', 'violence', 'burden', 'potentially']
# 158 ['run', 'operate', 'get', 'pass', 'open', 'running', 'draw', 'go', 'opened', 'self-generation', 'check']
# 159 ['rush', 'evening', 'Moore-Willis', 'FDR', '16:30', 'getaway', 'sunrise', '28.59', '30th', 'snow.', 'anniversary']
# 160 ['rust', 'chabazite.', 'vacation,', 'CuO–NiO', 'triacetin', 'R1234ze.', 'Post-retrofit', 'agility.', 'hydrophobic-coated', 'synonymous', '(2.1%']
# 161 ['sacrifice', 'parents', 'afraid', 'thirty-five,', 'someone', 'feeling', 'everyone', 'familiar', 'merely', 'rare', '60.8%,']
# 162 ['scare', 'propagate', 'laurel', 'Really', 'Concluding', 'Probably', 'Definitely', 'stop,', 'boycott', 'Ibrahim”', 'Sander']
# 163 ['scourge', 'MORE»', 'detention.”', 'problem."[46]', 'REUTERS/Jitendra', 'emissions".[37]', 'district:', 'circle.', 'Tale', 'LIFE-SAVING', 'constructions.']
# 164 ['sensibility', 'non-parts', 'toxicity', 'Galerkin–Fourier', 'nonflammability', 'Due', 'incomes).', 'attain', 'Owing', 'owing', 'wage']
# 165 ['sensitisation', 'Racial', '5.3.', '(Glynn', 'Vegetation', 'luminescent', 'Boswijk', 'Diaz-Sanchez,', 'Shabecoff,', 'Fierer,', 'Allergic']
# 166 ['sensitivity', 'effectiveness', 'accuracy', 'estimation', 'dynamic', 'precision', 'prediction', 'inertia', 'determination', 'measure', 'modeling']
# 167 ['sensitization', 'mortality,', 'respiratory', 'rainfall,', 'vector-borne', 'asthma', 'allergic', 'infectious', 'pollen', 'cardiovascular', 'erosion,']
# 168 ['serious', 'great', 'dire', 'crucial', 'huge', 'significant', 'immediate', 'threat', 'dominant', 'considerable', 'substantial']
# 169 ['serve', 'separate.', 'act', 'inform', 'apply', 'liberate', 'balloon', 'opposed', 'offer', 'follow.', 'define']
# 170 ['severe', 'drought,', 'droughts', 'devastating', 'floods', 'drought', 'flooding', 'storm', 'storms', 'frequent', 'intense']
# 171 ['sink', 'rejection', 'reservoir', 'exchanger', 'exchanger,', '(occurring', 'exhaustion', 'sink.', 'flux).', 'viscosities,', 'sink,']
# 172 ['sinking', '\x0cAmusan,', 'silt-heavy', 'fermentative', 'on-board', 'Algal', '(4.6', 'Biochem.', '[157,', 'biomass-burning', 'perfluorocarbons,']
# 173 ['slump', 'Selwynraj', '2195.2385', '2001;32:1031', 'SECTOR?', 'Country-by-Country', 'Consolidate.', '2011;390:', 'Workbook', 'Patwardhan,', '91.57%']
# 174 ['soak', 'attend,', 'be,', 'pass', 'furnish', 'subvert', 'unsubscribe', 'tarnish', 'save', 'operate', 'grab']
# 175 ['spillover', 'C=O', 'contexts—feed', 'emanate', 'Ecotect).', 'transmissions', 'decomposing', 'deflector,', 'pathogen', 'Blasius', 'newcomers']
# 176 ['spoil', 'drink;', 'soak', 'harvested', 'save', 'move?', '37.7', '(25◦', 'eat', 'cools', 'distribute']
# 177 ['squeeze', 'conservationist', 'decentralized,', '(37%)', 'accessible,', 'insurance,', 'climate-resistant', 'shelter,', 'economically,', 'affordable,', 'encouraging.']
# 178 ['stake', 'arrears', 'school-turned-shelter', 'landowners,', 'risk,"', 'Kyrgyz', '0.210', 'Employees', 'forefront', 'granularities,', 'Rabigh,']
# 179 ['stark', '“zero', 'Westerling,', 'Agents', 'development-security', 'disputed', 'Comparatively', 'demonstrating', 'Calone', 'Certification', 'd’états']
# 180 ['stern', '(m3/kg),', 'y–', 'Hospital,', 'Mariano', '37.43,', 'Power.”', 'Arias', '0–10', 'sui', '17.8%,']
# 181 ['stimulate', 'bolster', 'constrain', 'undermine', 'foster', 'prioritize', 'hinder', 'alleviate', 'attract', 'exploit', 'spur']
# 182 ['stir', 'Huixtla,', 'amid', 'herds.71', 'Azteca', 'theorist', 'awaits', 'S73–94.', 'domain,', 'octane', 'appearance,21']
# 183 ['strain', 'stress', 'strains', 'superplasticizers', 'transmission', 'deformation', 'restriction', 'dependence', 'reliance', 'influence', '(ethanol']
# 184 ['stress', 'stress,', 'exposure', 'waves', 'strain', 'hazard', 'illness', 'symptoms', 'loss', 'cardiovascular', 'stresses']
# 185 ['strike', 'ended', 'strike,', 'Monday', 'Friday', 'Sunday,', 'week-long', 'Fernandez', 'him', 'protest', 'girl']
# 186 ['subject', 'applicable', 'relevant', 'whether', 'question', 'topic', 'particular', 'reality', 'fit', 'preferred', 'issue']
# 187 ['surprise', 'devours', 'rest.”)', 'architect.', 'knew', 'absurd', 'hj', 'option,', 'believing', 'coaxialspiral', 'angry']
# 188 ['surrender', 'voluntarism,', 'vacillation', 'Isobe', 'X0:t', '(n.d.),', 'Bibi,', 'Liulitun', 'Generación,', 'Kuribayashi', 'T.W.']
# 189 ['tense', 'PCM-collector', 'displace', 'Cortical', 'compatible,', 'prosecute', 'disintegrate.', 'have!', 'campus)', 'services…', 'glazed;']
# 190 ['tension', '10:1),', 'r2,', 'divergence', 'similarity', 'personalities,', '(Roser-Renouf', '3:1;', 'waivers', 'dominion”', '((Cwf4/CL)opt)']
# 191 ['terrible', 'pawns', 'terrible,', 'Ritu', 'Storch,', '‘hockey', '(Basquiat)', 'Abbafati,', 'Herdt', 'Camsek', 'Fields']
# 192 ['terror', 'prisms', 'checkup.', 'singled', '61.94%', '63.80%', 'genThis', '“They’d', '0.619;', '(Qh,0', 'binned.']
# 193 ['threat', 'challenge', 'issue', 'concern', 'problem', 'threats', 'serious', 'consequences', 'causes', 'crisis', 'movement']
# 194 ['total', '10%', 'annual', 'net', 'remaining', 'lowest', 'cumulative', 'highest', '70%', '50%', 'equivalent']
# 195 ['touch', 'fishermen', 'contracted', '(150,150)', 'lie', 'stuck', 'terrain', 'compete', 'gravitate', 'territory', 'weekend,']
# 196 ['treat', 'adopt', 'persuade', 'convince', 'choose', 'belong', 'exploit', 'encourage', 'try', 'deploy', 'seek']
# 197 ['trench', '\x02100', 'plane)', '(only', 'string', '0.485%', '0.11', '315', 'diameter)', 'pen', '(Rials']
# 198 ['trouble', 'awkward', 'diminished', 'fountain', 'deniers', 'majority.', '"expressed', 'stated:', 'wished', '‘No’.', 'changed.']
# 199 ['trough', 'parabolic', 'photovoltaic/thermal', 'concentrating', 'concentrator', 'flat-plate', 'dish', 'Parabolic', 'Fresnel', '(PV/T)', 'photovoltaic']
# 200 ['unmanageable', 'industryfriendly', 'ascendent', 'under-production', '\uf8f2C', 'East,”', 'absconding', 'disinfection:', '8-week', 'unstoppable', 'mismatch.']
# 201 ['upset', 'daily/charge', '(qr)', 'BREBM', 'occupancy:', 'Sun’s', '(LAMEEs)', '2009;249:602–608.', 'trates', 'hvol,', '(stored,']
# 202 ['utmost', '(CJEU)', 'crucial', 'important', 'imperative', 'inherently', 'My', 'fundamental', 'rooted', 'crucial,', 'grounded']
# 203 ['vale', 'Sewe,', 'WU7,', 'Kuntu,', 'J103-2∼7.', 'Transportprozesse', 'Thermoelements', 'government-community', '\x00A\x00m\x00', '\x00r\x00e\x00f\x00l\x00e\x00c\x00t\x00a\x00n\x00c\x00e\x00s\x00,\x00', 'Mattheos']
# 204 ['valley', 'river,', 'Hefei', 'mountains,', 'Macapá', 'sample,', 'balcony', 'northeast', 'Portland,', 'littoral', 'municipality']
# 205 ['vapors', 'sunflower', '(Mutants–Sonaka)', 'CO2-enriched', 'reaction:', 'microwave', 'ether', 'anaerobic', '“restoring', 'powders', 'kerosene']
# 206 ['vapours', 'ball', 'sweep', 'HCFC-22', 'Formation', '(NiCl2,', 'fractionation', 'precool', 'NaCl', 'polypropylene', 'fuel-rich']
# 207 ['venture', '(Chicago', 'ActNow', 'system,”', 'Protection,', 'GIZ,', 'sector—including', 'EAgen', 'Normals,', 'funder', 'Riyadh:']
# 208 ['vex', 'rationale,', 'investigations,', 'Off,', 'hands,”', 'trees,”', 'questions,', 'interpretation', 'applicability', 'ULL', 'fragilities,']
# 209 ['wake', '#Omicron', 'experiments,', '1960s,', 'run-up', 'place.30', 'infection,', 'lead-in', 'Muddy', 'welcome.', '6.3.26,']
# 210 ['wastage', 'Recovered', 'undersupply).', 'usage;', 'efficiency.[121]', 'storage—hygrothermal', 'cheaper)', 'high-grade', 'Surplus', 'Regulated', 'justice:']
# 211 ['wicked', 'lecturer', '\x00I\x00E\x00A\x00', 'Viscosity', 'women),', 'S7,6', '\x00p\x00u\x00m\x00p\x00', 'Yag', 'her,”', 'acetylene', 'Tudor-style']
# 212 ['work', 'research', 'work,', 'job', 'work.', 'site', 'lo-', 'open', 'place', 'knowledge', 'experience']
# 213 ['worry', 'worried', 'talking', 'passionate', '2004;43:915,', '(Read', '2014;9:26019–28.', 'Prey.', 'divides.', 'Canadians', '60,000']
# 214 ['wound', 'silvery', 'Jamot', 'bracelets,', '0.26–', '(subprogramme', 'fully-mechanized', 'NaHCO3),', 'https://academic.oup.com/ijlct/article/16/4/1328/6324924', 'shimmering', 'Bottarelli*']
# 215 ['wrong', 'happy', 'really', 'me', 'worse,”', '“I', 'something', 'says,', 'pretty', 'familiar', 'visiting']

# %%
## chose from the word2vec outputs, the lists that seem to have clouds of meanings coherent with prosociality
## in this example we choose indexes 3,6,9,11,13 and 14
relevant_damage_w2v_words = list( list_of_damage_w2v[i] for i in [2,3,4,5,7,10,17,22,23,38,42,43,46,49,50,51,52,53,54,55,56,58,61,62,63,64,66,67,68,74,75,76,77,86,87,88,89,92,95,99,102,103,104,107,108,109,110,116,119,120,122,129,134,137,138,140,148,152,157,162,170,183,184,191,192,193,200,210,211,213,214])


## Add all the words into one final bags of words
damage_BoW = [item for sublist in relevant_damage_w2v_words for item in sublist]

print(damage_BoW)
# Out:
# ['affect', 'alter', 'exacerbate', 'threaten', 'trigger', 'cause', 'disrupt', 'contribute', 'aggravate', 'worsen', 'modify', 'aftermath', 'midst', 'outbreak', 'Horn', 'Ida', 'highlands', 'Delta', 'Bay', 'context', 'ITCZ,', 'northwest', 'alarm', 'ringing', 'bell', 'Ethernet.', 'Case1-Rig', 'Brexit),', 'UDP/IP', 'Case3-Rig', '110,000', 'dominion', 'Rioboo', 'alienate', 'rancor', 'express', 'trait:', 'adsorb', 'less’.', 'devote', 'follow,', '[38];', 'denialism', 'threat"', 'anxiety', 'conflict,', 'events,', 'violence,', 'attitudes,', 'shocks', 'exacerbation', 'mental', 'culture,', 'psychosocial', 'chronic', 'attack', 'window,', 'birthday', 'backlash', 'comedian', 'sister', 'hanged', 'blockade', 'mattress', 'hillside', '1920-22', 'bother', 'ndia', 'Liberaltarianism', 'GUATEMALA.', 'EC-funded', 'overt', '<http://web.', 'necessitating', 'authority-order', 'ARM', 'acknowledgement', 'burden', 'likelihood', 'prevalence', 'population,', 'proportion', 'consequences', 'brunt', 'burdens', 'impacts', 'incidence', 'impact', 'burn', 'transfers,', 'lose,', '(27%),', 'Substrates', 'algal', 'fuel,', '(mineral', 'factories,', 'cars,', 'forestry/forest', 'consequence', 'result', 'driver', 'epoch,', 'acts', 'result,', 'signpost', 'bi-modality', 'waterlogging', 'mono-causal', 'source/sink,', 'damage', 'degradation', 'loss', 'potentially', 'threats', 'crop', 'shocks', 'exposure', 'biodiversity', 'hazards', 'erosion', 'dangerous', 'severe', 'catastrophic', 'comfortable', 'costly', 'becoming', 'susceptible', 'frequent', 'fragile', 'intense', 'digestion,', 'deformation', 'damping', 'lateral', 'shear', 'modulus', 'MRR', 'elastic', 'confinement', 'deflection', 'axial', 'flame', 'depression', 'ill-health,', '(PTSD),', 'underemployment', 'water-borne', 'cancer,', 'depression,', 'post-traumatic', 'irritations', 'exacerbation', 'waterborne', 'deprivation', 'unemployment,', 'semiconductor–modified', '(Swilling', 'exacerbation', 'injury,', 'restoration).’', 'machinery,', 'Coe', 'PERN.', 'outlay', 'detriment', '“winnable”', '3.8-kg', ',Ac∗', 'act)', ',sc∗', 'beads,', 'fill”', 'donate,”', 'Pseudo-second-order', 'return.”33', 'difficult', 'necessary', 'easier', 'easy', 'hard', 'impossible', 'harder', 'desirable', 'beneficial', 'convenient', 'feasible', 'dismay', "Nakate's", '71%),', 'end-use.', '8).The', '10.4%,', '‘source', '14.4%', 'ignorance,', '7°C.', 'specify-', 'distort', 'prohibit', 'reward', 'prejudice', 'steal', 'procedural', 'tangled', 'devise', 'licenses', 'tection', 'penalize', 'distortion', 'sub-cell’s', 'SALP,', 'initialization.', 'M2þ(OH)22X', 'kl3', 'Type-I', '2500)', 'ecodistrict)', 'factor)', '15.0b', 'disturb', 'prohibit', 'elicit', 'diminish', 'Potau', 'deplete', 'reserves,', 'obstruct', 'labour;', 'Okan', 'infect', 'dread', '\x00E\x00n\x00v\x00i\x00r\x00o\x00n\x00m\x00e\x00n\x00t\x00', '73.8', 'Art.', '(0.368)', '–56.', '(0.001,', 'ISCC', '\x00L\x00i\x00u\x00*\x00,\x00', 'Þ=', '2010/11', 'effect', 'impact', 'influence', 'effects', 'effectiveness', 'effect,', 'behaviour', 'uncertainty', 'behavior', 'characteristics', 'impacts', 'effectuate', '2000–2010', 'aggressively,', 'migration-climate', 'ΔhFG', '\x0cPotential', 'detection.', 'me,’”', '(RFSSC)', '(Jaspal', '\x024%', 'endanger', 'enjoy', 'afford', 'mention', 'realize', 'renew', 'pretend', 'do', 'tell', 'sufficient;', 'bolster', 'endangerment', 'library,', '“individuals”', 'brutishness', 'values’', 'anaemia', 'pitfalls', 'educated,', 'girls;', 'demonstrations,', 'showcase', 'epidemic', 'Leone,', 'Guet', 'nent', 'Tigray', '(UNEP/ICIMOD', 'Sauce,', 'Namib', 'invasion', 'million);', 'surg-', 'erode', 'spark', 'Beetle-caused', 'campus)', 'prosperity”', 'marketable', 'inhibit', 'state-business-society', 'island’', 'aggravate', 'subvert', 'eruption', '1208', 'confluence', 'popularity', 'mi-', 'destabilisations', 'photoelectrocatalytic', 'connotations', 'architecture”', 'Recognising', 'potentially', 'extreme', 'severe', 'events', 'climate-related', 'droughts', 'extremes', 'weather', 'patterns', 'inte ...

# %%
## An hypothetical bag of words was thus obtained, which can be used for frequency analyses
## See next script

print('climate',climate_BoW)
print('\n')
print('damage',damage_BoW)
# Out:
# climate ['acclimatisation', 'preparation', 'accountability', 'community-based', '(OAC)', 'Yjt—flows', 'contingency', 'arrangements', 'PERN.', 'design—professional’s', 'Statutes', 'adaptation', 'mitigation', 'policies', 'strategies', 'investments', 'policy', 'implementation', 'planning', 'measures', 'policies,', 'implementing', 'adaption', 'adaptation', 'foster', 'materialize', 'impetus', '‘information', 'community’s', 'adaptation,', 'intentional', 'obstacle', 'responding', 'air', 'water', 'air.', 'airflow', 'desiccant', 'indoor', 'air,', 'groundwater', 'evaporation', 'outdoor', 'liquid', 'atmosphere', 'atmosphere,', 'gases', 'oceans', 'ice', 'dioxide', 'evaporation', 'sunlight', 'ammonia', 'snow', 'exhaust', 'autumn', 'isochoric', 'overcast', '8-h', 'semiconductor,', 'anti-Semitic', 'interminable', 'erroneous', 'spotty', 'harvest—are', 'highway', 'cold', 'hot', 'humid', 'warm', 'dry', 'ground', 'wet', 'winter', 'summer', 'tank', 'condensation', 'conditions', 'conditions,', 'condition', 'conditions.', 'parameters', 'pressures', 'patterns', 'zones', 'occupants', 'zone', 'locations', 'dehumidify', 'illuminate', 'moist', 'purificative', 'pre-heat', 'weaken', 'humidify', 'condense', 'dehumidifying', '[244].', 'degrade', 'dehydrate', '(LiCl)', 'gel-water', 'Aluminum', 'polyvinyl', 'Russ', 'fume,', 'silicate', 'electroless', 'gel/molecular', '(LiBr)', 'desiccate', '1983;26:231–', 'Temp.', 'selfassembled', 'g/m2', 'monolayers', 'HUMOR10,', 'degree(◦', 'org/10.1073/pnas.1816020116.', 'bulbs.', 'K21)', 'domestication', '(0.26', '(aluminium),', '1252', 'edible', 'relatives,', 'out-of-control', '(CH3CHO', 'weight/ml)].', 'Cheery', '2-intensive', 'downpour', 'Malley', 'would,', 'Gabr', 'hh33−h', 'Belhamel', 'McKinney', 'Alvina', 'objections.', 'Morrissey,', '(2°C)', 'drought', 'storm', 'severe', 'droughts', 'flooding', 'floods', 'drought,', 'storms', 'devastating', 'cyclones', 'rainfall', 'dry', 'wet', 'warm', 'cold', 'winter', 'summer', 'hot', 'rain', 'rainy', 'ice', 'snow', 'ecology', 'Root', 'treaties,', '\x0cAssessment', 'economics,', 'x)U12', 'Framing', 'Prevalence', 'Settlement', 'Ontology', 'disorganized', 'ecosystem', 'marine', 'biodiversity', 'agricultural', 'resource', 'agriculture,', 'biological', 'ecological', 'ecosystems,', 'infrastructure', 'ecosystems', 'environment', 'environment,', 'environment.', 'climate,', 'nature', 'spaces', 'infrastructure', 'ecological', 'long-term', 'environments', 'environments,', 'environs', '(EMF)', 'entirety.', '0.16/', 'brethren', 'thick;', 'simplicity;', 'Asbestos', 'specializations', 'homes)', '−0.4,', 'firestorm', 'Gatlinburg,', 'Tenn.,', '70-cm', 'Tocantins,', 'oils:', '1493,', 'reduzir', 'paper/', 'Tsunami)', '15-W', 'flood', 'flooding', 'vegetation', 'drought,', 'storm', 'river', 'heavy', 'forest', 'acute', 'coastal', 'fire', 'flow', 'airflow', 'mixing', 'flows', 'evaporation', 'dehumidifier', 'turbulent', 'transfer', 'evaporator', 'liquid', 'channel', 'habitat', 'biodiversity', 'erosion', 'fish', 'deforestation', 'desertification,', 'injuries,', 'ecosystems,', 'salinity', 'noise', 'erosion,', 'hailstorm', '1.001)', '2388', 'TCD', 'I_b}', 'Ẇpump2', '(Tsec', 'Ẋ', 'b19', '\x03TPinch,VG', 'θt', 'heat', 'sensible,', 'finite-heat', 'heat,', 'rock)', 'Heat', 'heat.', 'counterflow', '2017;157:462–76.', 'cooling', 'mass', 'landslide', '95447', 'sonic,', 'Desert,', 'mg21', 'fitting,', 'decrement', 'Européen', 'PCM-façade', 'fell—', 'namely;', 'monsoon', 'season,', 'winter', 'droughts', 'heatwaves', 'rainy', 'seasons', 'hurricanes', 'prolonged', 'summers', 'storm', 'natural', 'geological', 'direct', 'oil', 'weather-related', 'forest', 'biological', 'nature', 'climate-related', 'damage', 'physical', 'orbit', 'flows', 'atmosphere', 'atmosphere,', 'sunlight', 'liquid', 'radiative', 'groundwater', 'injected', 'formation', 'droplet', 'precipitation', 'rainfall', 'pollen', 'rainfall,', 'Arctic', 'melting', 'snow', 'precipitation,', 'droughts', 'temperatures,', 'ice', 'rain', 'ice', 'storm', 'snow', 's ...
#
#
# damage ['affect', 'alter', 'exacerbate', 'threaten', 'trigger', 'cause', 'disrupt', 'contribute', 'aggravate', 'worsen', 'modify', 'aftermath', 'midst', 'outbreak', 'Horn', 'Ida', 'highlands', 'Delta', 'Bay', 'context', 'ITCZ,', 'northwest', 'alarm', 'ringing', 'bell', 'Ethernet.', 'Case1-Rig', 'Brexit),', 'UDP/IP', 'Case3-Rig', '110,000', 'dominion', 'Rioboo', 'alienate', 'rancor', 'express', 'trait:', 'adsorb', 'less’.', 'devote', 'follow,', '[38];', 'denialism', 'threat"', 'anxiety', 'conflict,', 'events,', 'violence,', 'attitudes,', 'shocks', 'exacerbation', 'mental', 'culture,', 'psychosocial', 'chronic', 'attack', 'window,', 'birthday', 'backlash', 'comedian', 'sister', 'hanged', 'blockade', 'mattress', 'hillside', '1920-22', 'bother', 'ndia', 'Liberaltarianism', 'GUATEMALA.', 'EC-funded', 'overt', '<http://web.', 'necessitating', 'authority-order', 'ARM', 'acknowledgement', 'burden', 'likelihood', 'prevalence', 'population,', 'proportion', 'consequences', 'brunt', 'burdens', 'impacts', 'incidence', 'impact', 'burn', 'transfers,', 'lose,', '(27%),', 'Substrates', 'algal', 'fuel,', '(mineral', 'factories,', 'cars,', 'forestry/forest', 'consequence', 'result', 'driver', 'epoch,', 'acts', 'result,', 'signpost', 'bi-modality', 'waterlogging', 'mono-causal', 'source/sink,', 'damage', 'degradation', 'loss', 'potentially', 'threats', 'crop', 'shocks', 'exposure', 'biodiversity', 'hazards', 'erosion', 'dangerous', 'severe', 'catastrophic', 'comfortable', 'costly', 'becoming', 'susceptible', 'frequent', 'fragile', 'intense', 'digestion,', 'deformation', 'damping', 'lateral', 'shear', 'modulus', 'MRR', 'elastic', 'confinement', 'deflection', 'axial', 'flame', 'depression', 'ill-health,', '(PTSD),', 'underemployment', 'water-borne', 'cancer,', 'depression,', 'post-traumatic', 'irritations', 'exacerbation', 'waterborne', 'deprivation', 'unemployment,', 'semiconductor–modified', '(Swilling', 'exacerbation', 'injury,', 'restoration).’', 'machinery,', 'Coe', 'PERN.', 'outlay', 'detriment', '“winnable”', '3.8-kg', ',Ac∗', 'act)', ',sc∗', 'beads,', 'fill”', 'donate,”', 'Pseudo-second-order', 'return.”33', 'difficult', 'necessary', 'easier', 'easy', 'hard', 'impossible', 'harder', 'desirable', 'beneficial', 'convenient', 'feasible', 'dismay', "Nakate's", '71%),', 'end-use.', '8).The', '10.4%,', '‘source', '14.4%', 'ignorance,', '7°C.', 'specify-', 'distort', 'prohibit', 'reward', 'prejudice', 'steal', 'procedural', 'tangled', 'devise', 'licenses', 'tection', 'penalize', 'distortion', 'sub-cell’s', 'SALP,', 'initialization.', 'M2þ(OH)22X', 'kl3', 'Type-I', '2500)', 'ecodistrict)', 'factor)', '15.0b', 'disturb', 'prohibit', 'elicit', 'diminish', 'Potau', 'deplete', 'reserves,', 'obstruct', 'labour;', 'Okan', 'infect', 'dread', '\x00E\x00n\x00v\x00i\x00r\x00o\x00n\x00m\x00e\x00n\x00t\x00', '73.8', 'Art.', '(0.368)', '–56.', '(0.001,', 'ISCC', '\x00L\x00i\x00u\x00*\x00,\x00', 'Þ=', '2010/11', 'effect', 'impact', 'influence', 'effects', 'effectiveness', 'effect,', 'behaviour', 'uncertainty', 'behavior', 'characteristics', 'impacts', 'effectuate', '2000–2010', 'aggressively,', 'migration-climate', 'ΔhFG', '\x0cPotential', 'detection.', 'me,’”', '(RFSSC)', '(Jaspal', '\x024%', 'endanger', 'enjoy', 'afford', 'mention', 'realize', 'renew', 'pretend', 'do', 'tell', 'sufficient;', 'bolster', 'endangerment', 'library,', '“individuals”', 'brutishness', 'values’', 'anaemia', 'pitfalls', 'educated,', 'girls;', 'demonstrations,', 'showcase', 'epidemic', 'Leone,', 'Guet', 'nent', 'Tigray', '(UNEP/ICIMOD', 'Sauce,', 'Namib', 'invasion', 'million);', 'surg-', 'erode', 'spark', 'Beetle-caused', 'campus)', 'prosperity”', 'marketable', 'inhibit', 'state-business-society', 'island’', 'aggravate', 'subvert', 'eruption', '1208', 'confluence', 'popularity', 'mi-', 'destabilisations', 'photoelectrocatalytic', 'connotations', 'architecture”', 'Recognising', 'potentially', 'extreme', 'severe', 'events', 'climate-related', 'droughts', 'extremes', 'weather', 'patterns' ...
